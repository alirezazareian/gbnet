# %%
import numpy as np
np.random.seed(1234)
import torch
torch.manual_seed(1235)
torch.__version__
# Out:
# '0.3.0.post4'

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
codebase = '../../'
sys.path.append(codebase)

# %%
exp_name = 'exp_140'
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
from dataloaders.visual_genome import VGDataLoader, VG
import numpy as np
from torch import optim
import torch
import pandas as pd
import time
import os

from config import ModelConfig, BOX_SCALE, IM_SCALE
from torch.nn import functional as F
from lib.pytorch_misc import optimistic_restore, de_chunkize, clip_grad_norm
from lib.evaluation.sg_eval import BasicSceneGraphEvaluator, calculate_mR_from_evaluator_list, eval_entry
from lib.pytorch_misc import print_para
from torch.optim.lr_scheduler import ReduceLROnPlateau

from lib.my_model_34 import KERN

# %%
conf = ModelConfig(f'''
-m predcls -p 1000 -clip 5 
-tb_log_dir summaries/kern_predcls/{exp_name} 
-save_dir checkpoints/kern_predcls/{exp_name}
-ckpt checkpoints/vgdet/vg-24.tar 
-val_size 5000 
-adam 
-b 4
-ngpu 1
-lr 1e-4 
''')
# Out:
# ~~~~~~~~ Hyperparameters used: ~~~~~~~
# ckpt : checkpoints/vgdet/vg-24.tar
# save_dir : checkpoints/kern_predcls/exp_140
# num_gpus : 1
# num_workers : 1
# lr : 0.0001
# batch_size : 4
# val_size : 5000
# l2 : 0.0001
# adamwd : 0.0
# clip : 5.0
# print_interval : 1000
# mode : predcls
# cache :
# adam : True
# test : False
# num_epochs : 50
# use_resnet : False
# use_proposals : False
# pooling_dim : 4096
# use_ggnn_obj : False
# ggnn_obj_time_step_num : 3
# ggnn_obj_hidden_dim : 512
# ggnn_obj_output_dim : 512
# use_obj_knowledge : False
# obj_knowledge :
# use_ggnn_rel : False
# ggnn_rel_time_step_num : 3
# ggnn_rel_hidden_dim : 512
# ggnn_rel_output_dim : 512
# use_rel_knowledge : False
# rel_knowledge :
# tb_log_dir : summaries/kern_predcls/exp_140
# save_rel_recall :

# %%
train, val, _ = VG.splits(num_val_im=conf.val_size, filter_duplicate_rels=True,
                          use_proposals=conf.use_proposals,
                          filter_non_overlap=conf.mode == 'sgdet')

# %%
ind_to_predicates = train.ind_to_predicates # ind_to_predicates[0] means no relationship

# %%
train_loader, val_loader = VGDataLoader.splits(train, val, mode='rel',
                                               batch_size=conf.batch_size,
                                               num_workers=conf.num_workers,
                                               num_gpus=conf.num_gpus)

# %%
detector = KERN(classes=train.ind_to_classes, rel_classes=train.ind_to_predicates,
                num_gpus=conf.num_gpus, mode=conf.mode, require_overlap_det=True,
                use_resnet=conf.use_resnet, use_proposals=conf.use_proposals, pooling_dim=conf.pooling_dim,
                ggnn_rel_time_step_num=3, ggnn_rel_hidden_dim=1024, ggnn_rel_output_dim=None,
                graph_path=os.path.join(codebase, 'graphs/005/all_edges.pkl'), 
                emb_path=os.path.join(codebase, 'graphs/001/emb_mtx.pkl'), 
                rel_counts_path=os.path.join(codebase, 'graphs/001/pred_counts.pkl'), 
                use_knowledge=True, use_embedding=True, refine_obj_cls=False,
                class_volume=1.0, top_k_to_keep=5, normalize_messages=False,
               )

# %%
# Freeze the detector
for n, param in detector.detector.named_parameters():
    param.requires_grad = False

# %%
print(print_para(detector), flush=True)
# Out:
#  405.8M total parameters
#  -----
#
# detector.roi_fmap.0.weight                        : [4096,25088]    (102760448) (    )
# roi_fmap.1.0.weight                               : [4096,25088]    (102760448) (grad)
# roi_fmap_obj.0.weight                             : [4096,25088]    (102760448) (grad)
# detector.roi_fmap.3.weight                        : [4096,4096]     (16777216) (    )
# roi_fmap.1.3.weight                               : [4096,4096]     (16777216) (grad)
# roi_fmap_obj.3.weight                             : [4096,4096]     (16777216) (grad)
# ggnn_rel_reason.obj_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.rel_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# detector.bbox_fc.weight                           : [604,4096]      ( 2473984) (    )
# detector.features.19.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.21.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.24.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.26.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.28.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.rpn_head.conv.0.weight                   : [512,512,3,3]   ( 2359296) (    )
# detector.features.17.weight                       : [512,256,3,3]   ( 1179648) (    )
# union_boxes.conv.4.weight                         : [512,256,3,3]   ( 1179648) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: [1024,768]      (  786432) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: [1024,768]      (  786432) (grad)
# detector.score_fc.weight                          : [151,4096]      (  618496) (    )
# detector.features.12.weight                       : [256,256,3,3]   (  589824) (    )
# detector.features.14.weight                       : [256,256,3,3]   (  589824) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: [768,512]       (  393216) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: [768,512]       (  393216) (grad)
# detector.features.10.weight                       : [256,128,3,3]   (  294912) (    )
# detector.features.7.weight                        : [128,128,3,3]   (  147456) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# detector.features.5.weight                        : [128,64,3,3]    (   73728) (    )
# detector.rpn_head.conv.2.weight                   : [120,512,1,1]   (   61440) (    )
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: [51,1024]       (   52224) (grad)
# detector.features.2.weight                        : [64,64,3,3]     (   36864) (    )
# union_boxes.conv.0.weight                         : [256,2,7,7]     (   25088) (grad)
# detector.features.0.weight                        : [64,3,3,3]      (    1728) (    )
# union_boxes.conv.6.weight                         : [512]           (     512) (grad)
# union_boxes.conv.2.weight                         : [256]           (     256) (grad)

# %%
def get_optim(lr):
    # Lower the learning rate on the VGG fully connected layers by 1/10th. It's a hack, but it helps
    # stabilize the models.
    fc_params = [p for n,p in detector.named_parameters() if n.startswith('roi_fmap') and p.requires_grad]
    non_fc_params = [p for n,p in detector.named_parameters() if not n.startswith('roi_fmap') and p.requires_grad]
    params = [{'params': fc_params, 'lr': lr / 10.0}, {'params': non_fc_params}]
    # params = [p for n,p in detector.named_parameters() if p.requires_grad]

    if conf.adam:
        optimizer = optim.Adam(params, weight_decay=conf.adamwd, lr=lr, eps=1e-3)
    else:
        optimizer = optim.SGD(params, weight_decay=conf.l2, lr=lr, momentum=0.9)

    # scheduler = ReduceLROnPlateau(optimizer, 'max', patience=3, factor=0.1,
    #                               verbose=True, threshold=0.0001, threshold_mode='abs', cooldown=1)
    return optimizer #, scheduler

# %%
ckpt = torch.load(conf.ckpt)

# %%
if conf.ckpt.split('-')[-2].split('/')[-1] == 'vgrel':
    print("Loading EVERYTHING")
    start_epoch = ckpt['epoch']

    if not optimistic_restore(detector, ckpt['state_dict']):
        start_epoch = -1
        # optimistic_restore(detector.detector, torch.load('checkpoints/vgdet/vg-28.tar')['state_dict'])
else:
    start_epoch = -1
    optimistic_restore(detector.detector, ckpt['state_dict'])

    detector.roi_fmap[1][0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap[1][3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap[1][0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap[1][3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

    detector.roi_fmap_obj[0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap_obj[3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap_obj[0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap_obj[3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

# %%
detector.cuda();

# %%
def train_epoch(epoch_num):
    detector.train()
    tr = []
    start = time.time()
    for b, batch in enumerate(train_loader):
        result, loss_pd = train_batch(batch, verbose=b % (conf.print_interval*10) == 0)
        tr.append(loss_pd)
        '''
        if epoch_num == 1 and b % 1000 == 0:
            print('\n\n\n\n-------------------------------------------------------------------\n\n\n\n')
            print(detector.ggnn_rel_reason.ggnn.debug_info)        
        '''
        if b % conf.print_interval == 0 and b >= conf.print_interval:
            mn = pd.concat(tr[-conf.print_interval:], axis=1).mean(1)
            time_per_batch = (time.time() - start) / conf.print_interval
            print("\ne{:2d}b{:5d}/{:5d} {:.3f}s/batch, {:.1f}m/epoch".format(
                epoch_num, b, len(train_loader), time_per_batch, len(train_loader) * time_per_batch / 60))
            print(mn)
            print('-----------', flush=True)
            start = time.time()
    return pd.concat(tr, axis=1)

# %%
def train_batch(b, verbose=False):
    """
    :param b: contains:
          :param imgs: the image, [batch_size, 3, IM_SIZE, IM_SIZE]
          :param all_anchors: [num_anchors, 4] the boxes of all anchors that we'll be using
          :param all_anchor_inds: [num_anchors, 2] array of the indices into the concatenated
                                  RPN feature vector that give us all_anchors,
                                  each one (img_ind, fpn_idx)
          :param im_sizes: a [batch_size, 4] numpy array of (h, w, scale, num_good_anchors) for each image.

          :param num_anchors_per_img: int, number of anchors in total over the feature pyramid per img

          Training parameters:
          :param train_anchor_inds: a [num_train, 5] array of indices for the anchors that will
                                    be used to compute the training loss (img_ind, fpn_idx)
          :param gt_boxes: [num_gt, 4] GT boxes over the batch.
          :param gt_classes: [num_gt, 2] gt boxes where each one is (img_id, class)
    :return:
    """
    result = detector[b]

    losses = {}
    losses['class_loss'] = detector.obj_loss(result)
    losses['rel_loss'] = detector.rel_loss(result)
    loss = sum(losses.values())

    optimizer.zero_grad()
    loss.backward()
    clip_grad_norm(
        [(n, p) for n, p in detector.named_parameters() if p.grad is not None],
        max_norm=conf.clip, verbose=verbose, clip=True)
    losses['total'] = loss
    optimizer.step()
    loss_pd = pd.Series({x: y.data[0] for x, y in losses.items()})
    return result, loss_pd

# %%
def val_epoch():
    detector.eval()
    evaluator_list = [] # for calculating recall of each relationship except no relationship
    evaluator_multiple_preds_list = []
    for index, name in enumerate(ind_to_predicates):
        if index == 0:
            continue
        evaluator_list.append((index, name, BasicSceneGraphEvaluator.all_modes()))
        evaluator_multiple_preds_list.append((index, name, BasicSceneGraphEvaluator.all_modes(multiple_preds=True)))
    evaluator = BasicSceneGraphEvaluator.all_modes() # for calculating recall
    evaluator_multiple_preds = BasicSceneGraphEvaluator.all_modes(multiple_preds=True)
    for val_b, batch in enumerate(val_loader):
        val_batch(conf.num_gpus * val_b, batch, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list)

    recall = evaluator[conf.mode].print_stats()
    recall_mp = evaluator_multiple_preds[conf.mode].print_stats()
    
    mean_recall = calculate_mR_from_evaluator_list(evaluator_list, conf.mode)
    mean_recall_mp = calculate_mR_from_evaluator_list(evaluator_multiple_preds_list, conf.mode, multiple_preds=True)
    
    detector.train()
    return recall, recall_mp, mean_recall, mean_recall_mp

# %%
def val_batch(batch_num, b, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list):
    det_res = detector[b]
    if conf.num_gpus == 1:
        det_res = [det_res]

    for i, (boxes_i, objs_i, obj_scores_i, rels_i, pred_scores_i) in enumerate(det_res):
        gt_entry = {
            'gt_classes': val.gt_classes[batch_num + i].copy(),
            'gt_relations': val.relationships[batch_num + i].copy(),
            'gt_boxes': val.gt_boxes[batch_num + i].copy(),
        }
        assert np.all(objs_i[rels_i[:, 0]] > 0) and np.all(objs_i[rels_i[:, 1]] > 0)

        pred_entry = {
            'pred_boxes': boxes_i * BOX_SCALE/IM_SCALE,
            'pred_classes': objs_i,
            'pred_rel_inds': rels_i,
            'obj_scores': obj_scores_i,
            'rel_scores': pred_scores_i,  # hack for now.
        }

        eval_entry(conf.mode, gt_entry, pred_entry, evaluator, evaluator_multiple_preds, 
                   evaluator_list, evaluator_multiple_preds_list)

# %%
if conf.tb_log_dir is not None:
    from tensorboardX import SummaryWriter
    if not os.path.exists(conf.tb_log_dir):
        os.makedirs(conf.tb_log_dir) 
    writer = SummaryWriter(log_dir=conf.tb_log_dir)
    use_tb = True
else:
    use_tb = False

# %%
optimizer = get_optim(conf.lr * conf.num_gpus * conf.batch_size)

# %%
print("Training starts now!")

for epoch in range(1, 6):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 3.802 clip coef 1.315-----------------
# ggnn_rel_reason.rel_proj.weight                   : 2.502, (torch.Size([1024, 4096]))
# roi_fmap.1.3.weight                               : 1.336, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 1.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.987, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.935, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.860, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.800, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.707, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.688, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.688, (torch.Size([1024]))
# roi_fmap.1.0.weight                               : 0.523, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.286, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.269, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.254, (torch.Size([1024, 4096]))
# union_boxes.conv.4.weight                         : 0.208, (torch.Size([512, 256, 3, 3]))
# roi_fmap_obj.3.weight                             : 0.176, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.169, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.153, (torch.Size([768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.132, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.118, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.weight                             : 0.089, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.087, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.076, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.075, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.071, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.058, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.055, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.047, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.033, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.030, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.026, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.026, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.018, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.013, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.012, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.007, (torch.Size([768]))
# union_boxes.conv.0.bias                           : 0.007, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.006, (torch.Size([4096]))
# roi_fmap_obj.3.bias                               : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.004, (torch.Size([256]))
# union_boxes.conv.2.bias                           : 0.004, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b 1000/14430 0.311s/batch, 74.9m/epoch
# class_loss    0.000000
# rel_loss      0.241867
# total         0.241867
# dtype: float64
# -----------
#
# e 1b 2000/14430 0.309s/batch, 74.3m/epoch
# class_loss    0.000000
# rel_loss      0.185074
# total         0.185074
# dtype: float64
# -----------
#
# e 1b 3000/14430 0.308s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.178793
# total         0.178793
# dtype: float64
# -----------
#
# e 1b 4000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.174056
# total         0.174056
# dtype: float64
# -----------
#
# e 1b 5000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.166494
# total         0.166494
# dtype: float64
# -----------
#
# e 1b 6000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.00000
# rel_loss      0.16538
# total         0.16538
# dtype: float64
# -----------
#
# e 1b 7000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.162588
# total         0.162588
# dtype: float64
# -----------
#
# e 1b 8000/14430 0.311s/batch, 74.8m/epoch
# class_loss    0.0000
# rel_loss      0.1612
# total         0.1612
# dtype: float64
# -----------
#
# e 1b 9000/14430 0.306s/batch, 73.6m/epoch
# class_loss    0.000000
# rel_loss      0.164455
# total         0.164455
# dtype: float64
# -----------
# ---Total norm 0.383 clip coef 13.062-----------------
# roi_fmap.1.0.weight                               : 0.195, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.181, (torch.Size([51, 1024]))
# roi_fmap_obj.0.weight                             : 0.146, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.134, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.088, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.080, (torch.Size([4096, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.062, (torch.Size([1024, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.058, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.047, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.043, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.039, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.036, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.035, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.030, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.027, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.023, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.015, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.014, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.013, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.012, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.011, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.011, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.004, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.002, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.002, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# roi_fmap.1.0.bias                                 : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b10000/14430 0.309s/batch, 74.3m/epoch
# class_loss    0.000000
# rel_loss      0.156787
# total         0.156787
# dtype: float64
# -----------
#
# e 1b11000/14430 0.309s/batch, 74.3m/epoch
# class_loss    0.000000
# rel_loss      0.159241
# total         0.159241
# dtype: float64
# -----------
#
# e 1b12000/14430 0.307s/batch, 73.8m/epoch
# class_loss    0.000000
# rel_loss      0.157771
# total         0.157771
# dtype: float64
# -----------
#
# e 1b13000/14430 0.309s/batch, 74.3m/epoch
# class_loss    0.000000
# rel_loss      0.157336
# total         0.157336
# dtype: float64
# -----------
#
# e 1b14000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.155749
# total         0.155749
# dtype: float64
# -----------
# overall 1: (0.170)
# class_loss    0.000000
# rel_loss      0.170302
# total         0.170302
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.556965
# R@50: 0.613566
# R@100: 0.631253
# ======================predcls  recall without constraint============================
# R@20: 0.642815
# R@50: 0.778919
# R@100: 0.854816
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.08331807050234252
# mR@50:  0.10312044335570641
# mR@100:  0.10961323840759694
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.15155517667208973
# mR@50:  0.25847203113812617
# mR@100:  0.35742896147271286
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---Total norm 0.537 clip coef 9.307-----------------
# roi_fmap_obj.0.weight                             : 0.280, (torch.Size([4096, 25088]))
# roi_fmap.1.0.weight                               : 0.248, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.243, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.197, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.091, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.089, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.084, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.072, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.056, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.053, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.053, (torch.Size([768, 512]))
# union_boxes.conv.4.weight                         : 0.046, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.044, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.043, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.035, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.032, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.030, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.028, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.026, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.026, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.019, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.018, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.015, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.005, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.005, (torch.Size([512]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# roi_fmap.1.0.bias                                 : 0.001, (torch.Size([4096]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b 1000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.157005
# total         0.157005
# dtype: float64
# -----------
#
# e 2b 2000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.150613
# total         0.150613
# dtype: float64
# -----------
#
# e 2b 3000/14430 0.311s/batch, 74.7m/epoch
# class_loss    0.000000
# rel_loss      0.149073
# total         0.149073
# dtype: float64
# -----------
#
# e 2b 4000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.150223
# total         0.150223
# dtype: float64
# -----------
#
# e 2b 5000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.153897
# total         0.153897
# dtype: float64
# -----------
#
# e 2b 6000/14430 0.307s/batch, 73.8m/epoch
# class_loss    0.000000
# rel_loss      0.155426
# total         0.155426
# dtype: float64
# -----------
#
# e 2b 7000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.149953
# total         0.149953
# dtype: float64
# -----------
#
# e 2b 8000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.152426
# total         0.152426
# dtype: float64
# -----------
#
# e 2b 9000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.151652
# total         0.151652
# dtype: float64
# -----------
# ---Total norm 0.293 clip coef 17.093-----------------
# roi_fmap.1.0.weight                               : 0.158, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.147, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.124, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.094, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.058, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.047, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.041, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.035, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.033, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.027, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.025, (torch.Size([512, 256, 3, 3]))
# union_boxes.conv.0.weight                         : 0.021, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.020, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.017, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.008, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.007, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.007, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.006, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.005, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.003, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# union_boxes.conv.6.weight                         : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.002, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.001, (torch.Size([768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.001, (torch.Size([4096]))
# roi_fmap.1.0.bias                                 : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b10000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.00000
# rel_loss      0.15299
# total         0.15299
# dtype: float64
# -----------
#
# e 2b11000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.150064
# total         0.150064
# dtype: float64
# -----------
#
# e 2b12000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.152286
# total         0.152286
# dtype: float64
# -----------
#
# e 2b13000/14430 0.312s/batch, 74.9m/epoch
# class_loss    0.000000
# rel_loss      0.149067
# total         0.149067
# dtype: float64
# -----------
#
# e 2b14000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.147872
# total         0.147872
# dtype: float64
# -----------
# overall 2: (0.152)
# class_loss    0.000000
# rel_loss      0.151553
# total         0.151553
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.560017
# R@50: 0.615681
# R@100: 0.631451
# ======================predcls  recall without constraint============================
# R@20: 0.653318
# R@50: 0.791284
# R@100: 0.865246
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.10248885393704997
# mR@50:  0.1250944579100338
# mR@100:  0.1323328577195388
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.172814518630665
# mR@50:  0.2821720043711715
# mR@100:  0.40464033576900266
# ---Total norm 0.655 clip coef 7.632-----------------
# roi_fmap.1.0.weight                               : 0.333, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.317, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.280, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.239, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.119, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.115, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.095, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.091, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.078, (torch.Size([768, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.077, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.070, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.062, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.053, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.048, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.043, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.042, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.037, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.032, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.025, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.024, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.022, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.021, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.009, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.008, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.006, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.005, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 3b 1000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.144723
# total         0.144723
# dtype: float64
# -----------
#
# e 3b 2000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.151328
# total         0.151328
# dtype: float64
# -----------
#
# e 3b 3000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.147285
# total         0.147285
# dtype: float64
# -----------
#
# e 3b 4000/14430 0.310s/batch, 74.6m/epoch
# class_loss    0.000000
# rel_loss      0.145883
# total         0.145883
# dtype: float64
# -----------
#
# e 3b 5000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.148014
# total         0.148014
# dtype: float64
# -----------
#
# e 3b 6000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.149551
# total         0.149551
# dtype: float64
# -----------
#
# e 3b 7000/14430 0.306s/batch, 73.6m/epoch
# class_loss    0.000000
# rel_loss      0.150466
# total         0.150466
# dtype: float64
# -----------
#
# e 3b 8000/14430 0.310s/batch, 74.6m/epoch
# class_loss    0.000000
# rel_loss      0.144687
# total         0.144687
# dtype: float64
# -----------
#
# e 3b 9000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.148874
# total         0.148874
# dtype: float64
# -----------
# ---Total norm 0.882 clip coef 5.670-----------------
# roi_fmap.1.0.weight                               : 0.533, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.391, (torch.Size([51, 1024]))
# roi_fmap_obj.0.weight                             : 0.310, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.262, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.201, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.164, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.138, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.108, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.104, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.095, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.089, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.089, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.073, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.069, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.068, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.066, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.065, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.064, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.054, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.045, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.037, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.034, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.033, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.013, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.012, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.010, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.010, (torch.Size([768]))
# union_boxes.conv.6.weight                         : 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.007, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.007, (torch.Size([4096]))
# union_boxes.conv.0.bias                           : 0.007, (torch.Size([256]))
# ggnn_rel_reason.rel_proj.bias                     : 0.005, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 3b10000/14430 0.306s/batch, 73.5m/epoch
# class_loss    0.000000
# rel_loss      0.148707
# total         0.148707
# dtype: float64
# -----------
#
# e 3b11000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.145056
# total         0.145056
# dtype: float64
# -----------
#
# e 3b12000/14430 0.310s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.145456
# total         0.145456
# dtype: float64
# -----------
#
# e 3b13000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.00000
# rel_loss      0.14629
# total         0.14629
# dtype: float64
# -----------
#
# e 3b14000/14430 0.310s/batch, 74.6m/epoch
# class_loss    0.00000
# rel_loss      0.14729
# total         0.14729
# dtype: float64
# -----------
# overall 3: (0.147)
# class_loss    0.000000
# rel_loss      0.147385
# total         0.147385
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.567006
# R@50: 0.627481
# R@100: 0.645168
# ======================predcls  recall without constraint============================
# R@20: 0.652561
# R@50: 0.792946
# R@100: 0.868149
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.1154737980845728
# mR@50:  0.14094666990896929
# mR@100:  0.1488089764059162
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.18001324570452212
# mR@50:  0.2928224400218532
# mR@100:  0.4125172824646103
# ---Total norm 0.384 clip coef 13.020-----------------
# roi_fmap.1.0.weight                               : 0.218, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.188, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.158, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.112, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.081, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.060, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.054, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.043, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.043, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.036, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.031, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.030, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.026, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.023, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.022, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.021, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.016, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.015, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.015, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.010, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.005, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.003, (torch.Size([512]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.002, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 4b 1000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.145225
# total         0.145225
# dtype: float64
# -----------
#
# e 4b 2000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.142584
# total         0.142584
# dtype: float64
# -----------
#
# e 4b 3000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# ...
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 4b10000/14430 0.307s/batch, 73.8m/epoch
# class_loss    0.000000
# rel_loss      0.147461
# total         0.147461
# dtype: float64
# -----------
#
# e 4b11000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.143816
# total         0.143816
# dtype: float64
# -----------
#
# e 4b12000/14430 0.306s/batch, 73.6m/epoch
# class_loss    0.000000
# rel_loss      0.143488
# total         0.143488
# dtype: float64
# -----------
#
# e 4b13000/14430 0.307s/batch, 73.8m/epoch
# class_loss    0.000000
# rel_loss      0.146197
# total         0.146197
# dtype: float64
# -----------
#
# e 4b14000/14430 0.308s/batch, 74.0m/epoch
# class_loss    0.000000
# rel_loss      0.144581
# total         0.144581
# dtype: float64
# -----------
# overall 4: (0.145)
# class_loss    0.000000
# rel_loss      0.144519
# total         0.144519
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.572833
# R@50: 0.629466
# R@100: 0.646884
# ======================predcls  recall without constraint============================
# R@20: 0.661667
# R@50: 0.800299
# R@100: 0.873998
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.11577669101377001
# mR@50:  0.13855156749782074
# mR@100:  0.14845612645123007
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.19162279878769986
# mR@50:  0.3193967586679587
# mR@100:  0.44519161838563404
# ---Total norm 0.624 clip coef 8.011-----------------
# roi_fmap.1.0.weight                               : 0.386, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.279, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.240, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.211, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.127, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.097, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.072, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.068, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.055, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.054, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.049, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.049, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.044, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.040, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.035, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.031, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.026, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.025, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.024, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.021, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.018, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.017, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.015, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.007, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.006, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 5b 1000/14430 0.305s/batch, 73.2m/epoch
# class_loss    0.000000
# rel_loss      0.141731
# total         0.141731
# dtype: float64
# -----------
#
# e 5b 2000/14430 0.306s/batch, 73.5m/epoch
# class_loss    0.000000
# rel_loss      0.144448
# total         0.144448
# dtype: float64
# -----------
#
# e 5b 3000/14430 0.306s/batch, 73.6m/epoch
# class_loss    0.00000
# rel_loss      0.14259
# total         0.14259
# dtype: float64
# -----------
#
# e 5b 4000/14430 0.307s/batch, 73.7m/epoch
# class_loss    0.000000
# rel_loss      0.143055
# total         0.143055
# dtype: float64
# -----------
#
# e 5b 5000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.141663
# total         0.141663
# dtype: float64
# -----------
#
# e 5b 6000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.141184
# total         0.141184
# dtype: float64
# -----------
#
# e 5b 7000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.141099
# total         0.141099
# dtype: float64
# -----------
#
# e 5b 8000/14430 0.308s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.142467
# total         0.142467
# dtype: float64
# -----------
#
# e 5b 9000/14430 0.306s/batch, 73.5m/epoch
# class_loss    0.000000
# rel_loss      0.145874
# total         0.145874
# dtype: float64
# -----------
# ---Total norm 0.320 clip coef 15.631-----------------
# roi_fmap.1.0.weight                               : 0.171, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.149, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.125, (torch.Size([51, 1024]))
# roi_fmap_obj.3.weight                             : 0.112, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.073, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.059, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.051, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.046, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.041, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.038, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.037, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.034, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.026, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.025, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.021, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.016, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.011, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.011, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.010, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.010, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.007, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.004, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.rel_proj.bias                     : 0.002, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.002, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 5b10000/14430 0.309s/batch, 74.3m/epoch
# class_loss    0.000000
# rel_loss      0.141872
# total         0.141872
# dtype: float64
# -----------
#
# e 5b11000/14430 0.306s/batch, 73.7m/epoch
# class_loss    0.000000
# rel_loss      0.141466
# total         0.141466
# dtype: float64
# -----------
#
# e 5b12000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.140096
# total         0.140096
# dtype: float64
# -----------
#
# e 5b13000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.140512
# total         0.140512
# dtype: float64
# -----------
#
# e 5b14000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.140264
# total         0.140264
# dtype: float64
# -----------
# overall 5: (0.142)
# class_loss    0.000000
# rel_loss      0.142179
# total         0.142179
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.574908
# R@50: 0.629545
# R@100: 0.645835
# ======================predcls  recall without constraint============================
# R@20: 0.659305
# R@50: 0.796891
# R@100: 0.869978
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.11277874202821471
# mR@50:  0.13667947572505937
# mR@100:  0.14507219273910593
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.1809253348623891
# mR@50:  0.3030044200440958
# mR@100:  0.4312711860073909

# %%
for param_group in optimizer.param_groups:
    param_group['lr'] /= 10

# %%
print("Training starts now!")

for epoch in range(6, 11):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 0.604 clip coef 8.274-----------------
# roi_fmap_obj.0.weight                             : 0.318, (torch.Size([4096, 25088]))
# roi_fmap.1.0.weight                               : 0.316, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.232, (torch.Size([51, 1024]))
# roi_fmap_obj.3.weight                             : 0.229, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.109, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.084, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.067, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.063, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.056, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.054, (torch.Size([768, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.054, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.053, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.046, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.044, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.040, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.038, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.033, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.033, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.029, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.029, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.028, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.018, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.014, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.014, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.013, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.008, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.007, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.007, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 6b 1000/14430 0.305s/batch, 73.4m/epoch
# class_loss    0.000000
# rel_loss      0.142719
# total         0.142719
# dtype: float64
# -----------
#
# e 6b 2000/14430 0.308s/batch, 74.1m/epoch
# class_loss    0.000000
# rel_loss      0.137815
# total         0.137815
# dtype: float64
# -----------
#
# e 6b 3000/14430 0.311s/batch, 74.7m/epoch
# class_loss    0.000000
# rel_loss      0.134286
# total         0.134286
# dtype: float64
# -----------
#
# e 6b 4000/14430 0.307s/batch, 73.7m/epoch
# class_loss    0.000000
# rel_loss      0.135598
# total         0.135598
# dtype: float64
# -----------
#
# e 6b 5000/14430 0.310s/batch, 74.5m/epoch
# class_loss    0.000000
# rel_loss      0.138918
# total         0.138918
# dtype: float64
# -----------
#
# e 6b 6000/14430 0.310s/batch, 74.6m/epoch
# class_loss    0.00000
# rel_loss      0.13594
# total         0.13594
# dtype: float64
# -----------
#
# e 6b 7000/14430 0.310s/batch, 74.5m/epoch
# class_loss    0.000000
# rel_loss      0.136081
# total         0.136081
# dtype: float64
# -----------
#
# e 6b 8000/14430 0.308s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.137069
# total         0.137069
# dtype: float64
# -----------
#
# e 6b 9000/14430 0.309s/batch, 74.4m/epoch
# class_loss    0.000000
# rel_loss      0.133395
# total         0.133395
# dtype: float64
# -----------
# ---Total norm 0.468 clip coef 10.689-----------------
# roi_fmap.1.0.weight                               : 0.302, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.215, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.165, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.116, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.098, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.081, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.060, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.058, (torch.Size([768, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.053, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.051, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.051, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.050, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.036, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.036, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.029, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.029, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.024, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.017, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.016, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.014, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.010, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.009, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.006, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# roi_fmap_obj.3.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.005, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.003, (torch.Size([768]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.003, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 6b10000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.00000
# rel_loss      0.13414
# total         0.13414
# dtype: float64
# -----------
#
# e 6b11000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.135585
# total         0.135585
# dtype: float64
# -----------
#
# e 6b12000/14430 0.307s/batch, 73.8m/epoch
# class_loss    0.00000
# rel_loss      0.13734
# total         0.13734
# dtype: float64
# -----------
#
# e 6b13000/14430 0.306s/batch, 73.5m/epoch
# class_loss    0.000000
# rel_loss      0.136335
# total         0.136335
# dtype: float64
# -----------
#
# e 6b14000/14430 0.305s/batch, 73.3m/epoch
# class_loss    0.000000
# rel_loss      0.136366
# total         0.136366
# dtype: float64
# -----------
# overall 6: (0.136)
# class_loss    0.000000
# rel_loss      0.136382
# total         0.136382
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.584548
# R@50: 0.637978
# R@100: 0.653884
# ======================predcls  recall without constraint============================
# R@20: 0.675132
# R@50: 0.810817
# R@100: 0.879843
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.12663887971205032
# mR@50:  0.15374046760597712
# mR@100:  0.16468930089667388
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.2047889085831476
# mR@50:  0.3403410259495056
# mR@100:  0.4713673617611302
# ---Total norm 0.589 clip coef 8.484-----------------
# roi_fmap_obj.0.weight                             : 0.363, (torch.Size([4096, 25088]))
# roi_fmap.1.0.weight                               : 0.277, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.269, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.130, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.097, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.086, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.078, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.056, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.056, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.056, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.048, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.045, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.043, (torch.Size([512, 1024]))
# union_boxes.conv.4.weight                         : 0.035, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.034, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.031, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.031, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.024, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.023, (torch.Size([256, 512]))
# union_boxes.conv.0.weight                         : 0.022, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.021, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.012, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.010, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.009, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.006, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 7b 1000/14430 0.306s/batch, 73.5m/epoch
# class_loss    0.000000
# rel_loss      0.135128
# total         0.135128
# dtype: float64
# -----------
#
# e 7b 2000/14430 0.305s/batch, 73.3m/epoch
# class_loss    0.000000
# rel_loss      0.135483
# total         0.135483
# dtype: float64
# -----------
#
# e 7b 3000/14430 0.309s/batch, 74.2m/epoch
# class_loss    0.000000
# rel_loss      0.134481
# total         0.134481
# dtype: float64
# -----------
#
# e 7b 4000/14430 0.306s/batch, 73.7m/epoch
# class_loss    0.000000
# rel_loss      0.134649
# total         0.134649
# dtype: float64
# -----------
#
# e 7b 5000/14430 0.306s/batch, 73.7m/epoch
# class_loss    0.000000
# rel_loss      0.133762
# total         0.133762
# dtype: float64
# -----------
#
# e 7b 6000/14430 0.305s/batch, 73.3m/epoch
# class_loss    0.000000
# rel_loss      0.136032
# total         0.136032
# dtype: float64
# -----------
#
# e 7b 7000/14430 0.307s/batch, 73.9m/epoch
# class_loss    0.000000
# rel_loss      0.135337
# total         0.135337
# dtype: float64
# -----------
#
# e 7b 8000/14430 0.306s/batch, 73.7m/epoch
# class_loss    0.00000
# rel_loss      0.13732
# total         0.13732
# dtype: float64
# -----------
