# %%
import numpy as np
np.random.seed(1234)
import torch
torch.manual_seed(1235)
torch.__version__
# Out:
# '0.3.0.post4'

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
codebase = '../../'
sys.path.append(codebase)

# %%
exp_name = 'exp_136'
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
from dataloaders.visual_genome import VGDataLoader, VG
import numpy as np
from torch import optim
import torch
import pandas as pd
import time
import os

from config import ModelConfig, BOX_SCALE, IM_SCALE
from torch.nn import functional as F
from lib.pytorch_misc import optimistic_restore, de_chunkize, clip_grad_norm
from lib.evaluation.sg_eval import BasicSceneGraphEvaluator, calculate_mR_from_evaluator_list, eval_entry
from lib.pytorch_misc import print_para
from torch.optim.lr_scheduler import ReduceLROnPlateau

from lib.my_model_33 import KERN

# %%
conf = ModelConfig(f'''
-m predcls -p 1000 -clip 5 
-tb_log_dir summaries/kern_predcls/{exp_name} 
-save_dir checkpoints/kern_predcls/{exp_name}
-ckpt checkpoints/vgdet/vg-24.tar 
-val_size 5000 
-adam 
-b 4
-ngpu 1
-lr 1e-4 
''')
# Out:
# ~~~~~~~~ Hyperparameters used: ~~~~~~~
# ckpt : checkpoints/vgdet/vg-24.tar
# save_dir : checkpoints/kern_predcls/exp_136
# num_gpus : 1
# num_workers : 1
# lr : 0.0001
# batch_size : 4
# val_size : 5000
# l2 : 0.0001
# adamwd : 0.0
# clip : 5.0
# print_interval : 1000
# mode : predcls
# cache :
# adam : True
# test : False
# num_epochs : 50
# use_resnet : False
# use_proposals : False
# pooling_dim : 4096
# use_ggnn_obj : False
# ggnn_obj_time_step_num : 3
# ggnn_obj_hidden_dim : 512
# ggnn_obj_output_dim : 512
# use_obj_knowledge : False
# obj_knowledge :
# use_ggnn_rel : False
# ggnn_rel_time_step_num : 3
# ggnn_rel_hidden_dim : 512
# ggnn_rel_output_dim : 512
# use_rel_knowledge : False
# rel_knowledge :
# tb_log_dir : summaries/kern_predcls/exp_136
# save_rel_recall :

# %%
train, val, _ = VG.splits(num_val_im=conf.val_size, filter_duplicate_rels=True,
                          use_proposals=conf.use_proposals,
                          filter_non_overlap=conf.mode == 'sgdet')

# %%
ind_to_predicates = train.ind_to_predicates # ind_to_predicates[0] means no relationship

# %%
train_loader, val_loader = VGDataLoader.splits(train, val, mode='rel',
                                               batch_size=conf.batch_size,
                                               num_workers=conf.num_workers,
                                               num_gpus=conf.num_gpus)

# %%
detector = KERN(classes=train.ind_to_classes, rel_classes=train.ind_to_predicates,
                num_gpus=conf.num_gpus, mode=conf.mode, require_overlap_det=True,
                use_resnet=conf.use_resnet, use_proposals=conf.use_proposals, pooling_dim=conf.pooling_dim,
                ggnn_rel_time_step_num=2, ggnn_rel_hidden_dim=1024, ggnn_rel_output_dim=None,
                graph_path=os.path.join(codebase, 'graphs/005/all_edges.pkl'), 
                emb_path=os.path.join(codebase, 'graphs/001/emb_mtx.pkl'), 
                rel_counts_path=os.path.join(codebase, 'graphs/001/pred_counts.pkl'), 
                use_knowledge=True, use_embedding=True, refine_obj_cls=False,
                class_volume=1.0, top_k_to_keep=5, normalize_messages=False,
               )

# %%
# Freeze the detector
for n, param in detector.detector.named_parameters():
    param.requires_grad = False

# %%
print(print_para(detector), flush=True)
# Out:
#  444.6M total parameters
#  -----
#
# detector.roi_fmap.0.weight                        : [4096,25088]    (102760448) (    )
# roi_fmap.1.0.weight                               : [4096,25088]    (102760448) (grad)
# roi_fmap_obj.0.weight                             : [4096,25088]    (102760448) (grad)
# detector.roi_fmap.3.weight                        : [4096,4096]     (16777216) (    )
# roi_fmap.1.3.weight                               : [4096,4096]     (16777216) (grad)
# roi_fmap_obj.3.weight                             : [4096,4096]     (16777216) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: [3328,3328]     (11075584) (grad)
# ggnn_rel_reason.obj_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.rel_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: [2048,2048]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: [1024,3328]     ( 3407872) (grad)
# detector.bbox_fc.weight                           : [604,4096]      ( 2473984) (    )
# detector.features.19.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.21.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.24.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.26.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.28.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.rpn_head.conv.0.weight                   : [512,512,3,3]   ( 2359296) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: [1024,2048]     ( 2097152) (grad)
# detector.features.17.weight                       : [512,256,3,3]   ( 1179648) (    )
# union_boxes.conv.4.weight                         : [512,256,3,3]   ( 1179648) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: [1024,768]      (  786432) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: [1024,768]      (  786432) (grad)
# detector.score_fc.weight                          : [151,4096]      (  618496) (    )
# detector.features.12.weight                       : [256,256,3,3]   (  589824) (    )
# detector.features.14.weight                       : [256,256,3,3]   (  589824) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : [1024,300]      (  307200) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : [1024,300]      (  307200) (grad)
# detector.features.10.weight                       : [256,128,3,3]   (  294912) (    )
# detector.features.7.weight                        : [128,128,3,3]   (  147456) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# detector.features.5.weight                        : [128,64,3,3]    (   73728) (    )
# detector.rpn_head.conv.2.weight                   : [120,512,1,1]   (   61440) (    )
# detector.features.2.weight                        : [64,64,3,3]     (   36864) (    )
# union_boxes.conv.0.weight                         : [256,2,7,7]     (   25088) (grad)
# detector.features.0.weight                        : [64,3,3,3]      (    1728) (    )
# union_boxes.conv.6.weight                         : [512]           (     512) (grad)
# union_boxes.conv.2.weight                         : [256]           (     256) (grad)

# %%
def get_optim(lr):
    # Lower the learning rate on the VGG fully connected layers by 1/10th. It's a hack, but it helps
    # stabilize the models.
    fc_params = [p for n,p in detector.named_parameters() if n.startswith('roi_fmap') and p.requires_grad]
    non_fc_params = [p for n,p in detector.named_parameters() if not n.startswith('roi_fmap') and p.requires_grad]
    params = [{'params': fc_params, 'lr': lr / 10.0}, {'params': non_fc_params}]
    # params = [p for n,p in detector.named_parameters() if p.requires_grad]

    if conf.adam:
        optimizer = optim.Adam(params, weight_decay=conf.adamwd, lr=lr, eps=1e-3)
    else:
        optimizer = optim.SGD(params, weight_decay=conf.l2, lr=lr, momentum=0.9)

    # scheduler = ReduceLROnPlateau(optimizer, 'max', patience=3, factor=0.1,
    #                               verbose=True, threshold=0.0001, threshold_mode='abs', cooldown=1)
    return optimizer #, scheduler

# %%
ckpt = torch.load(conf.ckpt)

# %%
if conf.ckpt.split('-')[-2].split('/')[-1] == 'vgrel':
    print("Loading EVERYTHING")
    start_epoch = ckpt['epoch']

    if not optimistic_restore(detector, ckpt['state_dict']):
        start_epoch = -1
        # optimistic_restore(detector.detector, torch.load('checkpoints/vgdet/vg-28.tar')['state_dict'])
else:
    start_epoch = -1
    optimistic_restore(detector.detector, ckpt['state_dict'])

    detector.roi_fmap[1][0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap[1][3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap[1][0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap[1][3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

    detector.roi_fmap_obj[0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap_obj[3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap_obj[0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap_obj[3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

# %%
detector.cuda();

# %%
def train_epoch(epoch_num):
    detector.train()
    tr = []
    start = time.time()
    for b, batch in enumerate(train_loader):
        result, loss_pd = train_batch(batch, verbose=b % (conf.print_interval*10) == 0)
        tr.append(loss_pd)
        '''
        if epoch_num == 1 and b % 1000 == 0:
            print('\n\n\n\n-------------------------------------------------------------------\n\n\n\n')
            print(detector.ggnn_rel_reason.ggnn.debug_info)        
        '''
        if b % conf.print_interval == 0 and b >= conf.print_interval:
            mn = pd.concat(tr[-conf.print_interval:], axis=1).mean(1)
            time_per_batch = (time.time() - start) / conf.print_interval
            print("\ne{:2d}b{:5d}/{:5d} {:.3f}s/batch, {:.1f}m/epoch".format(
                epoch_num, b, len(train_loader), time_per_batch, len(train_loader) * time_per_batch / 60))
            print(mn)
            print('-----------', flush=True)
            start = time.time()
    return pd.concat(tr, axis=1)

# %%
def train_batch(b, verbose=False):
    """
    :param b: contains:
          :param imgs: the image, [batch_size, 3, IM_SIZE, IM_SIZE]
          :param all_anchors: [num_anchors, 4] the boxes of all anchors that we'll be using
          :param all_anchor_inds: [num_anchors, 2] array of the indices into the concatenated
                                  RPN feature vector that give us all_anchors,
                                  each one (img_ind, fpn_idx)
          :param im_sizes: a [batch_size, 4] numpy array of (h, w, scale, num_good_anchors) for each image.

          :param num_anchors_per_img: int, number of anchors in total over the feature pyramid per img

          Training parameters:
          :param train_anchor_inds: a [num_train, 5] array of indices for the anchors that will
                                    be used to compute the training loss (img_ind, fpn_idx)
          :param gt_boxes: [num_gt, 4] GT boxes over the batch.
          :param gt_classes: [num_gt, 2] gt boxes where each one is (img_id, class)
    :return:
    """
    result = detector[b]

    losses = {}
    losses['class_loss'] = detector.obj_loss(result)
    losses['rel_loss'] = detector.rel_loss(result)
    loss = sum(losses.values())

    optimizer.zero_grad()
    loss.backward()
    clip_grad_norm(
        [(n, p) for n, p in detector.named_parameters() if p.grad is not None],
        max_norm=conf.clip, verbose=verbose, clip=True)
    losses['total'] = loss
    optimizer.step()
    loss_pd = pd.Series({x: y.data[0] for x, y in losses.items()})
    return result, loss_pd

# %%
def val_epoch():
    detector.eval()
    evaluator_list = [] # for calculating recall of each relationship except no relationship
    evaluator_multiple_preds_list = []
    for index, name in enumerate(ind_to_predicates):
        if index == 0:
            continue
        evaluator_list.append((index, name, BasicSceneGraphEvaluator.all_modes()))
        evaluator_multiple_preds_list.append((index, name, BasicSceneGraphEvaluator.all_modes(multiple_preds=True)))
    evaluator = BasicSceneGraphEvaluator.all_modes() # for calculating recall
    evaluator_multiple_preds = BasicSceneGraphEvaluator.all_modes(multiple_preds=True)
    for val_b, batch in enumerate(val_loader):
        val_batch(conf.num_gpus * val_b, batch, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list)

    recall = evaluator[conf.mode].print_stats()
    recall_mp = evaluator_multiple_preds[conf.mode].print_stats()
    
    mean_recall = calculate_mR_from_evaluator_list(evaluator_list, conf.mode)
    mean_recall_mp = calculate_mR_from_evaluator_list(evaluator_multiple_preds_list, conf.mode, multiple_preds=True)
    
    detector.train()
    return recall, recall_mp, mean_recall, mean_recall_mp

# %%
def val_batch(batch_num, b, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list):
    det_res = detector[b]
    if conf.num_gpus == 1:
        det_res = [det_res]

    for i, (boxes_i, objs_i, obj_scores_i, rels_i, pred_scores_i) in enumerate(det_res):
        gt_entry = {
            'gt_classes': val.gt_classes[batch_num + i].copy(),
            'gt_relations': val.relationships[batch_num + i].copy(),
            'gt_boxes': val.gt_boxes[batch_num + i].copy(),
        }
        assert np.all(objs_i[rels_i[:, 0]] > 0) and np.all(objs_i[rels_i[:, 1]] > 0)

        pred_entry = {
            'pred_boxes': boxes_i * BOX_SCALE/IM_SCALE,
            'pred_classes': objs_i,
            'pred_rel_inds': rels_i,
            'obj_scores': obj_scores_i,
            'rel_scores': pred_scores_i,  # hack for now.
        }

        eval_entry(conf.mode, gt_entry, pred_entry, evaluator, evaluator_multiple_preds, 
                   evaluator_list, evaluator_multiple_preds_list)

# %%
if conf.tb_log_dir is not None:
    from tensorboardX import SummaryWriter
    if not os.path.exists(conf.tb_log_dir):
        os.makedirs(conf.tb_log_dir) 
    writer = SummaryWriter(log_dir=conf.tb_log_dir)
    use_tb = True
else:
    use_tb = False

# %%
optimizer = get_optim(conf.lr * conf.num_gpus * conf.batch_size)

# %%
print("Training starts now!")

for epoch in range(1, 6):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 3.256 clip coef 1.536-----------------
# ggnn_rel_reason.rel_proj.weight                   : 1.700, (torch.Size([1024, 4096]))
# roi_fmap.1.3.weight                               : 1.010, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.985, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.953, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.846, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.788, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.769, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.701, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.618, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.574, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.454, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.430, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.430, (torch.Size([1024]))
# roi_fmap.1.0.weight                               : 0.408, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.395, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.354, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.302, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.290, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.290, (torch.Size([1024]))
# union_boxes.conv.4.weight                         : 0.235, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.225, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.224, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.219, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.203, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.169, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.133, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.131, (torch.Size([1024, 768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.111, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.108, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.088, (torch.Size([768, 768]))
# roi_fmap_obj.3.weight                             : 0.082, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.081, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.066, (torch.Size([256, 2, 7, 7]))
# roi_fmap.1.3.bias                                 : 0.064, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.062, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.060, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.060, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.059, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.055, (torch.Size([512, 1024]))
# roi_fmap_obj.0.weight                             : 0.043, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.041, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.034, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.034, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.031, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.028, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.028, (torch.Size([256]))
# union_boxes.conv.6.bias                           : 0.028, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.025, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.025, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.018, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.018, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.017, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.016, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.016, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.011, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.009, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.006, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.006, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.006, (torch.Size([1024, 3328]))
# roi_fmap.1.0.bias                                 : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.005, (torch.Size([768, 768]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.004, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.002, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.002, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.000, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b 1000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.238764
# total         0.238764
# dtype: float64
# -----------
#
# e 1b 2000/14430 0.372s/batch, 89.3m/epoch
# class_loss    0.000000
# rel_loss      0.188516
# total         0.188516
# dtype: float64
# -----------
#
# e 1b 3000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.179835
# total         0.179835
# dtype: float64
# -----------
#
# e 1b 4000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.173131
# total         0.173131
# dtype: float64
# -----------
#
# e 1b 5000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.164089
# total         0.164089
# dtype: float64
# -----------
#
# e 1b 6000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.159634
# total         0.159634
# dtype: float64
# -----------
#
# e 1b 7000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.156527
# total         0.156527
# dtype: float64
# -----------
#
# e 1b 8000/14430 0.379s/batch, 91.1m/epoch
# class_loss    0.00000
# rel_loss      0.15696
# total         0.15696
# dtype: float64
# -----------
#
# e 1b 9000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.154752
# total         0.154752
# dtype: float64
# -----------
# ---Total norm 0.434 clip coef 11.514-----------------
# roi_fmap.1.0.weight                               : 0.280, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.143, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.142, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.112, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.081, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.072, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.065, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.064, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.063, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.059, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.057, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.051, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.045, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.044, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.041, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.039, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.036, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.034, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.032, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.027, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.026, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.024, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.022, (torch.Size([1024, 768]))
# union_boxes.conv.0.weight                         : 0.022, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.019, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.019, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.018, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.016, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.014, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.009, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.007, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.006, (torch.Size([768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.005, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.005, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.004, (torch.Size([256]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.003, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.003, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b10000/14430 0.376s/batch, 90.5m/epoch
# class_loss    0.00000
# rel_loss      0.15386
# total         0.15386
# dtype: float64
# -----------
#
# e 1b11000/14430 0.376s/batch, 90.5m/epoch
# class_loss    0.000000
# rel_loss      0.152025
# total         0.152025
# dtype: float64
# -----------
#
# e 1b12000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.151985
# total         0.151985
# dtype: float64
# -----------
#
# e 1b13000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.147822
# total         0.147822
# dtype: float64
# -----------
#
# e 1b14000/14430 0.375s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.150106
# total         0.150106
# dtype: float64
# -----------
# overall 1: (0.166)
# class_loss    0.000000
# rel_loss      0.166098
# total         0.166098
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.584203
# R@50: 0.638912
# R@100: 0.653303
# ======================predcls  recall without constraint============================
# R@20: 0.671893
# R@50: 0.803274
# R@100: 0.877017
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.08861524852154375
# mR@50:  0.10955281109602127
# mR@100:  0.11670452217840303
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.1455262331794871
# mR@50:  0.2610298431837677
# mR@100:  0.396512618998348
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---Total norm 0.558 clip coef 8.960-----------------
# roi_fmap.1.0.weight                               : 0.330, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.274, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.222, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.110, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.087, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.075, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.072, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.068, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.058, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.053, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.049, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.048, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.047, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.044, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.043, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.042, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.038, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.036, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.034, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.033, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.030, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.029, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.027, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.026, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.024, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.021, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.018, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.015, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.013, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.013, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.012, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.011, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.008, (torch.Size([256]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.007, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# roi_fmap_obj.3.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.005, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.004, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.003, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b 1000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.147968
# total         0.147968
# dtype: float64
# -----------
#
# e 2b 2000/14430 0.376s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.143657
# total         0.143657
# dtype: float64
# -----------
#
# e 2b 3000/14430 0.374s/batch, 90.1m/epoch
# class_loss    0.00000
# rel_loss      0.14775
# total         0.14775
# dtype: float64
# -----------
#
# e 2b 4000/14430 0.377s/batch, 90.7m/epoch
# class_loss    0.000000
# rel_loss      0.144255
# total         0.144255
# dtype: float64
# -----------
#
# e 2b 5000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.148167
# total         0.148167
# dtype: float64
# -----------
#
# e 2b 6000/14430 0.374s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.142737
# total         0.142737
# dtype: float64
# -----------
#
# e 2b 7000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.144324
# total         0.144324
# dtype: float64
# -----------
#
# e 2b 8000/14430 0.376s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.144529
# total         0.144529
# dtype: float64
# -----------
#
# e 2b 9000/14430 0.372s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.146181
# total         0.146181
# dtype: float64
# -----------
# ---Total norm 0.557 clip coef 8.978-----------------
# roi_fmap.1.0.weight                               : 0.417, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.156, (torch.Size([4096, 4096]))
# roi_fmap_obj.0.weight                             : 0.149, (torch.Size([4096, 25088]))
# roi_fmap.1.3.weight                               : 0.138, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.075, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.075, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.072, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.072, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.071, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.068, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.067, (torch.Size([1024, 768]))
# ggnn_rel_reason.rel_proj.weight                   : 0.065, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.063, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.050, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.048, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.047, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.040, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.039, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.038, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.035, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.034, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.027, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.026, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.023, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.022, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.021, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.021, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.020, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.018, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.013, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.011, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.009, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.009, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.008, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.008, (torch.Size([1024, 3328]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.003, (torch.Size([768]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b10000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.146367
# total         0.146367
# dtype: float64
# -----------
#
# e 2b11000/14430 0.375s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.144909
# total         0.144909
# dtype: float64
# -----------
#
# e 2b12000/14430 0.375s/batch, 90.2m/epoch
# class_loss    0.000000
# rel_loss      0.143666
# total         0.143666
# dtype: float64
# -----------
#
# e 2b13000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.143071
# total         0.143071
# dtype: float64
# -----------
#
# e 2b14000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.140331
# total         0.140331
# dtype: float64
# -----------
# overall 2: (0.145)
# class_loss    0.000000
# rel_loss      0.144873
# total         0.144873
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.612673
# R@50: 0.659839
# R@100: 0.674707
# ======================predcls  recall without constraint============================
# R@20: 0.702904
# R@50: 0.823444
# R@100: 0.888798
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.12344814720689187
# mR@50:  0.14656793417445907
# mR@100:  0.15508028644911678
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.19952418159236637
# mR@50:  0.3411593186466513
# mR@100:  0.4513104694398035
# ---Total norm 0.323 clip coef 15.487-----------------
# roi_fmap.1.0.weight                               : 0.177, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.115, (torch.Size([4096, 4096]))
# roi_fmap_obj.0.weight                             : 0.108, (torch.Size([4096, 25088]))
# roi_fmap.1.3.weight                               : 0.089, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.064, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.060, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.059, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.053, (torch.Size([1024, 768]))
# ggnn_rel_reason.obj_proj.weight                   : 0.052, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.050, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.038, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.037, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.034, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.028, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.027, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.023, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.022, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.017, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.016, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.015, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.014, (torch.Size([1024, 768]))
# ...
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.002, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 5b 1000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.134634
# total         0.134634
# dtype: float64
# -----------
#
# e 5b 2000/14430 0.373s/batch, 89.7m/epoch
# class_loss    0.000000
# rel_loss      0.135271
# total         0.135271
# dtype: float64
# -----------
#
# e 5b 3000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.136378
# total         0.136378
# dtype: float64
# -----------
#
# e 5b 4000/14430 0.373s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.133477
# total         0.133477
# dtype: float64
# -----------
#
# e 5b 5000/14430 0.372s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.136678
# total         0.136678
# dtype: float64
# -----------
#
# e 5b 6000/14430 0.373s/batch, 89.7m/epoch
# class_loss    0.000000
# rel_loss      0.136921
# total         0.136921
# dtype: float64
# -----------
#
# e 5b 7000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.133299
# total         0.133299
# dtype: float64
# -----------
#
# e 5b 8000/14430 0.371s/batch, 89.2m/epoch
# class_loss    0.000000
# rel_loss      0.135084
# total         0.135084
# dtype: float64
# -----------
#
# e 5b 9000/14430 0.376s/batch, 90.4m/epoch
# class_loss    0.000000
# rel_loss      0.132029
# total         0.132029
# dtype: float64
# -----------
# ---Total norm 0.296 clip coef 16.912-----------------
# roi_fmap.1.0.weight                               : 0.213, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.109, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.101, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.066, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.041, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.034, (torch.Size([1024, 768]))
# ggnn_rel_reason.obj_proj.weight                   : 0.034, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.033, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.030, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.025, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.025, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.020, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.019, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.019, (torch.Size([1024]))
# union_boxes.conv.4.weight                         : 0.017, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.015, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.014, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.014, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.012, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.011, (torch.Size([1024, 768]))
# union_boxes.conv.0.weight                         : 0.011, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.011, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.009, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.008, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.006, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.005, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.003, (torch.Size([3328, 3328]))
# union_boxes.conv.6.bias                           : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.002, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.002, (torch.Size([768]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.000, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 5b10000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.136158
# total         0.136158
# dtype: float64
# -----------
#
# e 5b11000/14430 0.372s/batch, 89.4m/epoch
# class_loss    0.000000
# rel_loss      0.138093
# total         0.138093
# dtype: float64
# -----------
#
# e 5b12000/14430 0.373s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.137682
# total         0.137682
# dtype: float64
# -----------
#
# e 5b13000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.136095
# total         0.136095
# dtype: float64
# -----------
#
# e 5b14000/14430 0.376s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.135118
# total         0.135118
# dtype: float64
# -----------
# overall 5: (0.136)
# class_loss    0.000000
# rel_loss      0.135524
# total         0.135524
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.623506
# R@50: 0.670666
# R@100: 0.684383
# ======================predcls  recall without constraint============================
# R@20: 0.716900
# R@50: 0.836026
# R@100: 0.902672
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.12982500679270048
# mR@50:  0.15327613752574773
# mR@100:  0.16382872973637305
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.22289636052339573
# mR@50:  0.37576557018096984
# mR@100:  0.5244961254635024

# %%
for param_group in optimizer.param_groups:
    param_group['lr'] /= 10

# %%
print("Training starts now!")

for epoch in range(6, 11):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 0.895 clip coef 5.589-----------------
# roi_fmap.1.0.weight                               : 0.647, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.302, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.283, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.206, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.129, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.119, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.112, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.103, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.103, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.097, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.096, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.092, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.082, (torch.Size([256, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.081, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.071, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.070, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.067, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.058, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.057, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.057, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.057, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.056, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.054, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.051, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.049, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.047, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.043, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.036, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.034, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.033, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.031, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.028, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.024, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.023, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.022, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.022, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.022, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.016, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.015, (torch.Size([768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.013, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.013, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.012, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.011, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.011, (torch.Size([256]))
# union_boxes.conv.6.bias                           : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.008, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.007, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.006, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.005, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.003, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 6b 1000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.132004
# total         0.132004
# dtype: float64
# -----------
#
# e 6b 2000/14430 0.372s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.132564
# total         0.132564
# dtype: float64
# -----------
#
# e 6b 3000/14430 0.371s/batch, 89.3m/epoch
# class_loss    0.000000
# rel_loss      0.132053
# total         0.132053
# dtype: float64
# -----------
#
# e 6b 4000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.128117
# total         0.128117
# dtype: float64
# -----------
#
# e 6b 5000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.129274
# total         0.129274
# dtype: float64
# -----------
#
# e 6b 6000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.128121
# total         0.128121
# dtype: float64
# -----------
#
# e 6b 7000/14430 0.375s/batch, 90.2m/epoch
# class_loss    0.000000
# rel_loss      0.127871
# total         0.127871
# dtype: float64
# -----------
#
# e 6b 8000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.128958
# total         0.128958
# dtype: float64
# -----------
#
# e 6b 9000/14430 0.371s/batch, 89.3m/epoch
# class_loss    0.000000
# rel_loss      0.130989
# total         0.130989
# dtype: float64
# -----------
# ---Total norm 1.346 clip coef 3.716-----------------
# roi_fmap.1.0.weight                               : 0.940, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.555, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.486, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.306, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.198, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.173, (torch.Size([1024, 768]))
# ggnn_rel_reason.obj_proj.weight                   : 0.167, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.144, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.132, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.129, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.121, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.110, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.108, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.107, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.096, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.094, (torch.Size([1024, 300]))
# union_boxes.conv.4.weight                         : 0.085, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.074, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.064, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.064, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.063, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.055, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.053, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.052, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.052, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.051, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.051, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.046, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.044, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.044, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.043, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.043, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.041, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.037, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.034, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.033, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.027, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.026, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.024, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.024, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.023, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.017, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.017, (torch.Size([512, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.016, (torch.Size([3328, 3328]))
# union_boxes.conv.6.bias                           : 0.015, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.014, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.013, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.013, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.011, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.010, (torch.Size([1024, 3328]))
# ggnn_rel_reason.obj_proj.bias                     : 0.009, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.007, (torch.Size([768]))
# roi_fmap.1.0.bias                                 : 0.007, (torch.Size([4096]))
# union_boxes.conv.0.bias                           : 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.005, (torch.Size([512]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.002, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 6b10000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.127428
# total         0.127428
# dtype: float64
# -----------
#
# e 6b11000/14430 0.375s/batch, 90.2m/epoch
# class_loss    0.000000
# rel_loss      0.126327
# total         0.126327
# dtype: float64
# -----------
#
# e 6b12000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.125896
# total         0.125896
# dtype: float64
# -----------
#
# e 6b13000/14430 0.373s/batch, 89.7m/epoch
# class_loss    0.000000
# rel_loss      0.128771
# total         0.128771
# dtype: float64
# -----------
#
# e 6b14000/14430 0.374s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.126945
# total         0.126945
# dtype: float64
# -----------
# overall 6: (0.129)
# class_loss    0.000000
# rel_loss      0.128916
# total         0.128916
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.626078
# R@50: 0.674933
# R@100: 0.688280
# ======================predcls  recall without constraint============================
# R@20: 0.725066
# R@50: 0.843875
# R@100: 0.908334
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.14778485471258912
# mR@50:  0.17666681267191556
# mR@100:  0.1891162505827258
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.23482117474750613
# mR@50:  0.39183069258296677
# mR@100:  0.5399846247531523
# ---Total norm 0.395 clip coef 12.666-----------------
# roi_fmap.1.0.weight                               : 0.315, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.110, (torch.Size([4096, 25088]))
# roi_fmap.1.3.weight                               : 0.096, (torch.Size([4096, 4096]))
# roi_fmap_obj.3.weight                             : 0.094, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.052, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.047, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.044, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.040, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.038, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.038, (torch.Size([1024, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.036, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.032, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.030, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.028, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.026, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.025, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.024, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.020, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.020, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.020, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.018, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.013, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.013, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.012, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.012, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.011, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.011, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.009, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.008, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.008, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.007, (torch.Size([512]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.006, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.004, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.003, (torch.Size([768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.003, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.002, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.001, (torch.Size([1024, 3328]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.000, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 7b 1000/14430 0.375s/batch, 90.2m/epoch
# class_loss    0.00000
# rel_loss      0.12785
# total         0.12785
# dtype: float64
# -----------
#
# e 7b 2000/14430 0.373s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.126202
# total         0.126202
# dtype: float64
# -----------
#
# e 7b 3000/14430 0.373s/batch, 89.7m/epoch
# class_loss    0.000000
# rel_loss      0.128044
# total         0.128044
# dtype: float64
# -----------
#
# e 7b 4000/14430 0.374s/batch, 89.8m/epoch
# class_loss    0.0000
# rel_loss      0.1285
# total         0.1285
# dtype: float64
# -----------
#
# e 7b 5000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.127126
# total         0.127126
# dtype: float64
# -----------
#
# e 7b 6000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.123752
# total         0.123752
# dtype: float64
# -----------
#
# e 7b 7000/14430 0.376s/batch, 90.3m/epoch
# class_loss    0.000000
# rel_loss      0.127542
# total         0.127542
# dtype: float64
# -----------
#
# e 7b 8000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.00000
# rel_loss      0.12736
# total         0.12736
# dtype: float64
# -----------
#
# e 7b 9000/14430 0.369s/batch, 88.8m/epoch
# class_loss    0.000000
# rel_loss      0.127265
# total         0.127265
# dtype: float64
# -----------
# ---Total norm 0.974 clip coef 5.132-----------------
# roi_fmap.1.0.weight                               : 0.740, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.322, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.292, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.231, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.135, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.121, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.115, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.109, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.105, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.099, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.097, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.093, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.083, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.076, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.073, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.067, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.067, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.064, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.053, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.047, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.045, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.044, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.042, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.040, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.039, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.036, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.034, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.034, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.032, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.029, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.028, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.024, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.017, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.017, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.016, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.016, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.014, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.013, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.011, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.010, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.009, (torch.Size([512, 1024]))
# union_boxes.conv.6.bias                           : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.009, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.009, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.008, (torch.Size([256, 512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.007, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.006, (torch.Size([256]))
# union_boxes.conv.0.bias                           : 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.006, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.001, (torch.Size([3328]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 7b10000/14430 0.374s/batch, 89.8m/epoch
# class_loss    0.000000
# rel_loss      0.126332
# total         0.126332
# dtype: float64
# -----------
#
# e 7b11000/14430 0.373s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.126156
# total         0.126156
# dtype: float64
# -----------
#
# e 7b12000/14430 0.374s/batch, 89.9m/epoch
# class_loss    0.000000
# rel_loss      0.128245
# total         0.128245
# dtype: float64
# -----------
#
# e 7b13000/14430 0.373s/batch, 89.6m/epoch
# class_loss    0.000000
# rel_loss      0.127608
# total         0.127608
# dtype: float64
# -----------
#
# e 7b14000/14430 0.371s/batch, 89.2m/epoch
# class_loss    0.000000
# rel_loss      0.127437
# total         0.127437
# dtype: float64
# -----------
# overall 7: (0.127)
# class_loss    0.000000
# rel_loss      0.127158
# total         0.127158
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.626218
# R@50: 0.674671
# R@100: 0.688453
# ======================predcls  recall without constraint============================
# R@20: 0.726418
# R@50: 0.845350
# R@100: 0.909670
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.15092023221520282
# mR@50:  0.18888279496592875
# mR@100:  0.19804626691963084
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.2411272588050899
# mR@50:  0.407112279860033
# mR@100:  0.5443774045350084
# ---Total norm 0.845 clip coef 5.918-----------------
# roi_fmap.1.0.weight                               : 0.624, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.355, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.266, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.180, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.103, (torch.Size([768, 768]))
# ggnn_rel_reason.obj_proj.weight                   : 0.089, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.086, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.084, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.077, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.076, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.072, (torch.Size([256, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.070, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.067, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.061, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.057, (torch.Size([768, 768]))
# union_boxes.conv.4.weight                         : 0.055, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.055, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.049, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.048, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.047, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.042, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.041, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.039, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.035, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.034, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.032, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.031, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.025, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.020, (torch.Size([1024]))
# ...
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.003, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.000, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e10b 1000/14430 0.376s/batch, 90.5m/epoch
# class_loss    0.000000
# rel_loss      0.125895
# total         0.125895
# dtype: float64
# -----------
#
# e10b 2000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.123777
# total         0.123777
# dtype: float64
# -----------
#
# e10b 3000/14430 0.376s/batch, 90.5m/epoch
# class_loss    0.000000
# rel_loss      0.124203
# total         0.124203
# dtype: float64
# -----------
#
# e10b 4000/14430 0.375s/batch, 90.2m/epoch
# class_loss    0.000000
# rel_loss      0.124445
# total         0.124445
# dtype: float64
# -----------
#
# e10b 5000/14430 0.376s/batch, 90.4m/epoch
# class_loss    0.000000
# rel_loss      0.122097
# total         0.122097
# dtype: float64
# -----------
#
# e10b 6000/14430 0.377s/batch, 90.7m/epoch
# class_loss    0.000000
# rel_loss      0.122833
# total         0.122833
# dtype: float64
# -----------
#
# e10b 7000/14430 0.372s/batch, 89.5m/epoch
# class_loss    0.000000
# rel_loss      0.128177
# total         0.128177
# dtype: float64
# -----------
#
# e10b 8000/14430 0.376s/batch, 90.5m/epoch
# class_loss    0.00000
# rel_loss      0.12273
# total         0.12273
# dtype: float64
# -----------
#
# e10b 9000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.00000
# rel_loss      0.12719
# total         0.12719
# dtype: float64
# -----------
# ---Total norm 0.340 clip coef 14.687-----------------
# roi_fmap.1.0.weight                               : 0.260, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.110, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.104, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.079, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.047, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.040, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.038, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.035, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.034, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.029, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.025, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.025, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.022, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.021, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.019, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.017, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.016, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.015, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.014, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.014, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.013, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.011, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.009, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.009, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.009, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.008, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.007, (torch.Size([256, 512]))
# roi_fmap.1.3.bias                                 : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.rel_proj.bias                     : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.005, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.002, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.002, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.001, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.000, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e10b10000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.125535
# total         0.125535
# dtype: float64
# -----------
#
# e10b11000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.000000
# rel_loss      0.127121
# total         0.127121
# dtype: float64
# -----------
#
# e10b12000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.127315
# total         0.127315
# dtype: float64
# -----------
#
# e10b13000/14430 0.374s/batch, 90.0m/epoch
# class_loss    0.000000
# rel_loss      0.128368
# total         0.128368
# dtype: float64
# -----------
#
# e10b14000/14430 0.375s/batch, 90.1m/epoch
# class_loss    0.00000
# rel_loss      0.12439
# total         0.12439
# dtype: float64
# -----------
# overall10: (0.125)
# class_loss    0.00000
# rel_loss      0.12525
# total         0.12525
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.625335
# R@50: 0.673983
# R@100: 0.687787
# ======================predcls  recall without constraint============================
# R@20: 0.727887
# R@50: 0.844480
# R@100: 0.907609
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.16376497917284535
# mR@50:  0.19798383388284985
# mR@100:  0.20761024153798285
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.26625451398826405
# mR@50:  0.4184295196543556
# mR@100:  0.5482664785838265
