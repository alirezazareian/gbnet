# %%
import numpy as np
np.random.seed(1234)
import torch
torch.manual_seed(1235)
torch.__version__
# Out:
# '0.3.0.post4'

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
codebase = '../../'
sys.path.append(codebase)

# %%
exp_name = 'exp_134'
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
from dataloaders.visual_genome import VGDataLoader, VG
import numpy as np
from torch import optim
import torch
import pandas as pd
import time
import os

from config import ModelConfig, BOX_SCALE, IM_SCALE
from torch.nn import functional as F
from lib.pytorch_misc import optimistic_restore, de_chunkize, clip_grad_norm
from lib.evaluation.sg_eval import BasicSceneGraphEvaluator, calculate_mR_from_evaluator_list, eval_entry
from lib.pytorch_misc import print_para
from torch.optim.lr_scheduler import ReduceLROnPlateau

from lib.my_model_33 import KERN

# %%
conf = ModelConfig(f'''
-m predcls -p 1000 -clip 5 
-tb_log_dir summaries/kern_predcls/{exp_name} 
-save_dir checkpoints/kern_predcls/{exp_name}
-ckpt checkpoints/vgdet/vg-24.tar 
-val_size 5000 
-adam 
-b 4
-ngpu 1
-lr 1e-4 
''')
# Out:
# ~~~~~~~~ Hyperparameters used: ~~~~~~~
# ckpt : checkpoints/vgdet/vg-24.tar
# save_dir : checkpoints/kern_predcls/exp_134
# num_gpus : 1
# num_workers : 1
# lr : 0.0001
# batch_size : 4
# val_size : 5000
# l2 : 0.0001
# adamwd : 0.0
# clip : 5.0
# print_interval : 1000
# mode : predcls
# cache :
# adam : True
# test : False
# num_epochs : 50
# use_resnet : False
# use_proposals : False
# pooling_dim : 4096
# use_ggnn_obj : False
# ggnn_obj_time_step_num : 3
# ggnn_obj_hidden_dim : 512
# ggnn_obj_output_dim : 512
# use_obj_knowledge : False
# obj_knowledge :
# use_ggnn_rel : False
# ggnn_rel_time_step_num : 3
# ggnn_rel_hidden_dim : 512
# ggnn_rel_output_dim : 512
# use_rel_knowledge : False
# rel_knowledge :
# tb_log_dir : summaries/kern_predcls/exp_134
# save_rel_recall :

# %%
train, val, _ = VG.splits(num_val_im=conf.val_size, filter_duplicate_rels=True,
                          use_proposals=conf.use_proposals,
                          filter_non_overlap=conf.mode == 'sgdet')

# %%
ind_to_predicates = train.ind_to_predicates # ind_to_predicates[0] means no relationship

# %%
train_loader, val_loader = VGDataLoader.splits(train, val, mode='rel',
                                               batch_size=conf.batch_size,
                                               num_workers=conf.num_workers,
                                               num_gpus=conf.num_gpus)

# %%
detector = KERN(classes=train.ind_to_classes, rel_classes=train.ind_to_predicates,
                num_gpus=conf.num_gpus, mode=conf.mode, require_overlap_det=True,
                use_resnet=conf.use_resnet, use_proposals=conf.use_proposals, pooling_dim=conf.pooling_dim,
                ggnn_rel_time_step_num=1, ggnn_rel_hidden_dim=1024, ggnn_rel_output_dim=None,
                graph_path=os.path.join(codebase, 'graphs/005/all_edges.pkl'), 
                emb_path=os.path.join(codebase, 'graphs/001/emb_mtx.pkl'), 
                rel_counts_path=os.path.join(codebase, 'graphs/001/pred_counts.pkl'), 
                use_knowledge=True, use_embedding=True, refine_obj_cls=False,
                class_volume=1.0, top_k_to_keep=5, normalize_messages=False,
               )

# %%
# Freeze the detector
for n, param in detector.detector.named_parameters():
    param.requires_grad = False

# %%
print(print_para(detector), flush=True)
# Out:
#  444.6M total parameters
#  -----
#
# detector.roi_fmap.0.weight                        : [4096,25088]    (102760448) (    )
# roi_fmap.1.0.weight                               : [4096,25088]    (102760448) (grad)
# roi_fmap_obj.0.weight                             : [4096,25088]    (102760448) (grad)
# detector.roi_fmap.3.weight                        : [4096,4096]     (16777216) (    )
# roi_fmap.1.3.weight                               : [4096,4096]     (16777216) (grad)
# roi_fmap_obj.3.weight                             : [4096,4096]     (16777216) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: [3328,3328]     (11075584) (grad)
# ggnn_rel_reason.obj_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.rel_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: [2048,2048]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: [1024,3328]     ( 3407872) (grad)
# detector.bbox_fc.weight                           : [604,4096]      ( 2473984) (    )
# detector.features.19.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.21.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.24.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.26.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.28.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.rpn_head.conv.0.weight                   : [512,512,3,3]   ( 2359296) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: [1024,2048]     ( 2097152) (grad)
# detector.features.17.weight                       : [512,256,3,3]   ( 1179648) (    )
# union_boxes.conv.4.weight                         : [512,256,3,3]   ( 1179648) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: [1024,768]      (  786432) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: [1024,768]      (  786432) (grad)
# detector.score_fc.weight                          : [151,4096]      (  618496) (    )
# detector.features.12.weight                       : [256,256,3,3]   (  589824) (    )
# detector.features.14.weight                       : [256,256,3,3]   (  589824) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : [1024,300]      (  307200) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : [1024,300]      (  307200) (grad)
# detector.features.10.weight                       : [256,128,3,3]   (  294912) (    )
# detector.features.7.weight                        : [128,128,3,3]   (  147456) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# detector.features.5.weight                        : [128,64,3,3]    (   73728) (    )
# detector.rpn_head.conv.2.weight                   : [120,512,1,1]   (   61440) (    )
# detector.features.2.weight                        : [64,64,3,3]     (   36864) (    )
# union_boxes.conv.0.weight                         : [256,2,7,7]     (   25088) (grad)
# detector.features.0.weight                        : [64,3,3,3]      (    1728) (    )
# union_boxes.conv.6.weight                         : [512]           (     512) (grad)
# union_boxes.conv.2.weight                         : [256]           (     256) (grad)

# %%
def get_optim(lr):
    # Lower the learning rate on the VGG fully connected layers by 1/10th. It's a hack, but it helps
    # stabilize the models.
    fc_params = [p for n,p in detector.named_parameters() if n.startswith('roi_fmap') and p.requires_grad]
    non_fc_params = [p for n,p in detector.named_parameters() if not n.startswith('roi_fmap') and p.requires_grad]
    params = [{'params': fc_params, 'lr': lr / 10.0}, {'params': non_fc_params}]
    # params = [p for n,p in detector.named_parameters() if p.requires_grad]

    if conf.adam:
        optimizer = optim.Adam(params, weight_decay=conf.adamwd, lr=lr, eps=1e-3)
    else:
        optimizer = optim.SGD(params, weight_decay=conf.l2, lr=lr, momentum=0.9)

    # scheduler = ReduceLROnPlateau(optimizer, 'max', patience=3, factor=0.1,
    #                               verbose=True, threshold=0.0001, threshold_mode='abs', cooldown=1)
    return optimizer #, scheduler

# %%
ckpt = torch.load(conf.ckpt)

# %%
if conf.ckpt.split('-')[-2].split('/')[-1] == 'vgrel':
    print("Loading EVERYTHING")
    start_epoch = ckpt['epoch']

    if not optimistic_restore(detector, ckpt['state_dict']):
        start_epoch = -1
        # optimistic_restore(detector.detector, torch.load('checkpoints/vgdet/vg-28.tar')['state_dict'])
else:
    start_epoch = -1
    optimistic_restore(detector.detector, ckpt['state_dict'])

    detector.roi_fmap[1][0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap[1][3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap[1][0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap[1][3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

    detector.roi_fmap_obj[0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap_obj[3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap_obj[0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap_obj[3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

# %%
detector.cuda();

# %%
def train_epoch(epoch_num):
    detector.train()
    tr = []
    start = time.time()
    for b, batch in enumerate(train_loader):
        result, loss_pd = train_batch(batch, verbose=b % (conf.print_interval*10) == 0)
        tr.append(loss_pd)
        '''
        if epoch_num == 1 and b % 1000 == 0:
            print('\n\n\n\n-------------------------------------------------------------------\n\n\n\n')
            print(detector.ggnn_rel_reason.ggnn.debug_info)        
        '''
        if b % conf.print_interval == 0 and b >= conf.print_interval:
            mn = pd.concat(tr[-conf.print_interval:], axis=1).mean(1)
            time_per_batch = (time.time() - start) / conf.print_interval
            print("\ne{:2d}b{:5d}/{:5d} {:.3f}s/batch, {:.1f}m/epoch".format(
                epoch_num, b, len(train_loader), time_per_batch, len(train_loader) * time_per_batch / 60))
            print(mn)
            print('-----------', flush=True)
            start = time.time()
    return pd.concat(tr, axis=1)

# %%
def train_batch(b, verbose=False):
    """
    :param b: contains:
          :param imgs: the image, [batch_size, 3, IM_SIZE, IM_SIZE]
          :param all_anchors: [num_anchors, 4] the boxes of all anchors that we'll be using
          :param all_anchor_inds: [num_anchors, 2] array of the indices into the concatenated
                                  RPN feature vector that give us all_anchors,
                                  each one (img_ind, fpn_idx)
          :param im_sizes: a [batch_size, 4] numpy array of (h, w, scale, num_good_anchors) for each image.

          :param num_anchors_per_img: int, number of anchors in total over the feature pyramid per img

          Training parameters:
          :param train_anchor_inds: a [num_train, 5] array of indices for the anchors that will
                                    be used to compute the training loss (img_ind, fpn_idx)
          :param gt_boxes: [num_gt, 4] GT boxes over the batch.
          :param gt_classes: [num_gt, 2] gt boxes where each one is (img_id, class)
    :return:
    """
    result = detector[b]

    losses = {}
    losses['class_loss'] = detector.obj_loss(result)
    losses['rel_loss'] = detector.rel_loss(result)
    loss = sum(losses.values())

    optimizer.zero_grad()
    loss.backward()
    clip_grad_norm(
        [(n, p) for n, p in detector.named_parameters() if p.grad is not None],
        max_norm=conf.clip, verbose=verbose, clip=True)
    losses['total'] = loss
    optimizer.step()
    loss_pd = pd.Series({x: y.data[0] for x, y in losses.items()})
    return result, loss_pd

# %%
def val_epoch():
    detector.eval()
    evaluator_list = [] # for calculating recall of each relationship except no relationship
    evaluator_multiple_preds_list = []
    for index, name in enumerate(ind_to_predicates):
        if index == 0:
            continue
        evaluator_list.append((index, name, BasicSceneGraphEvaluator.all_modes()))
        evaluator_multiple_preds_list.append((index, name, BasicSceneGraphEvaluator.all_modes(multiple_preds=True)))
    evaluator = BasicSceneGraphEvaluator.all_modes() # for calculating recall
    evaluator_multiple_preds = BasicSceneGraphEvaluator.all_modes(multiple_preds=True)
    for val_b, batch in enumerate(val_loader):
        val_batch(conf.num_gpus * val_b, batch, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list)

    recall = evaluator[conf.mode].print_stats()
    recall_mp = evaluator_multiple_preds[conf.mode].print_stats()
    
    mean_recall = calculate_mR_from_evaluator_list(evaluator_list, conf.mode)
    mean_recall_mp = calculate_mR_from_evaluator_list(evaluator_multiple_preds_list, conf.mode, multiple_preds=True)
    
    detector.train()
    return recall, recall_mp, mean_recall, mean_recall_mp

# %%
def val_batch(batch_num, b, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list):
    det_res = detector[b]
    if conf.num_gpus == 1:
        det_res = [det_res]

    for i, (boxes_i, objs_i, obj_scores_i, rels_i, pred_scores_i) in enumerate(det_res):
        gt_entry = {
            'gt_classes': val.gt_classes[batch_num + i].copy(),
            'gt_relations': val.relationships[batch_num + i].copy(),
            'gt_boxes': val.gt_boxes[batch_num + i].copy(),
        }
        assert np.all(objs_i[rels_i[:, 0]] > 0) and np.all(objs_i[rels_i[:, 1]] > 0)

        pred_entry = {
            'pred_boxes': boxes_i * BOX_SCALE/IM_SCALE,
            'pred_classes': objs_i,
            'pred_rel_inds': rels_i,
            'obj_scores': obj_scores_i,
            'rel_scores': pred_scores_i,  # hack for now.
        }

        eval_entry(conf.mode, gt_entry, pred_entry, evaluator, evaluator_multiple_preds, 
                   evaluator_list, evaluator_multiple_preds_list)

# %%
if conf.tb_log_dir is not None:
    from tensorboardX import SummaryWriter
    if not os.path.exists(conf.tb_log_dir):
        os.makedirs(conf.tb_log_dir) 
    writer = SummaryWriter(log_dir=conf.tb_log_dir)
    use_tb = True
else:
    use_tb = False

# %%
optimizer = get_optim(conf.lr * conf.num_gpus * conf.batch_size)

# %%
print("Training starts now!")

for epoch in range(1, 6):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 8.926 clip coef 0.560-----------------
# ggnn_rel_reason.rel_proj.weight                   : 5.659, (torch.Size([1024, 4096]))
# roi_fmap.1.3.weight                               : 3.360, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 2.709, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 2.511, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 2.344, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 2.079, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 1.771, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 1.370, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 1.291, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 1.115, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.954, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.806, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.797, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.712, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.511, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.492, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.492, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.487, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.485, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.369, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.352, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.352, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.308, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.280, (torch.Size([2048, 2048]))
# ggnn_rel_reason.obj_proj.weight                   : 0.250, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.239, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.229, (torch.Size([2048]))
# union_boxes.conv.0.weight                         : 0.215, (torch.Size([256, 2, 7, 7]))
# roi_fmap.1.3.bias                                 : 0.214, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.213, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.160, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.weight                             : 0.159, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.150, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.149, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.128, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.097, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.089, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.085, (torch.Size([256, 512]))
# roi_fmap_obj.0.weight                             : 0.084, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.082, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.074, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.072, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.062, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.050, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.046, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.040, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.038, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.038, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.038, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.034, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.027, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.027, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.027, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.026, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.026, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.023, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.021, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.020, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.017, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.017, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.016, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.016, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.014, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.013, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.011, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.007, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.006, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 1b 1000/14430 0.340s/batch, 81.8m/epoch
# class_loss    0.000000
# rel_loss      0.224468
# total         0.224468
# dtype: float64
# -----------
#
# e 1b 2000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.190342
# total         0.190342
# dtype: float64
# -----------
#
# e 1b 3000/14430 0.339s/batch, 81.5m/epoch
# class_loss    0.000000
# rel_loss      0.183316
# total         0.183316
# dtype: float64
# -----------
#
# e 1b 4000/14430 0.338s/batch, 81.3m/epoch
# class_loss    0.000000
# rel_loss      0.178121
# total         0.178121
# dtype: float64
# -----------
#
# e 1b 5000/14430 0.341s/batch, 82.0m/epoch
# class_loss    0.000000
# rel_loss      0.170856
# total         0.170856
# dtype: float64
# -----------
#
# e 1b 6000/14430 0.342s/batch, 82.3m/epoch
# class_loss    0.000000
# rel_loss      0.167157
# total         0.167157
# dtype: float64
# -----------
#
# e 1b 7000/14430 0.341s/batch, 82.1m/epoch
# class_loss    0.000000
# rel_loss      0.164822
# total         0.164822
# dtype: float64
# -----------
#
# e 1b 8000/14430 0.346s/batch, 83.2m/epoch
# class_loss    0.00000
# rel_loss      0.16718
# total         0.16718
# dtype: float64
# -----------
#
# e 1b 9000/14430 0.341s/batch, 82.1m/epoch
# class_loss    0.000000
# rel_loss      0.164947
# total         0.164947
# dtype: float64
# -----------
# ---Total norm 0.550 clip coef 9.098-----------------
# roi_fmap.1.0.weight                               : 0.341, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.280, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.207, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.123, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.095, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.072, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.070, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.068, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.056, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.055, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.051, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.045, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.041, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.039, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.035, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.032, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.028, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.027, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.022, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.008, (torch.Size([2048, 2048]))
# ggnn_rel_reason.rel_proj.bias                     : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.007, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.006, (torch.Size([2048]))
# roi_fmap.1.3.bias                                 : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.004, (torch.Size([1024, 300]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.001, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 1b10000/14430 0.342s/batch, 82.3m/epoch
# class_loss    0.000000
# rel_loss      0.164484
# total         0.164484
# dtype: float64
# -----------
#
# e 1b11000/14430 0.343s/batch, 82.4m/epoch
# class_loss    0.000000
# rel_loss      0.162659
# total         0.162659
# dtype: float64
# -----------
#
# e 1b12000/14430 0.343s/batch, 82.6m/epoch
# class_loss    0.000000
# rel_loss      0.162185
# total         0.162185
# dtype: float64
# -----------
#
# e 1b13000/14430 0.339s/batch, 81.5m/epoch
# class_loss    0.000000
# rel_loss      0.158362
# total         0.158362
# dtype: float64
# -----------
#
# e 1b14000/14430 0.341s/batch, 82.0m/epoch
# class_loss    0.000000
# rel_loss      0.161157
# total         0.161157
# dtype: float64
# -----------
# overall 1: (0.173)
# class_loss    0.000000
# rel_loss      0.172809
# total         0.172809
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.551304
# R@50: 0.608459
# R@100: 0.625435
# ======================predcls  recall without constraint============================
# R@20: 0.632519
# R@50: 0.774281
# R@100: 0.851982
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.08039830652564559
# mR@50:  0.09881629577965328
# mR@100:  0.1067861825357114
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.12992572445953293
# mR@50:  0.2384577917839438
# mR@100:  0.3415651244401293
# /home/alireza/home_at_filer2/tools/anaconda3/envs/kern/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/home_at_filer2/tools/anaconda3/envs/kern/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---Total norm 0.537 clip coef 9.307-----------------
# roi_fmap.1.0.weight                               : 0.362, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.233, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.165, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.122, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.088, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.080, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.073, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.067, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.065, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.060, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.056, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.052, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.050, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.040, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.039, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.038, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.034, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.033, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.033, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.031, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.025, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.025, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.025, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.014, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.013, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.013, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.011, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.008, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.007, (torch.Size([512, 1024]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.006, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.006, (torch.Size([768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.005, (torch.Size([1024, 300]))
# roi_fmap_obj.3.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.004, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.002, (torch.Size([512]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 2b 1000/14430 0.356s/batch, 85.6m/epoch
# class_loss    0.000000
# rel_loss      0.158742
# total         0.158742
# dtype: float64
# -----------
#
# e 2b 2000/14430 0.340s/batch, 81.8m/epoch
# class_loss    0.000000
# rel_loss      0.154396
# total         0.154396
# dtype: float64
# -----------
#
# e 2b 3000/14430 0.346s/batch, 83.2m/epoch
# class_loss    0.000000
# rel_loss      0.159943
# total         0.159943
# dtype: float64
# -----------
#
# e 2b 4000/14430 0.363s/batch, 87.2m/epoch
# class_loss    0.000000
# rel_loss      0.155028
# total         0.155028
# dtype: float64
# -----------
#
# e 2b 5000/14430 0.342s/batch, 82.3m/epoch
# class_loss    0.000000
# rel_loss      0.159471
# total         0.159471
# dtype: float64
# -----------
#
# e 2b 6000/14430 0.345s/batch, 82.9m/epoch
# class_loss    0.000000
# rel_loss      0.154383
# total         0.154383
# dtype: float64
# -----------
#
# e 2b 7000/14430 0.337s/batch, 81.0m/epoch
# class_loss    0.000000
# rel_loss      0.156013
# total         0.156013
# dtype: float64
# -----------
#
# e 2b 8000/14430 0.340s/batch, 81.8m/epoch
# class_loss    0.000000
# rel_loss      0.155944
# total         0.155944
# dtype: float64
# -----------
#
# e 2b 9000/14430 0.335s/batch, 80.6m/epoch
# class_loss    0.000000
# rel_loss      0.157616
# total         0.157616
# dtype: float64
# -----------
# ---Total norm 1.037 clip coef 4.820-----------------
# roi_fmap_obj.0.weight                             : 0.669, (torch.Size([4096, 25088]))
# roi_fmap.1.0.weight                               : 0.518, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.473, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.210, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.141, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.088, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.085, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.082, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.077, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.077, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.075, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.069, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.069, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.060, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.058, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.056, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.051, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.045, (torch.Size([512, 256, 3, 3]))
# union_boxes.conv.0.weight                         : 0.040, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.028, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.012, (torch.Size([4096]))
# roi_fmap.1.3.bias                                 : 0.011, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.010, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.009, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.006, (torch.Size([256]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.006, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.005, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.005, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.005, (torch.Size([2048]))
# union_boxes.conv.6.weight                         : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.002, (torch.Size([256]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 2b10000/14430 0.338s/batch, 81.2m/epoch
# class_loss    0.000000
# rel_loss      0.158663
# total         0.158663
# dtype: float64
# -----------
#
# e 2b11000/14430 0.339s/batch, 81.6m/epoch
# class_loss    0.000000
# rel_loss      0.156571
# total         0.156571
# dtype: float64
# -----------
#
# e 2b12000/14430 0.338s/batch, 81.2m/epoch
# class_loss    0.000000
# rel_loss      0.155299
# total         0.155299
# dtype: float64
# -----------
#
# e 2b13000/14430 0.336s/batch, 80.9m/epoch
# class_loss    0.000000
# rel_loss      0.154695
# total         0.154695
# dtype: float64
# -----------
#
# e 2b14000/14430 0.339s/batch, 81.5m/epoch
# class_loss    0.000000
# rel_loss      0.152511
# total         0.152511
# dtype: float64
# -----------
# overall 2: (0.156)
# class_loss    0.000000
# rel_loss      0.156388
# total         0.156388
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.565522
# R@50: 0.621145
# R@100: 0.637908
# ======================predcls  recall without constraint============================
# R@20: 0.650917
# R@50: 0.788455
# R@100: 0.863172
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.10859498104112271
# mR@50:  0.13214817467134157
# mR@100:  0.14048079108130498
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.16532358760054827
# mR@50:  0.27338234278642565
# mR@100:  0.38651719944382007
# ---Total norm 0.410 clip coef 12.182-----------------
# roi_fmap.1.0.weight                               : 0.264, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.176, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.157, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.116, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.059, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.058, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.051, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.049, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.043, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.034, (torch.Size([1024, 300]))
# union_boxes.conv.4.weight                         : 0.033, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.032, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.027, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.027, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.024, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.022, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.005, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.005, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.005, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.004, (torch.Size([512, 1024]))
# roi_fmap_obj.3.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# union_boxes.conv.6.bias                           : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.002, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 3b 1000/14430 0.337s/batch, 81.1m/epoch
# class_loss    0.000000
# rel_loss      0.152213
# total         0.152213
# dtype: float64
# -----------
#
# e 3b 2000/14430 0.339s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.155669
# total         0.155669
# dtype: float64
# -----------
#
# e 3b 3000/14430 0.340s/batch, 81.8m/epoch
# class_loss    0.000000
# rel_loss      0.151019
# total         0.151019
# dtype: float64
# -----------
#
# e 3b 4000/14430 0.358s/batch, 86.2m/epoch
# class_loss    0.000000
# rel_loss      0.152526
# total         0.152526
# dtype: float64
# -----------
#
# e 3b 5000/14430 0.344s/batch, 82.6m/epoch
# class_loss    0.000000
# rel_loss      0.149362
# total         0.149362
# dtype: float64
# -----------
#
# e 3b 6000/14430 0.336s/batch, 80.8m/epoch
# class_loss    0.000000
# rel_loss      0.155523
# total         0.155523
# dtype: float64
# -----------
#
# e 3b 7000/14430 0.339s/batch, 81.6m/epoch
# class_loss    0.000000
# rel_loss      0.151267
# total         0.151267
# dtype: float64
# -----------
#
# e 3b 8000/14430 0.346s/batch, 83.3m/epoch
# class_loss    0.000000
# rel_loss      0.148226
# total         0.148226
# dtype: float64
# -----------
#
# e 3b 9000/14430 0.341s/batch, 82.0m/epoch
# class_loss    0.000000
# rel_loss      0.153101
# total         0.153101
# dtype: float64
# -----------
# ---Total norm 0.754 clip coef 6.631-----------------
# roi_fmap.1.0.weight                               : 0.458, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.388, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.273, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.162, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.139, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.139, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.089, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.088, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.087, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.072, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.072, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.072, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.066, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.063, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.060, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.051, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.044, (torch.Size([512, 1024]))
# union_boxes.conv.4.weight                         : 0.043, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.036, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.034, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.028, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.026, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.024, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.013, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.012, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.009, (torch.Size([2048, 2048]))
# roi_fmap_obj.3.bias                               : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.007, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.005, (torch.Size([2048]))
# union_boxes.conv.6.weight                         : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.004, (torch.Size([1024, 300]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.003, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ...
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.053, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.049, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.046, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.045, (torch.Size([1024, 300]))
# union_boxes.conv.4.weight                         : 0.037, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.035, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.032, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.029, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.026, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.025, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.025, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.010, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.009, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.007, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.005, (torch.Size([2048, 2048]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.004, (torch.Size([1024, 2048]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.003, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.003, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.002, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 5b 1000/14430 0.338s/batch, 81.2m/epoch
# class_loss    0.000000
# rel_loss      0.145115
# total         0.145115
# dtype: float64
# -----------
#
# e 5b 2000/14430 0.340s/batch, 81.7m/epoch
# class_loss    0.000000
# rel_loss      0.145247
# total         0.145247
# dtype: float64
# -----------
#
# e 5b 3000/14430 0.340s/batch, 81.7m/epoch
# class_loss    0.000000
# rel_loss      0.147162
# total         0.147162
# dtype: float64
# -----------
#
# e 5b 4000/14430 0.339s/batch, 81.5m/epoch
# class_loss    0.000000
# rel_loss      0.144099
# total         0.144099
# dtype: float64
# -----------
#
# e 5b 5000/14430 0.337s/batch, 81.1m/epoch
# class_loss    0.000000
# rel_loss      0.147552
# total         0.147552
# dtype: float64
# -----------
#
# e 5b 6000/14430 0.349s/batch, 84.0m/epoch
# class_loss    0.000000
# rel_loss      0.147348
# total         0.147348
# dtype: float64
# -----------
#
# e 5b 7000/14430 0.337s/batch, 80.9m/epoch
# class_loss    0.000000
# rel_loss      0.143675
# total         0.143675
# dtype: float64
# -----------
#
# e 5b 8000/14430 0.335s/batch, 80.5m/epoch
# class_loss    0.000000
# rel_loss      0.145537
# total         0.145537
# dtype: float64
# -----------
#
# e 5b 9000/14430 0.340s/batch, 81.7m/epoch
# class_loss    0.000000
# rel_loss      0.142537
# total         0.142537
# dtype: float64
# -----------
# ---Total norm 0.399 clip coef 12.545-----------------
# roi_fmap.1.0.weight                               : 0.269, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.211, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.137, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.079, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.042, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.039, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.038, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.037, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.037, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.035, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.031, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.027, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.022, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.019, (torch.Size([512, 1024]))
# union_boxes.conv.4.weight                         : 0.018, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.014, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.013, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.003, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.003, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.002, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.002, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.002, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.001, (torch.Size([1024, 300]))
# union_boxes.conv.0.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# union_boxes.conv.2.bias                           : 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 5b10000/14430 0.336s/batch, 80.9m/epoch
# class_loss    0.000000
# rel_loss      0.146897
# total         0.146897
# dtype: float64
# -----------
#
# e 5b11000/14430 0.335s/batch, 80.6m/epoch
# class_loss    0.000000
# rel_loss      0.149579
# total         0.149579
# dtype: float64
# -----------
#
# e 5b12000/14430 0.336s/batch, 80.8m/epoch
# class_loss    0.00000
# rel_loss      0.14857
# total         0.14857
# dtype: float64
# -----------
#
# e 5b13000/14430 0.338s/batch, 81.3m/epoch
# class_loss    0.000000
# rel_loss      0.147127
# total         0.147127
# dtype: float64
# -----------
#
# e 5b14000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.145723
# total         0.145723
# dtype: float64
# -----------
# overall 5: (0.146)
# class_loss    0.000000
# rel_loss      0.146205
# total         0.146205
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.576792
# R@50: 0.632468
# R@100: 0.648029
# ======================predcls  recall without constraint============================
# R@20: 0.664239
# R@50: 0.797884
# R@100: 0.871142
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.10553071803259532
# mR@50:  0.1279350829443022
# mR@100:  0.13624475887877532
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.1843987221813192
# mR@50:  0.31097100095414004
# mR@100:  0.4243379181520492

# %%
for param_group in optimizer.param_groups:
    param_group['lr'] /= 10

# %%
print("Training starts now!")

for epoch in range(6, 11):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 1.298 clip coef 3.851-----------------
# roi_fmap.1.0.weight                               : 0.836, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.684, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.487, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.273, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.183, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.143, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.128, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.120, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.116, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.107, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.106, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.099, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.099, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.091, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.089, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.078, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.073, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.072, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.072, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.069, (torch.Size([1024]))
# union_boxes.conv.4.weight                         : 0.065, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.064, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.050, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.047, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.046, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.031, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.031, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.031, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.017, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.016, (torch.Size([768]))
# union_boxes.conv.6.bias                           : 0.016, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.015, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.015, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.014, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.013, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.010, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.010, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.009, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.008, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.007, (torch.Size([4096]))
# roi_fmap_obj.0.bias                               : 0.006, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.005, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 6b 1000/14430 0.341s/batch, 82.1m/epoch
# class_loss    0.000000
# rel_loss      0.141121
# total         0.141121
# dtype: float64
# -----------
#
# e 6b 2000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.00000
# rel_loss      0.14257
# total         0.14257
# dtype: float64
# -----------
#
# e 6b 3000/14430 0.335s/batch, 80.5m/epoch
# class_loss    0.000000
# rel_loss      0.141802
# total         0.141802
# dtype: float64
# -----------
#
# e 6b 4000/14430 0.336s/batch, 80.9m/epoch
# class_loss    0.000000
# rel_loss      0.138303
# total         0.138303
# dtype: float64
# -----------
#
# e 6b 5000/14430 0.335s/batch, 80.7m/epoch
# class_loss    0.00000
# rel_loss      0.13947
# total         0.13947
# dtype: float64
# -----------
#
# e 6b 6000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.137852
# total         0.137852
# dtype: float64
# -----------
#
# e 6b 7000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.137444
# total         0.137444
# dtype: float64
# -----------
#
# e 6b 8000/14430 0.338s/batch, 81.3m/epoch
# class_loss    0.000000
# rel_loss      0.138923
# total         0.138923
# dtype: float64
# -----------
#
# e 6b 9000/14430 0.338s/batch, 81.4m/epoch
# class_loss    0.000000
# rel_loss      0.140477
# total         0.140477
# dtype: float64
# -----------
# ---Total norm 1.807 clip coef 2.767-----------------
# roi_fmap.1.0.weight                               : 1.300, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.879, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.587, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.417, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.225, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.191, (torch.Size([1024, 768]))
# ggnn_rel_reason.obj_proj.weight                   : 0.180, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.159, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.158, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.145, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.128, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.117, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.102, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.099, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.090, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.079, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.079, (torch.Size([1024, 300]))
# union_boxes.conv.0.weight                         : 0.062, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.062, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.055, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.048, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.029, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.027, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.022, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.021, (torch.Size([768]))
# union_boxes.conv.6.bias                           : 0.020, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.019, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.014, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.012, (torch.Size([512]))
# roi_fmap.1.0.bias                                 : 0.010, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.007, (torch.Size([4096]))
# union_boxes.conv.0.bias                           : 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.006, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.006, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.003, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.002, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 6b10000/14430 0.342s/batch, 82.2m/epoch
# class_loss    0.000000
# rel_loss      0.136979
# total         0.136979
# dtype: float64
# -----------
#
# e 6b11000/14430 0.342s/batch, 82.2m/epoch
# class_loss    0.000000
# rel_loss      0.135399
# total         0.135399
# dtype: float64
# -----------
#
# e 6b12000/14430 0.336s/batch, 80.8m/epoch
# class_loss    0.000000
# rel_loss      0.135785
# total         0.135785
# dtype: float64
# -----------
#
# e 6b13000/14430 0.336s/batch, 80.7m/epoch
# class_loss    0.00000
# rel_loss      0.13811
# total         0.13811
# dtype: float64
# -----------
#
# e 6b14000/14430 0.338s/batch, 81.2m/epoch
# class_loss    0.000000
# rel_loss      0.136805
# total         0.136805
# dtype: float64
# -----------
# overall 6: (0.139)
# class_loss    0.000000
# rel_loss      0.138624
# total         0.138624
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.577730
# R@50: 0.635649
# R@100: 0.651983
# ======================predcls  recall without constraint============================
# R@20: 0.668029
# R@50: 0.803512
# R@100: 0.875442
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.13266475720219226
# mR@50:  0.1596431346839966
# mR@100:  0.1687705018510867
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.20690479910955886
# mR@50:  0.34080032788329817
# mR@100:  0.4593888216645132
# ---Total norm 0.440 clip coef 11.371-----------------
# roi_fmap.1.0.weight                               : 0.363, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.133, (torch.Size([4096, 25088]))
# roi_fmap.1.3.weight                               : 0.107, (torch.Size([4096, 4096]))
# roi_fmap_obj.3.weight                             : 0.093, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.065, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.063, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.048, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.040, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.037, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.034, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.032, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.031, (torch.Size([1024, 300]))
# ggnn_rel_reason.obj_proj.weight                   : 0.030, (torch.Size([1024, 4096]))
# union_boxes.conv.4.weight                         : 0.030, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.027, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.023, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.023, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.022, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.018, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.011, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.010, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# roi_fmap_obj.3.bias                               : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.003, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.003, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.003, (torch.Size([256]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.002, (torch.Size([1024, 2048]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.002, (torch.Size([2048]))
# roi_fmap_obj.0.bias                               : 0.001, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.001, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 7b 1000/14430 0.341s/batch, 82.0m/epoch
# class_loss    0.000000
# rel_loss      0.137673
# total         0.137673
# dtype: float64
# -----------
#
# e 7b 2000/14430 0.335s/batch, 80.6m/epoch
# class_loss    0.000000
# rel_loss      0.135664
# total         0.135664
# dtype: float64
# -----------
#
# e 7b 3000/14430 0.337s/batch, 81.1m/epoch
# class_loss    0.000000
# rel_loss      0.137461
# total         0.137461
# dtype: float64
# -----------
#
# e 7b 4000/14430 0.340s/batch, 81.8m/epoch
# class_loss    0.00000
# rel_loss      0.13822
# total         0.13822
# dtype: float64
# -----------
#
# e 7b 5000/14430 0.339s/batch, 81.4m/epoch
# class_loss    0.00000
# rel_loss      0.13668
# total         0.13668
# dtype: float64
# -----------
#
# e 7b 6000/14430 0.343s/batch, 82.5m/epoch
# class_loss    0.00000
# rel_loss      0.13286
# total         0.13286
# dtype: float64
# -----------
#
# e 7b 7000/14430 0.361s/batch, 86.7m/epoch
# class_loss    0.000000
# rel_loss      0.136896
# total         0.136896
# dtype: float64
# -----------
#
# e 7b 8000/14430 0.335s/batch, 80.6m/epoch
# class_loss    0.000000
# rel_loss      0.136759
# total         0.136759
# dtype: float64
# -----------
#
# e 7b 9000/14430 0.329s/batch, 79.1m/epoch
# class_loss    0.000000
# rel_loss      0.137399
# total         0.137399
# dtype: float64
# -----------
# ---Total norm 1.251 clip coef 3.996-----------------
# roi_fmap.1.0.weight                               : 0.968, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.533, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.351, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.287, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.116, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.115, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.113, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.112, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.111, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.108, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.089, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.089, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.087, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.077, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.074, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.069, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.065, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.061, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.052, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.050, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.046, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.038, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.022, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.021, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.013, (torch.Size([768]))
# roi_fmap_obj.3.bias                               : 0.012, (torch.Size([4096]))
# union_boxes.conv.6.bias                           : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.010, (torch.Size([2048, 2048]))
# ggnn_rel_reason.obj_proj.bias                     : 0.010, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.009, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.009, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.008, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.008, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.005, (torch.Size([512, 1024]))
# roi_fmap_obj.0.bias                               : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.004, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.004, (torch.Size([256, 512]))
# union_boxes.conv.2.weight                         : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.003, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 7b10000/14430 0.331s/batch, 79.6m/epoch
# class_loss    0.000000
# rel_loss      0.135576
# total         0.135576
# dtype: float64
# -----------
#
# e 7b11000/14430 0.330s/batch, 79.4m/epoch
# class_loss    0.000000
# rel_loss      0.135254
# total         0.135254
# dtype: float64
# -----------
#
# e 7b12000/14430 0.331s/batch, 79.5m/epoch
# class_loss    0.000000
# rel_loss      0.137269
# total         0.137269
# dtype: float64
# -----------
#
# e 7b13000/14430 0.330s/batch, 79.3m/epoch
# class_loss    0.000000
# rel_loss      0.136914
# total         0.136914
# dtype: float64
# -----------
#
# e 7b14000/14430 0.330s/batch, 79.3m/epoch
# class_loss    0.000000
# rel_loss      0.136729
# total         0.136729
# dtype: float64
# -----------
# overall 7: (0.137)
# class_loss    0.000000
# rel_loss      0.136593
# total         0.136593
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.578876
# R@50: 0.636755
# R@100: 0.653461
# ======================predcls  recall without constraint============================
# R@20: 0.669275
# R@50: 0.806295
# R@100: 0.875772
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.13429052792354804
# mR@50:  0.1638479744725774
# mR@100:  0.1727378123655792
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.2064125941180471
# mR@50:  0.3504381704256799
# mR@100:  0.4636254852880255
# ---Total norm 1.086 clip coef 4.604-----------------
# roi_fmap.1.0.weight                               : 0.866, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.447, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.295, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.230, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.096, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.093, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.093, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.091, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.090, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.082, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.080, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.076, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.067, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.060, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.054, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.051, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.048, (torch.Size([512, 1024]))
# union_boxes.conv.0.weight                         : 0.044, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.040, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.040, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.034, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.021, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.020, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.012, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.010, (torch.Size([768]))
# roi_fmap_obj.3.bias                               : 0.010, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.007, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.007, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.007, (torch.Size([512]))
# roi_fmap.1.0.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.006, (torch.Size([1024, 2048]))
# union_boxes.conv.0.bias                           : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.004, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.003, (torch.Size([2048]))
# union_boxes.conv.2.weight                         : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.003, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.003, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e 8b 1000/14430 0.332s/batch, 79.9m/epoch
# class_loss    0.000000
# rel_loss      0.134013
# total         0.134013
# dtype: float64
# -----------
#
# e 8b 2000/14430 0.330s/batch, 79.4m/epoch
# class_loss    0.000000
# rel_loss      0.134933
# total         0.134933
# dtype: float64
# -----------
#
# e 8b 3000/14430 0.331s/batch, 79.5m/epoch
# class_loss    0.00000
# rel_loss      0.13274
# total         0.13274
# dtype: float64
# -----------
#
# e 8b 4000/14430 0.337s/batch, 81.1m/epoch
# class_loss    0.000000
# rel_loss      0.132535
# total         0.132535
# dtype: float64
# -----------
#
# e 8b 5000/14430 0.334s/batch, 80.3m/epoch
# class_loss    0.000000
# rel_loss      0.138273
# total         0.138273
# dtype: float64
# -----------
#
# e 8b 6000/14430 0.329s/batch, 79.2m/epoch
# class_loss    0.000000
# rel_loss      0.135448
# total         0.135448
# dtype: float64
# -----------
#
# e 8b 7000/14430 0.331s/batch, 79.5m/epoch
# class_loss    0.000000
# rel_loss      0.135898
# total         0.135898
# dtype: float64
# -----------
#
# e 8b 8000/14430 0.330s/batch, 79.4m/epoch
# class_loss    0.000000
# rel_loss      0.137417
# total         0.137417
# dtype: float64
# -----------
#
# e 8b 9000/14430 0.330s/batch, 79.4m/epoch
# class_loss    0.00000
# rel_loss      0.13847
# total         0.13847
# dtype: float64
# -----------
# ---Total norm 0.974 clip coef 5.133-----------------
# roi_fmap.1.0.weight                               : 0.681, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.503, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.334, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.186, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.120, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.113, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.084, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.077, (torch.Size([1024, 4096]))
# ggnn_rel_reason.rel_proj.weight                   : 0.077, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.072, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.070, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.067, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.058, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.058, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.051, (torch.Size([256, 512]))
# union_boxes.conv.4.weight                         : 0.050, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.048, (torch.Size([1024, 300]))
# union_boxes.conv.0.weight                         : 0.043, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.042, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.033, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.022, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.020, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.019, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.011, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.010, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.010, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.007, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.007, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.005, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.005, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.004, (torch.Size([1024, 2048]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.004, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.003, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.002, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.002, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.002, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ...
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.065, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.065, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.060, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.057, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.053, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.050, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.031, (torch.Size([1024, 300]))
# union_boxes.conv.0.weight                         : 0.030, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.029, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.028, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.023, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.014, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.013, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.011, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.011, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.010, (torch.Size([768]))
# union_boxes.conv.6.bias                           : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.009, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.006, (torch.Size([512]))
# roi_fmap.1.0.bias                                 : 0.005, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.004, (torch.Size([256]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.003, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.003, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.002, (torch.Size([2048]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.001, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e10b 1000/14430 0.332s/batch, 79.8m/epoch
# class_loss    0.000000
# rel_loss      0.135042
# total         0.135042
# dtype: float64
# -----------
#
# e10b 2000/14430 0.329s/batch, 79.1m/epoch
# class_loss    0.00000
# rel_loss      0.13235
# total         0.13235
# dtype: float64
# -----------
#
# e10b 3000/14430 0.331s/batch, 79.6m/epoch
# class_loss    0.000000
# rel_loss      0.133161
# total         0.133161
# dtype: float64
# -----------
#
# e10b 4000/14430 0.331s/batch, 79.7m/epoch
# class_loss    0.000000
# rel_loss      0.132838
# total         0.132838
# dtype: float64
# -----------
#
# e10b 5000/14430 0.331s/batch, 79.7m/epoch
# class_loss    0.000000
# rel_loss      0.130836
# total         0.130836
# dtype: float64
# -----------
#
# e10b 6000/14430 0.332s/batch, 79.9m/epoch
# class_loss    0.000000
# rel_loss      0.131482
# total         0.131482
# dtype: float64
# -----------
#
# e10b 7000/14430 0.328s/batch, 79.0m/epoch
# class_loss    0.000000
# rel_loss      0.136461
# total         0.136461
# dtype: float64
# -----------
#
# e10b 8000/14430 0.332s/batch, 80.0m/epoch
# class_loss    0.00000
# rel_loss      0.13144
# total         0.13144
# dtype: float64
# -----------
#
# e10b 9000/14430 0.330s/batch, 79.5m/epoch
# class_loss    0.000000
# rel_loss      0.136157
# total         0.136157
# dtype: float64
# -----------
# ---Total norm 0.483 clip coef 10.354-----------------
# roi_fmap.1.0.weight                               : 0.367, (torch.Size([4096, 25088]))
# roi_fmap_obj.0.weight                             : 0.214, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 0.156, (torch.Size([4096, 4096]))
# roi_fmap.1.3.weight                               : 0.106, (torch.Size([4096, 4096]))
# ggnn_rel_reason.obj_proj.weight                   : 0.047, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.043, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.041, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.034, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.031, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.029, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.028, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.024, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.022, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.019, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.018, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.009, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.009, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.006, (torch.Size([4096]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.003, (torch.Size([512]))
# roi_fmap.1.0.bias                                 : 0.003, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.003, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.002, (torch.Size([1024, 2048]))
# roi_fmap_obj.0.bias                               : 0.002, (torch.Size([4096]))
# union_boxes.conv.0.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.001, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.001, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.001, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.001, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.000, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.000, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.000, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.000, (torch.Size([256]))
# -------------------------------
#
# e10b10000/14430 0.333s/batch, 80.0m/epoch
# class_loss    0.000000
# rel_loss      0.134017
# total         0.134017
# dtype: float64
# -----------
#
# e10b11000/14430 0.331s/batch, 79.6m/epoch
# class_loss    0.00000
# rel_loss      0.13557
# total         0.13557
# dtype: float64
# -----------
#
# e10b12000/14430 0.330s/batch, 79.4m/epoch
# class_loss    0.000000
# rel_loss      0.136902
# total         0.136902
# dtype: float64
# -----------
#
# e10b13000/14430 0.334s/batch, 80.2m/epoch
# class_loss    0.000000
# rel_loss      0.137067
# total         0.137067
# dtype: float64
# -----------
#
# e10b14000/14430 0.333s/batch, 80.2m/epoch
# class_loss    0.000000
# rel_loss      0.132948
# total         0.132948
# dtype: float64
# -----------
# overall10: (0.134)
# class_loss    0.000000
# rel_loss      0.133947
# total         0.133947
# dtype: float64
# ======================predcls  recall with constraint============================
# R@20: 0.577209
# R@50: 0.633226
# R@100: 0.650500
# ======================predcls  recall without constraint============================
# R@20: 0.667086
# R@50: 0.802187
# R@100: 0.874336
#
#
# ======================predcls  mean recall with constraint============================
# mR@20:  0.14148055359940936
# mR@50:  0.17128836506173822
# mR@100:  0.1821021102057794
#
#
# ======================predcls  mean recall without constraint============================
# mR@20:  0.21066547287839502
# mR@50:  0.3514735571805073
# mR@100:  0.46521114949252906
