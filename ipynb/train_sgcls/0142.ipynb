# %%
import numpy as np
np.random.seed(1244)
import torch
torch.manual_seed(1245)
torch.__version__
# Out:
# '0.3.0.post4'

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
codebase = '../../'
sys.path.append(codebase)

# %%
exp_name = 'exp_142'
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from dataloaders.visual_genome import VGDataLoader, VG
import numpy as np
from torch import optim
import torch
import pandas as pd
import time
import os

from config import ModelConfig, BOX_SCALE, IM_SCALE
from torch.nn import functional as F
from lib.pytorch_misc import optimistic_restore, de_chunkize, clip_grad_norm
from lib.evaluation.sg_eval import BasicSceneGraphEvaluator, calculate_mR_from_evaluator_list, eval_entry
from lib.pytorch_misc import print_para
from torch.optim.lr_scheduler import ReduceLROnPlateau

from lib.my_model_33 import KERN

# %%
conf = ModelConfig(f'''
-m sgcls -p 1000 -clip 5 
-tb_log_dir summaries/kern_sgcls/{exp_name} 
-save_dir checkpoints/kern_sgcls/{exp_name}
-ckpt checkpoints/kern_predcls/exp_132/vgrel-10.tar
-val_size 5000 
-adam 
-b 4
-ngpu 1
-lr 1e-5 
''')
# Out:
# ~~~~~~~~ Hyperparameters used: ~~~~~~~
# ckpt : checkpoints/kern_predcls/exp_132/vgrel-10.tar
# save_dir : checkpoints/kern_sgcls/exp_142
# num_gpus : 1
# num_workers : 1
# lr : 1e-05
# batch_size : 4
# val_size : 5000
# l2 : 0.0001
# adamwd : 0.0
# clip : 5.0
# print_interval : 1000
# mode : sgcls
# cache :
# adam : True
# test : False
# num_epochs : 50
# use_resnet : False
# use_proposals : False
# pooling_dim : 4096
# use_ggnn_obj : False
# ggnn_obj_time_step_num : 3
# ggnn_obj_hidden_dim : 512
# ggnn_obj_output_dim : 512
# use_obj_knowledge : False
# obj_knowledge :
# use_ggnn_rel : False
# ggnn_rel_time_step_num : 3
# ggnn_rel_hidden_dim : 512
# ggnn_rel_output_dim : 512
# use_rel_knowledge : False
# rel_knowledge :
# tb_log_dir : summaries/kern_sgcls/exp_142
# save_rel_recall :

# %%
train, val, _ = VG.splits(num_val_im=conf.val_size, filter_duplicate_rels=True,
                          use_proposals=conf.use_proposals,
                          filter_non_overlap=conf.mode == 'sgdet')

# %%
ind_to_predicates = train.ind_to_predicates # ind_to_predicates[0] means no relationship

# %%
train_loader, val_loader = VGDataLoader.splits(train, val, mode='rel',
                                               batch_size=conf.batch_size,
                                               num_workers=conf.num_workers,
                                               num_gpus=conf.num_gpus)

# %%
detector = KERN(classes=train.ind_to_classes, rel_classes=train.ind_to_predicates,
                num_gpus=conf.num_gpus, mode=conf.mode, require_overlap_det=True,
                use_resnet=conf.use_resnet, use_proposals=conf.use_proposals, pooling_dim=conf.pooling_dim,
                ggnn_rel_time_step_num=3, ggnn_rel_hidden_dim=1024, ggnn_rel_output_dim=None,
                graph_path=os.path.join(codebase, 'graphs/005/all_edges.pkl'), 
                emb_path=os.path.join(codebase, 'graphs/001/emb_mtx.pkl'), 
                rel_counts_path=os.path.join(codebase, 'graphs/001/pred_counts.pkl'), 
                use_knowledge=True, use_embedding=True, refine_obj_cls=True,
                class_volume=1.0, top_k_to_keep=5, normalize_messages=False,
               )
# Out:
# /home/alireza/home_at_filer2/tools/anaconda3/envs/kern2/lib/python3.6/site-packages/torch/cuda/__init__.py:87: UserWarning:
#     Found GPU0 GeForce GTX 1080 Ti which requires CUDA_VERSION >= 8000 for
#      optimal performance and fast startup time, but your PyTorch was compiled
#      with CUDA_VERSION 7050. Please install the correct PyTorch binary
#      using instructions from http://pytorch.org
#
#   warnings.warn(error_str % (d, name, 8000, CUDA_VERSION))

# %%
# Freeze the detector
for n, param in detector.detector.named_parameters():
    param.requires_grad = False

# %%
print(print_para(detector), flush=True)
# Out:
#  448.8M total parameters
#  -----
#
# detector.roi_fmap.0.weight                        : [4096,25088]    (102760448) (    )
# roi_fmap.1.0.weight                               : [4096,25088]    (102760448) (grad)
# roi_fmap_obj.0.weight                             : [4096,25088]    (102760448) (grad)
# detector.roi_fmap.3.weight                        : [4096,4096]     (16777216) (    )
# roi_fmap.1.3.weight                               : [4096,4096]     (16777216) (grad)
# roi_fmap_obj.3.weight                             : [4096,4096]     (16777216) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: [3328,3328]     (11075584) (grad)
# ggnn_rel_reason.obj_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.rel_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: [2048,2048]     ( 4194304) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: [1024,3328]     ( 3407872) (grad)
# detector.bbox_fc.weight                           : [604,4096]      ( 2473984) (    )
# detector.features.19.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.21.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.24.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.26.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.28.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.rpn_head.conv.0.weight                   : [512,512,3,3]   ( 2359296) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: [1024,2048]     ( 2097152) (grad)
# detector.features.17.weight                       : [512,256,3,3]   ( 1179648) (    )
# union_boxes.conv.4.weight                         : [512,256,3,3]   ( 1179648) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: [1024,768]      (  786432) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: [1024,768]      (  786432) (grad)
# detector.score_fc.weight                          : [151,4096]      (  618496) (    )
# detector.features.12.weight                       : [256,256,3,3]   (  589824) (    )
# detector.features.14.weight                       : [256,256,3,3]   (  589824) (    )
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: [768,768]       (  589824) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : [1024,300]      (  307200) (grad)
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : [1024,300]      (  307200) (grad)
# detector.features.10.weight                       : [256,128,3,3]   (  294912) (    )
# detector.features.7.weight                        : [128,128,3,3]   (  147456) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# detector.features.5.weight                        : [128,64,3,3]    (   73728) (    )
# detector.rpn_head.conv.2.weight                   : [120,512,1,1]   (   61440) (    )
# detector.features.2.weight                        : [64,64,3,3]     (   36864) (    )
# union_boxes.conv.0.weight                         : [256,2,7,7]     (   25088) (grad)
# detector.features.0.weight                        : [64,3,3,3]      (    1728) (    )
# union_boxes.conv.6.weight                         : [512]           (     512) (grad)
# union_boxes.conv.2.weight                         : [256]           (     256) (grad)

# %%
def get_optim(lr):
    # Lower the learning rate on the VGG fully connected layers by 1/10th. It's a hack, but it helps
    # stabilize the models.
    fc_params = [p for n,p in detector.named_parameters() if n.startswith('roi_fmap') and p.requires_grad]
    non_fc_params = [p for n,p in detector.named_parameters() if not n.startswith('roi_fmap') and p.requires_grad]
    params = [{'params': fc_params, 'lr': lr / 10.0}, {'params': non_fc_params}]
    # params = [p for n,p in detector.named_parameters() if p.requires_grad]

    if conf.adam:
        optimizer = optim.Adam(params, weight_decay=conf.adamwd, lr=lr, eps=1e-3)
    else:
        optimizer = optim.SGD(params, weight_decay=conf.l2, lr=lr, momentum=0.9)

    # scheduler = ReduceLROnPlateau(optimizer, 'max', patience=3, factor=0.1,
    #                               verbose=True, threshold=0.0001, threshold_mode='abs', cooldown=1)
    return optimizer #, scheduler

# %%
ckpt = torch.load(conf.ckpt)

# %%
if conf.ckpt.split('-')[-2].split('/')[-1] == 'vgrel':
    print("Loading EVERYTHING")
    start_epoch = ckpt['epoch']

    if not optimistic_restore(detector, ckpt['state_dict']):
        start_epoch = -1
        # optimistic_restore(detector.detector, torch.load('checkpoints/vgdet/vg-28.tar')['state_dict'])
else:
    start_epoch = -1
    optimistic_restore(detector.detector, ckpt['state_dict'])

    detector.roi_fmap[1][0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap[1][3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap[1][0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap[1][3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

    detector.roi_fmap_obj[0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap_obj[3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap_obj[0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap_obj[3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])
# Out:
# Loading EVERYTHING
# We couldn't find ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight,ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight,ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight,ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias,ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias

# %%
detector.cuda();

# %%
def train_epoch(epoch_num):
    detector.train()
    tr = []
    start = time.time()
    for b, batch in enumerate(train_loader):
        result, loss_pd = train_batch(batch, verbose=b % (conf.print_interval*10) == 0)
        tr.append(loss_pd)
        '''
        if b % 100 == 0:
            print(loss_pd)
            gt = result.rel_labels[:,3].data.cpu().numpy()
            out = result.rel_dists.data.cpu().numpy()
            ind = np.where(gt)[0]
            print(gt[ind])
            print(np.argmax(out[ind], 1))
            print(np.argmax(out[ind, 1:], 1) + 1)
        '''

        if b % conf.print_interval == 0 and b >= conf.print_interval:
            mn = pd.concat(tr[-conf.print_interval:], axis=1).mean(1)
            time_per_batch = (time.time() - start) / conf.print_interval
            print("\ne{:2d}b{:5d}/{:5d} {:.3f}s/batch, {:.1f}m/epoch".format(
                epoch_num, b, len(train_loader), time_per_batch, len(train_loader) * time_per_batch / 60))
            print(mn)
            print('-----------', flush=True)
            start = time.time()
    return pd.concat(tr, axis=1)

# %%
def train_batch(b, verbose=False):
    """
    :param b: contains:
          :param imgs: the image, [batch_size, 3, IM_SIZE, IM_SIZE]
          :param all_anchors: [num_anchors, 4] the boxes of all anchors that we'll be using
          :param all_anchor_inds: [num_anchors, 2] array of the indices into the concatenated
                                  RPN feature vector that give us all_anchors,
                                  each one (img_ind, fpn_idx)
          :param im_sizes: a [batch_size, 4] numpy array of (h, w, scale, num_good_anchors) for each image.

          :param num_anchors_per_img: int, number of anchors in total over the feature pyramid per img

          Training parameters:
          :param train_anchor_inds: a [num_train, 5] array of indices for the anchors that will
                                    be used to compute the training loss (img_ind, fpn_idx)
          :param gt_boxes: [num_gt, 4] GT boxes over the batch.
          :param gt_classes: [num_gt, 2] gt boxes where each one is (img_id, class)
    :return:
    """
    result = detector[b]

    losses = {}
    losses['class_loss'] = detector.obj_loss(result)
    losses['rel_loss'] = detector.rel_loss(result)
    loss = sum(losses.values())

    optimizer.zero_grad()
    loss.backward()
    clip_grad_norm(
        [(n, p) for n, p in detector.named_parameters() if p.grad is not None],
        max_norm=conf.clip, verbose=verbose, clip=True)
    losses['total'] = loss
    optimizer.step()
    loss_pd = pd.Series({x: y.data[0] for x, y in losses.items()})
    return result, loss_pd

# %%
def val_epoch():
    detector.eval()
    evaluator_list = [] # for calculating recall of each relationship except no relationship
    evaluator_multiple_preds_list = []
    for index, name in enumerate(ind_to_predicates):
        if index == 0:
            continue
        evaluator_list.append((index, name, BasicSceneGraphEvaluator.all_modes()))
        evaluator_multiple_preds_list.append((index, name, BasicSceneGraphEvaluator.all_modes(multiple_preds=True)))
    evaluator = BasicSceneGraphEvaluator.all_modes() # for calculating recall
    evaluator_multiple_preds = BasicSceneGraphEvaluator.all_modes(multiple_preds=True)
    for val_b, batch in enumerate(val_loader):
        val_batch(conf.num_gpus * val_b, batch, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list)

    recall = evaluator[conf.mode].print_stats()
    recall_mp = evaluator_multiple_preds[conf.mode].print_stats()
    
    mean_recall = calculate_mR_from_evaluator_list(evaluator_list, conf.mode)
    mean_recall_mp = calculate_mR_from_evaluator_list(evaluator_multiple_preds_list, conf.mode, multiple_preds=True)
    
    detector.train()
    return recall, recall_mp, mean_recall, mean_recall_mp

# %%
def val_batch(batch_num, b, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list):
    det_res = detector[b]
    if conf.num_gpus == 1:
        det_res = [det_res]

    for i, (boxes_i, objs_i, obj_scores_i, rels_i, pred_scores_i) in enumerate(det_res):
        gt_entry = {
            'gt_classes': val.gt_classes[batch_num + i].copy(),
            'gt_relations': val.relationships[batch_num + i].copy(),
            'gt_boxes': val.gt_boxes[batch_num + i].copy(),
        }
        assert np.all(objs_i[rels_i[:, 0]] > 0) and np.all(objs_i[rels_i[:, 1]] > 0)

        pred_entry = {
            'pred_boxes': boxes_i * BOX_SCALE/IM_SCALE,
            'pred_classes': objs_i,
            'pred_rel_inds': rels_i,
            'obj_scores': obj_scores_i,
            'rel_scores': pred_scores_i,  # hack for now.
        }

        eval_entry(conf.mode, gt_entry, pred_entry, evaluator, evaluator_multiple_preds, 
                   evaluator_list, evaluator_multiple_preds_list)

# %%
if conf.tb_log_dir is not None:
    from tensorboardX import SummaryWriter
    if not os.path.exists(conf.tb_log_dir):
        os.makedirs(conf.tb_log_dir) 
    writer = SummaryWriter(log_dir=conf.tb_log_dir)
    use_tb = True
else:
    use_tb = False

# %%
optimizer = get_optim(conf.lr * conf.num_gpus * conf.batch_size)

# %%
print("Training starts now!")

for epoch in range(1, 16):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 2.124 clip coef 2.354-----------------
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: 0.734, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: 0.640, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 0.625, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.591, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.588, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.530, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.weight                             : 0.482, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 0.441, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.420, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.416, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.401, (torch.Size([3328, 3328]))
# roi_fmap_obj.0.weight                             : 0.398, (torch.Size([4096, 25088]))
# ggnn_rel_reason.obj_proj.weight                   : 0.365, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.357, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.342, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.341, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias: 0.243, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.233, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.217, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.217, (torch.Size([1024]))
# roi_fmap.1.3.weight                               : 0.204, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.195, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.195, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.194, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.160, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.159, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.124, (torch.Size([1024, 768]))
# ggnn_rel_reason.rel_proj.weight                   : 0.107, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.102, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.099, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.096, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.096, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.088, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.086, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.085, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.076, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.074, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.074, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.074, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.070, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.066, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.066, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.065, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.064, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.064, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.064, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.064, (torch.Size([1024, 300]))
# union_boxes.conv.4.weight                         : 0.061, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.058, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.053, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.050, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.050, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.050, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.049, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.048, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.046, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.045, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.043, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.042, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.037, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.034, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.034, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.031, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.028, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.027, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.024, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.024, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.022, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.022, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.020, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.019, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.017, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.015, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.014, (torch.Size([512]))
# roi_fmap_obj.3.bias                               : 0.014, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.012, (torch.Size([256]))
# ggnn_rel_reason.rel_proj.bias                     : 0.012, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.011, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.011, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.009, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.009, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.006, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.004, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b 1000/14430 0.810s/batch, 194.8m/epoch
# class_loss    1.713503
# rel_loss      0.140511
# total         1.854014
# dtype: float64
# -----------
#
# e 1b 2000/14430 0.642s/batch, 154.4m/epoch
# class_loss    1.044982
# rel_loss      0.139883
# total         1.184866
# dtype: float64
# -----------
#
# e 1b 3000/14430 0.639s/batch, 153.6m/epoch
# class_loss    0.993447
# rel_loss      0.137836
# total         1.131283
# dtype: float64
# -----------
#
# e 1b 4000/14430 0.640s/batch, 154.0m/epoch
# class_loss    0.943447
# rel_loss      0.137769
# total         1.081216
# dtype: float64
# -----------
#
# e 1b 5000/14430 0.636s/batch, 152.9m/epoch
# class_loss    0.892162
# rel_loss      0.140858
# total         1.033020
# dtype: float64
# -----------
#
# e 1b 6000/14430 0.638s/batch, 153.3m/epoch
# class_loss    0.900845
# rel_loss      0.141351
# total         1.042196
# dtype: float64
# -----------
#
# e 1b 7000/14430 0.636s/batch, 153.0m/epoch
# class_loss    0.888210
# rel_loss      0.142248
# total         1.030458
# dtype: float64
# -----------
#
# e 1b 8000/14430 0.634s/batch, 152.4m/epoch
# class_loss    0.897692
# rel_loss      0.135987
# total         1.033680
# dtype: float64
# -----------
#
# e 1b 9000/14430 0.636s/batch, 152.9m/epoch
# class_loss    0.861894
# rel_loss      0.141714
# total         1.003608
# dtype: float64
# -----------
# ---Total norm 4.993 clip coef 1.001-----------------
# roi_fmap_obj.0.weight                             : 2.864, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 2.207, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: 1.144, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 1.049, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 1.048, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.988, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.906, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.893, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.873, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 0.830, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: 0.826, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.817, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 0.801, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.751, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.561, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.400, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.373, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.356, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.336, (torch.Size([256, 512]))
# roi_fmap.1.3.weight                               : 0.311, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.308, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.249, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.243, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.232, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.203, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.181, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.181, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.176, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.172, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.165, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.163, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.163, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias: 0.159, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.154, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.154, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.149, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.122, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.119, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.117, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.110, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.109, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.105, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.104, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.096, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.094, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.094, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.088, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.087, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.082, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.069, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.064, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.051, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.051, (torch.Size([1024, 300]))
# roi_fmap_obj.3.bias                               : 0.051, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.044, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.044, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.043, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.042, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.041, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.040, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.037, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.036, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.035, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.034, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.031, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.029, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.026, (torch.Size([1024, 2048]))
# union_boxes.conv.6.bias                           : 0.024, (torch.Size([512]))
# roi_fmap_obj.0.bias                               : 0.023, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.021, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.019, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.018, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.015, (torch.Size([512]))
# roi_fmap.1.3.bias                                 : 0.014, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.013, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.013, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.012, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.009, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.009, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.009, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 1b10000/14430 0.638s/batch, 153.5m/epoch
# class_loss    0.873916
# rel_loss      0.134602
# total         1.008518
# dtype: float64
# -----------
#
# e 1b11000/14430 0.633s/batch, 152.3m/epoch
# class_loss    0.858896
# rel_loss      0.140702
# total         0.999598
# dtype: float64
# -----------
#
# e 1b12000/14430 0.639s/batch, 153.6m/epoch
# class_loss    0.862088
# rel_loss      0.138172
# total         1.000260
# dtype: float64
# -----------
#
# e 1b13000/14430 0.639s/batch, 153.6m/epoch
# class_loss    0.844796
# rel_loss      0.138134
# total         0.982930
# dtype: float64
# -----------
#
# e 1b14000/14430 0.635s/batch, 152.7m/epoch
# class_loss    0.846585
# rel_loss      0.140304
# total         0.986889
# dtype: float64
# -----------
# overall 1: (1.095)
# class_loss    0.956058
# rel_loss      0.139251
# total         1.095309
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.381344
# R@50: 0.406663
# R@100: 0.412515
# ======================sgcls  recall without constraint============================
# R@20: 0.437153
# R@50: 0.503754
# R@100: 0.533250
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.0828618723128366
# mR@50:  0.09521855367746371
# mR@100:  0.10004604463833726
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.1387238671067308
# mR@50:  0.22971487760992196
# mR@100:  0.29005917557839545
# /home/alireza/home_at_filer2/tools/anaconda3/envs/kern2/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza/home_at_filer2/tools/anaconda3/envs/kern2/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---Total norm 4.710 clip coef 1.062-----------------
# roi_fmap_obj.0.weight                             : 2.980, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 2.105, (torch.Size([4096, 4096]))
# roi_fmap.1.0.weight                               : 1.318, (torch.Size([4096, 25088]))
# ggnn_rel_reason.obj_proj.weight                   : 0.863, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: 0.830, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.791, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.768, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.649, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.647, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 0.629, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 0.624, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.616, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.587, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: 0.579, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.529, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.494, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.393, (torch.Size([1024, 768]))
# roi_fmap.1.3.weight                               : 0.375, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.266, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.260, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.242, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.237, (torch.Size([512, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.224, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.221, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.221, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.220, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.215, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.190, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.188, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.182, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.181, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.175, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.161, (torch.Size([512, 256, 3, 3]))
# union_boxes.conv.0.weight                         : 0.155, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.147, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.146, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.138, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias: 0.138, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.138, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.136, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.136, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.134, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.114, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.106, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.094, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.090, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.073, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.072, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.070, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.069, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.061, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.061, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.061, (torch.Size([1024]))
# roi_fmap_obj.3.bias                               : 0.057, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.057, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.056, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.050, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.043, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.042, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.042, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.042, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.042, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.029, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.028, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.027, (torch.Size([2048, 2048]))
# roi_fmap_obj.0.bias                               : 0.027, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.026, (torch.Size([512, 1024]))
# union_boxes.conv.6.bias                           : 0.026, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.026, (torch.Size([256, 512]))
# ggnn_rel_reason.rel_proj.bias                     : 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.025, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.023, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.022, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.022, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.021, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.020, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.017, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.017, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.012, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.011, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.010, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.009, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.009, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.006, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.005, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.003, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# union_boxes.conv.2.bias                           : 0.003, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b 1000/14430 0.640s/batch, 153.9m/epoch
# class_loss    0.835762
# rel_loss      0.139013
# total         0.974775
# dtype: float64
# -----------
#
# e 2b 2000/14430 0.640s/batch, 153.8m/epoch
# class_loss    0.824786
# rel_loss      0.137885
# total         0.962671
# dtype: float64
# -----------
#
# e 2b 3000/14430 0.638s/batch, 153.4m/epoch
# class_loss    0.826168
# rel_loss      0.138999
# total         0.965167
# dtype: float64
# -----------
#
# e 2b 4000/14430 0.640s/batch, 153.9m/epoch
# class_loss    0.830606
# rel_loss      0.137869
# total         0.968475
# dtype: float64
# -----------
#
# e 2b 5000/14430 0.717s/batch, 172.3m/epoch
# class_loss    0.830600
# rel_loss      0.136412
# total         0.967012
# dtype: float64
# -----------
#
# e 2b 6000/14430 0.636s/batch, 153.0m/epoch
# class_loss    0.808127
# rel_loss      0.138901
# total         0.947028
# dtype: float64
# -----------
#
# e 2b 7000/14430 0.639s/batch, 153.7m/epoch
# class_loss    0.816073
# rel_loss      0.135884
# total         0.951956
# dtype: float64
# -----------
#
# e 2b 8000/14430 0.636s/batch, 153.0m/epoch
# class_loss    0.818025
# rel_loss      0.137488
# total         0.955513
# dtype: float64
# -----------
#
# e 2b 9000/14430 0.643s/batch, 154.7m/epoch
# class_loss    0.814563
# rel_loss      0.135275
# total         0.949838
# dtype: float64
# -----------
# ---Total norm 7.685 clip coef 0.651-----------------
# roi_fmap_obj.0.weight                             : 4.539, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 3.339, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: 1.573, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 1.563, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 1.546, (torch.Size([3328, 3328]))
# ggnn_rel_reason.obj_proj.weight                   : 1.507, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 1.378, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 1.296, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 1.240, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 1.236, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 1.194, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.188, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: 1.183, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 1.162, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.919, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.869, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.662, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.566, (torch.Size([256, 512]))
# roi_fmap.1.3.weight                               : 0.556, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.546, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.493, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.421, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.402, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.402, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.376, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.372, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.367, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.365, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.349, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.348, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.345, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.344, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.265, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias: 0.241, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.232, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.228, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.224, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.224, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.210, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.200, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.198, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.198, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.186, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.160, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.159, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.146, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.138, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.129, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.111, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.106, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.101, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.099, (torch.Size([256]))
# roi_fmap_obj.3.bias                               : 0.093, (torch.Size([4096]))
# ggnn_rel_reason.obj_proj.bias                     : 0.089, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.087, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.072, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.062, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.061, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.061, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.049, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.049, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.046, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.044, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.043, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.040, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.036, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.036, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.033, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.033, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.032, (torch.Size([512, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.032, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.031, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.029, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.027, (torch.Size([1024, 1024]))
# roi_fmap.1.3.bias                                 : 0.024, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.024, (torch.Size([2048, 2048]))
# union_boxes.conv.0.bias                           : 0.023, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.020, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.018, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.017, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.016, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.016, (torch.Size([1024, 2048]))
# union_boxes.conv.2.weight                         : 0.013, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.012, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.010, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.010, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.004, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.004, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.000, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e 2b10000/14430 0.642s/batch, 154.3m/epoch
# class_loss    0.827756
# rel_loss      0.138174
# total         0.965929
# dtype: float64
# -----------
#
# e 2b11000/14430 0.638s/batch, 153.5m/epoch
# class_loss    0.812028
# rel_loss      0.136049
# total         0.948076
# dtype: float64
# -----------
#
# e 2b12000/14430 0.637s/batch, 153.2m/epoch
# class_loss    0.802035
# rel_loss      0.138608
# total         0.940643
# dtype: float64
# -----------
#
# e 2b13000/14430 0.667s/batch, 160.5m/epoch
# class_loss    0.819694
# rel_loss      0.136048
# total         0.955742
# dtype: float64
# -----------
#
# e 2b14000/14430 0.645s/batch, 155.2m/epoch
# class_loss    0.819714
# rel_loss      0.134889
# total         0.954602
# dtype: float64
# -----------
# overall 2: (0.958)
# class_loss    0.820248
# rel_loss      0.137263
# total         0.957511
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.385386
# R@50: 0.413566
# R@100: 0.419797
# ======================sgcls  recall without constraint============================
# R@20: 0.441731
# R@50: 0.510183
# R@100: 0.541486
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.08006936163516772
# ...
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.039, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.036, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.036, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.035, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.032, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.031, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.031, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.031, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.027, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.027, (torch.Size([2048]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.026, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.016, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.013, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.009, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.009, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.009, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.003, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.001, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e13b10000/14430 0.640s/batch, 154.0m/epoch
# class_loss    0.601305
# rel_loss      0.134859
# total         0.736165
# dtype: float64
# -----------
#
# e13b11000/14430 0.643s/batch, 154.7m/epoch
# class_loss    0.593524
# rel_loss      0.130484
# total         0.724008
# dtype: float64
# -----------
#
# e13b12000/14430 0.637s/batch, 153.2m/epoch
# class_loss    0.606971
# rel_loss      0.132493
# total         0.739465
# dtype: float64
# -----------
#
# e13b13000/14430 0.641s/batch, 154.1m/epoch
# class_loss    0.612649
# rel_loss      0.134169
# total         0.746817
# dtype: float64
# -----------
#
# e13b14000/14430 0.643s/batch, 154.7m/epoch
# class_loss    0.613172
# rel_loss      0.131916
# total         0.745088
# dtype: float64
# -----------
# overall13: (0.736)
# class_loss    0.603782
# rel_loss      0.131959
# total         0.735741
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.397684
# R@50: 0.423630
# R@100: 0.430814
# ======================sgcls  recall without constraint============================
# R@20: 0.453490
# R@50: 0.522759
# R@100: 0.557252
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.09220290216553197
# mR@50:  0.10659551666206413
# mR@100:  0.11026530252846697
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.14217813076316038
# mR@50:  0.25119292087281425
# mR@100:  0.31965887993868103
# ---Total norm 9.806 clip coef 0.510-----------------
# roi_fmap_obj.0.weight                             : 7.002, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 4.216, (torch.Size([4096, 4096]))
# roi_fmap.1.0.weight                               : 3.875, (torch.Size([4096, 25088]))
# ggnn_rel_reason.obj_proj.weight                   : 1.073, (torch.Size([1024, 4096]))
# roi_fmap.1.3.weight                               : 1.066, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 0.991, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 0.984, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.932, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.weight: 0.902, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.weight: 0.837, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.824, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.803, (torch.Size([768, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.weight: 0.787, (torch.Size([3328, 3328]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.weight      : 0.783, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.weight       : 0.731, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.638, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.weight      : 0.613, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.weight: 0.583, (torch.Size([1024, 3328]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.500, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.489, (torch.Size([768, 768]))
# ggnn_rel_reason.rel_proj.weight                   : 0.481, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.462, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.462, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.453, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.428, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.424, (torch.Size([512, 1024]))
# union_boxes.conv.4.weight                         : 0.418, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.378, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.weight: 0.347, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.338, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.316, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.weight: 0.311, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.292, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.289, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.263, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.248, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.242, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.0.linear.bias: 0.238, (torch.Size([3328]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.237, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.weight: 0.212, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.208, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.202, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_ent.model.2.linear.bias: 0.172, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_ent.bias        : 0.161, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_ent.bias        : 0.161, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.weight      : 0.160, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.weight: 0.155, (torch.Size([2048, 2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.148, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.146, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.weight: 0.145, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.0.linear.bias: 0.139, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.weight      : 0.136, (torch.Size([1024, 300]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.weight     : 0.134, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.weight      : 0.114, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.104, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.104, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.100, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.096, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.weight: 0.096, (torch.Size([1024, 2048]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.089, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.089, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.2.linear.bias: 0.081, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.weight     : 0.079, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.078, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.weight      : 0.077, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.075, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.070, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.068, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_ent.bias         : 0.065, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.0.linear.bias: 0.064, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.0.linear.bias: 0.063, (torch.Size([2048]))
# union_boxes.conv.6.bias                           : 0.061, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_ont_pred.bias       : 0.061, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_ont_pred.bias       : 0.061, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_ent.model.0.linear.bias: 0.060, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.059, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.058, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.weight: 0.058, (torch.Size([256, 512]))
# roi_fmap.1.3.bias                                 : 0.056, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.weight: 0.056, (torch.Size([512, 1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.053, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_ont_pred.model.2.linear.bias: 0.050, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.050, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.045, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.043, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.weight      : 0.038, (torch.Size([1024, 1024]))
# union_boxes.conv.6.weight                         : 0.034, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.033, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.030, (torch.Size([1024, 1024]))
# roi_fmap.1.0.bias                                 : 0.028, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.2.linear.bias: 0.027, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_ent.bias        : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_ent.bias        : 0.023, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_init_ont_pred.bias        : 0.021, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_ont_pred.model.0.linear.bias: 0.020, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.weight     : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.019, (torch.Size([1024, 1024]))
# union_boxes.conv.2.weight                         : 0.015, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_ent.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_ent.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.010, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.009, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.weight     : 0.008, (torch.Size([1024, 1024]))
# union_boxes.conv.4.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.weight     : 0.005, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_ont_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_ont_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_ont_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_ont_pred.weight     : 0.002, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_pred.model.2.linear.bias: 0.000, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_ont_ent.model.2.linear.bias: 0.000, (torch.Size([1024]))
# -------------------------------
#
# e14b 1000/14430 0.645s/batch, 155.0m/epoch
# class_loss    0.577410
# rel_loss      0.130599
# total         0.708009
# dtype: float64
# -----------
#
# e14b 2000/14430 0.641s/batch, 154.3m/epoch
# class_loss    0.580600
# rel_loss      0.127971
# total         0.708571
# dtype: float64
# -----------
#
# e14b 3000/14430 0.645s/batch, 155.0m/epoch
# class_loss    0.596283
# rel_loss      0.128640
# total         0.724923
# dtype: float64
# -----------
#
# e14b 4000/14430 0.644s/batch, 154.9m/epoch
# class_loss    0.582246
# rel_loss      0.130071
# total         0.712317
# dtype: float64
# -----------
#
# e14b 5000/14430 0.644s/batch, 154.9m/epoch
# class_loss    0.593777
# rel_loss      0.129949
# total         0.723726
# dtype: float64
# -----------
#
# e14b 6000/14430 0.639s/batch, 153.6m/epoch
# class_loss    0.583145
# rel_loss      0.132556
# total         0.715701
# dtype: float64
# -----------
#
# e14b 7000/14430 0.641s/batch, 154.1m/epoch
# class_loss    0.587123
# rel_loss      0.130108
# total         0.717231
# dtype: float64
# -----------
