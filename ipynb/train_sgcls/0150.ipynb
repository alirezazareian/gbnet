# %%
import numpy as np
np.random.seed(1244)
import torch
torch.manual_seed(1245)
torch.__version__
# Out:
# '0.3.0.post4'

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
codebase = '../../'
sys.path.append(codebase)

# %%
exp_name = 'exp_150'
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
from dataloaders.visual_genome import VGDataLoader, VG
import numpy as np
from torch import optim
import torch
import pandas as pd
import time
import os

from config import ModelConfig, BOX_SCALE, IM_SCALE
from torch.nn import functional as F
from lib.pytorch_misc import optimistic_restore, de_chunkize, clip_grad_norm
from lib.evaluation.sg_eval import BasicSceneGraphEvaluator, calculate_mR_from_evaluator_list, eval_entry
from lib.pytorch_misc import print_para
from torch.optim.lr_scheduler import ReduceLROnPlateau

from lib.my_model_34 import KERN

# %%
conf = ModelConfig(f'''
-m sgcls -p 1000 -clip 5 
-tb_log_dir summaries/kern_sgcls/{exp_name} 
-save_dir checkpoints/kern_sgcls/{exp_name}
-ckpt checkpoints/kern_predcls/exp_140/vgrel-10.tar
-val_size 5000 
-adam 
-b 4
-ngpu 1
-lr 1e-5 
''')
# Out:
# ~~~~~~~~ Hyperparameters used: ~~~~~~~
# ckpt : checkpoints/kern_predcls/exp_140/vgrel-10.tar
# save_dir : checkpoints/kern_sgcls/exp_150
# num_gpus : 1
# num_workers : 1
# lr : 1e-05
# batch_size : 4
# val_size : 5000
# l2 : 0.0001
# adamwd : 0.0
# clip : 5.0
# print_interval : 1000
# mode : sgcls
# cache :
# adam : True
# test : False
# num_epochs : 50
# use_resnet : False
# use_proposals : False
# pooling_dim : 4096
# use_ggnn_obj : False
# ggnn_obj_time_step_num : 3
# ggnn_obj_hidden_dim : 512
# ggnn_obj_output_dim : 512
# use_obj_knowledge : False
# obj_knowledge :
# use_ggnn_rel : False
# ggnn_rel_time_step_num : 3
# ggnn_rel_hidden_dim : 512
# ggnn_rel_output_dim : 512
# use_rel_knowledge : False
# rel_knowledge :
# tb_log_dir : summaries/kern_sgcls/exp_150
# save_rel_recall :

# %%
train, val, _ = VG.splits(num_val_im=conf.val_size, filter_duplicate_rels=True,
                          use_proposals=conf.use_proposals,
                          filter_non_overlap=conf.mode == 'sgdet')

# %%
ind_to_predicates = train.ind_to_predicates # ind_to_predicates[0] means no relationship

# %%
train_loader, val_loader = VGDataLoader.splits(train, val, mode='rel',
                                               batch_size=conf.batch_size,
                                               num_workers=conf.num_workers,
                                               num_gpus=conf.num_gpus)

# %%
detector = KERN(classes=train.ind_to_classes, rel_classes=train.ind_to_predicates,
                num_gpus=conf.num_gpus, mode=conf.mode, require_overlap_det=True,
                use_resnet=conf.use_resnet, use_proposals=conf.use_proposals, pooling_dim=conf.pooling_dim,
                ggnn_rel_time_step_num=3, ggnn_rel_hidden_dim=1024, ggnn_rel_output_dim=None,
                graph_path=os.path.join(codebase, 'graphs/005/all_edges.pkl'), 
                emb_path=os.path.join(codebase, 'graphs/001/emb_mtx.pkl'), 
                rel_counts_path=os.path.join(codebase, 'graphs/001/pred_counts.pkl'), 
                use_knowledge=True, use_embedding=True, refine_obj_cls=True,
                class_volume=1.0, top_k_to_keep=5, normalize_messages=False,
               )

# %%
# Freeze the detector
for n, param in detector.detector.named_parameters():
    param.requires_grad = False

# %%
print(print_para(detector), flush=True)
# Out:
#  407.0M total parameters
#  -----
#
# detector.roi_fmap.0.weight                        : [4096,25088]    (102760448) (    )
# roi_fmap.1.0.weight                               : [4096,25088]    (102760448) (grad)
# roi_fmap_obj.0.weight                             : [4096,25088]    (102760448) (grad)
# detector.roi_fmap.3.weight                        : [4096,4096]     (16777216) (    )
# roi_fmap.1.3.weight                               : [4096,4096]     (16777216) (grad)
# roi_fmap_obj.3.weight                             : [4096,4096]     (16777216) (grad)
# ggnn_rel_reason.obj_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# ggnn_rel_reason.rel_proj.weight                   : [1024,4096]     ( 4194304) (grad)
# detector.bbox_fc.weight                           : [604,4096]      ( 2473984) (    )
# detector.features.19.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.21.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.24.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.26.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.features.28.weight                       : [512,512,3,3]   ( 2359296) (    )
# detector.rpn_head.conv.0.weight                   : [512,512,3,3]   ( 2359296) (    )
# detector.features.17.weight                       : [512,256,3,3]   ( 1179648) (    )
# union_boxes.conv.4.weight                         : [512,256,3,3]   ( 1179648) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: [1024,1024]     ( 1048576) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: [1024,768]      (  786432) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: [1024,768]      (  786432) (grad)
# detector.score_fc.weight                          : [151,4096]      (  618496) (    )
# detector.features.12.weight                       : [256,256,3,3]   (  589824) (    )
# detector.features.14.weight                       : [256,256,3,3]   (  589824) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: [512,1024]      (  524288) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: [768,512]       (  393216) (grad)
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: [768,512]       (  393216) (grad)
# detector.features.10.weight                       : [256,128,3,3]   (  294912) (    )
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: [151,1024]      (  154624) (grad)
# detector.features.7.weight                        : [128,128,3,3]   (  147456) (    )
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: [256,512]       (  131072) (grad)
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: [256,512]       (  131072) (grad)
# detector.features.5.weight                        : [128,64,3,3]    (   73728) (    )
# detector.rpn_head.conv.2.weight                   : [120,512,1,1]   (   61440) (    )
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: [51,1024]       (   52224) (grad)
# detector.features.2.weight                        : [64,64,3,3]     (   36864) (    )
# union_boxes.conv.0.weight                         : [256,2,7,7]     (   25088) (grad)
# detector.features.0.weight                        : [64,3,3,3]      (    1728) (    )
# union_boxes.conv.6.weight                         : [512]           (     512) (grad)
# union_boxes.conv.2.weight                         : [256]           (     256) (grad)

# %%
def get_optim(lr):
    # Lower the learning rate on the VGG fully connected layers by 1/10th. It's a hack, but it helps
    # stabilize the models.
    fc_params = [p for n,p in detector.named_parameters() if n.startswith('roi_fmap') and p.requires_grad]
    non_fc_params = [p for n,p in detector.named_parameters() if not n.startswith('roi_fmap') and p.requires_grad]
    params = [{'params': fc_params, 'lr': lr / 10.0}, {'params': non_fc_params}]
    # params = [p for n,p in detector.named_parameters() if p.requires_grad]

    if conf.adam:
        optimizer = optim.Adam(params, weight_decay=conf.adamwd, lr=lr, eps=1e-3)
    else:
        optimizer = optim.SGD(params, weight_decay=conf.l2, lr=lr, momentum=0.9)

    # scheduler = ReduceLROnPlateau(optimizer, 'max', patience=3, factor=0.1,
    #                               verbose=True, threshold=0.0001, threshold_mode='abs', cooldown=1)
    return optimizer #, scheduler

# %%
ckpt = torch.load(conf.ckpt)

# %%
if conf.ckpt.split('-')[-2].split('/')[-1] == 'vgrel':
    print("Loading EVERYTHING")
    start_epoch = ckpt['epoch']

    if not optimistic_restore(detector, ckpt['state_dict']):
        start_epoch = -1
        # optimistic_restore(detector.detector, torch.load('checkpoints/vgdet/vg-28.tar')['state_dict'])
else:
    start_epoch = -1
    optimistic_restore(detector.detector, ckpt['state_dict'])

    detector.roi_fmap[1][0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap[1][3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap[1][0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap[1][3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])

    detector.roi_fmap_obj[0].weight.data.copy_(ckpt['state_dict']['roi_fmap.0.weight'])
    detector.roi_fmap_obj[3].weight.data.copy_(ckpt['state_dict']['roi_fmap.3.weight'])
    detector.roi_fmap_obj[0].bias.data.copy_(ckpt['state_dict']['roi_fmap.0.bias'])
    detector.roi_fmap_obj[3].bias.data.copy_(ckpt['state_dict']['roi_fmap.3.bias'])
# Out:
# Loading EVERYTHING
# We couldn't find ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias,ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight

# %%
detector.cuda();

# %%
def train_epoch(epoch_num):
    detector.train()
    tr = []
    start = time.time()
    for b, batch in enumerate(train_loader):
        result, loss_pd = train_batch(batch, verbose=b % (conf.print_interval*10) == 0)
        tr.append(loss_pd)
        '''
        if b % 100 == 0:
            print(loss_pd)
            gt = result.rel_labels[:,3].data.cpu().numpy()
            out = result.rel_dists.data.cpu().numpy()
            ind = np.where(gt)[0]
            print(gt[ind])
            print(np.argmax(out[ind], 1))
            print(np.argmax(out[ind, 1:], 1) + 1)
        '''

        if b % conf.print_interval == 0 and b >= conf.print_interval:
            mn = pd.concat(tr[-conf.print_interval:], axis=1).mean(1)
            time_per_batch = (time.time() - start) / conf.print_interval
            print("\ne{:2d}b{:5d}/{:5d} {:.3f}s/batch, {:.1f}m/epoch".format(
                epoch_num, b, len(train_loader), time_per_batch, len(train_loader) * time_per_batch / 60))
            print(mn)
            print('-----------', flush=True)
            start = time.time()
    return pd.concat(tr, axis=1)

# %%
def train_batch(b, verbose=False):
    """
    :param b: contains:
          :param imgs: the image, [batch_size, 3, IM_SIZE, IM_SIZE]
          :param all_anchors: [num_anchors, 4] the boxes of all anchors that we'll be using
          :param all_anchor_inds: [num_anchors, 2] array of the indices into the concatenated
                                  RPN feature vector that give us all_anchors,
                                  each one (img_ind, fpn_idx)
          :param im_sizes: a [batch_size, 4] numpy array of (h, w, scale, num_good_anchors) for each image.

          :param num_anchors_per_img: int, number of anchors in total over the feature pyramid per img

          Training parameters:
          :param train_anchor_inds: a [num_train, 5] array of indices for the anchors that will
                                    be used to compute the training loss (img_ind, fpn_idx)
          :param gt_boxes: [num_gt, 4] GT boxes over the batch.
          :param gt_classes: [num_gt, 2] gt boxes where each one is (img_id, class)
    :return:
    """
    result = detector[b]

    losses = {}
    losses['class_loss'] = detector.obj_loss(result)
    losses['rel_loss'] = detector.rel_loss(result)
    loss = sum(losses.values())

    optimizer.zero_grad()
    loss.backward()
    clip_grad_norm(
        [(n, p) for n, p in detector.named_parameters() if p.grad is not None],
        max_norm=conf.clip, verbose=verbose, clip=True)
    losses['total'] = loss
    optimizer.step()
    loss_pd = pd.Series({x: y.data[0] for x, y in losses.items()})
    return result, loss_pd

# %%
def val_epoch():
    detector.eval()
    evaluator_list = [] # for calculating recall of each relationship except no relationship
    evaluator_multiple_preds_list = []
    for index, name in enumerate(ind_to_predicates):
        if index == 0:
            continue
        evaluator_list.append((index, name, BasicSceneGraphEvaluator.all_modes()))
        evaluator_multiple_preds_list.append((index, name, BasicSceneGraphEvaluator.all_modes(multiple_preds=True)))
    evaluator = BasicSceneGraphEvaluator.all_modes() # for calculating recall
    evaluator_multiple_preds = BasicSceneGraphEvaluator.all_modes(multiple_preds=True)
    for val_b, batch in enumerate(val_loader):
        val_batch(conf.num_gpus * val_b, batch, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list)

    recall = evaluator[conf.mode].print_stats()
    recall_mp = evaluator_multiple_preds[conf.mode].print_stats()
    
    mean_recall = calculate_mR_from_evaluator_list(evaluator_list, conf.mode)
    mean_recall_mp = calculate_mR_from_evaluator_list(evaluator_multiple_preds_list, conf.mode, multiple_preds=True)
    
    detector.train()
    return recall, recall_mp, mean_recall, mean_recall_mp

# %%
def val_batch(batch_num, b, evaluator, evaluator_multiple_preds, evaluator_list, evaluator_multiple_preds_list):
    det_res = detector[b]
    if conf.num_gpus == 1:
        det_res = [det_res]

    for i, (boxes_i, objs_i, obj_scores_i, rels_i, pred_scores_i) in enumerate(det_res):
        gt_entry = {
            'gt_classes': val.gt_classes[batch_num + i].copy(),
            'gt_relations': val.relationships[batch_num + i].copy(),
            'gt_boxes': val.gt_boxes[batch_num + i].copy(),
        }
        assert np.all(objs_i[rels_i[:, 0]] > 0) and np.all(objs_i[rels_i[:, 1]] > 0)

        pred_entry = {
            'pred_boxes': boxes_i * BOX_SCALE/IM_SCALE,
            'pred_classes': objs_i,
            'pred_rel_inds': rels_i,
            'obj_scores': obj_scores_i,
            'rel_scores': pred_scores_i,  # hack for now.
        }

        eval_entry(conf.mode, gt_entry, pred_entry, evaluator, evaluator_multiple_preds, 
                   evaluator_list, evaluator_multiple_preds_list)

# %%
if conf.tb_log_dir is not None:
    from tensorboardX import SummaryWriter
    if not os.path.exists(conf.tb_log_dir):
        os.makedirs(conf.tb_log_dir) 
    writer = SummaryWriter(log_dir=conf.tb_log_dir)
    use_tb = True
else:
    use_tb = False

# %%
optimizer = get_optim(conf.lr * conf.num_gpus * conf.batch_size)

# %%
print("Training starts now!")

for epoch in range(1, 16):
    rez = train_epoch(epoch)
    print("overall{:2d}: ({:.3f})\n{}".format(epoch, rez.mean(1)['total'], rez.mean(1)), flush=True)

    if use_tb:
        writer.add_scalar('loss/rel_loss', rez.mean(1)['rel_loss'], epoch)
        writer.add_scalar('loss/class_loss', rez.mean(1)['class_loss'], epoch)
        writer.add_scalar('loss/total', rez.mean(1)['total'], epoch)

    if conf.save_dir is not None:
        torch.save({
            'epoch': epoch,
            'state_dict': detector.state_dict(), #{k:v for k,v in detector.state_dict().items() if not k.startswith('detector.')},
            # 'optimizer': optimizer.state_dict(),
        }, os.path.join(conf.save_dir, '{}-{}.tar'.format('vgrel', epoch)))

    recall, recall_mp, mean_recall, mean_recall_mp = val_epoch()
    if use_tb:
        for key, value in recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/' + key, value, epoch)
        for key, value in recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/' + key, value, epoch)
        for key, value in mean_recall.items():
            writer.add_scalar('eval_' + conf.mode + '_with_constraint/mean ' + key, value, epoch)
        for key, value in mean_recall_mp.items():
            writer.add_scalar('eval_' + conf.mode + '_without_constraint/mean ' + key, value, epoch)
# Out:
# Training starts now!
# ---Total norm 1.288 clip coef 3.883-----------------
# roi_fmap_obj.3.weight                             : 0.553, (torch.Size([4096, 4096]))
# roi_fmap_obj.0.weight                             : 0.531, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 0.435, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.412, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.368, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.367, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 0.351, (torch.Size([151, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.289, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.181, (torch.Size([151]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.159, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.154, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.146, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.146, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.136, (torch.Size([1024, 768]))
# roi_fmap.1.3.weight                               : 0.130, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.098, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.097, (torch.Size([768, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.088, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.081, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.072, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.067, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.067, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.061, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.059, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.053, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.051, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.050, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.042, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.038, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.037, (torch.Size([768]))
# union_boxes.conv.4.weight                         : 0.036, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.025, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.024, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.024, (torch.Size([256, 2, 7, 7]))
# roi_fmap_obj.3.bias                               : 0.015, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.012, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.008, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.008, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.007, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# union_boxes.conv.6.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.005, (torch.Size([512]))
# roi_fmap_obj.0.bias                               : 0.004, (torch.Size([4096]))
# union_boxes.conv.6.weight                         : 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.003, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.003, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.003, (torch.Size([4096]))
# roi_fmap.1.0.bias                                 : 0.002, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.001, (torch.Size([512]))
# -------------------------------
#
# e 1b 1000/14430 0.320s/batch, 76.9m/epoch
# class_loss    3.318532
# rel_loss      0.140817
# total         3.459349
# dtype: float64
# -----------
#
# e 1b 2000/14430 0.317s/batch, 76.1m/epoch
# class_loss    1.244500
# rel_loss      0.148707
# total         1.393207
# dtype: float64
# -----------
#
# e 1b 3000/14430 0.320s/batch, 76.9m/epoch
# class_loss    1.047785
# rel_loss      0.145378
# total         1.193163
# dtype: float64
# -----------
#
# e 1b 4000/14430 0.317s/batch, 76.3m/epoch
# class_loss    1.002159
# rel_loss      0.146650
# total         1.148810
# dtype: float64
# -----------
#
# e 1b 5000/14430 0.317s/batch, 76.3m/epoch
# class_loss    0.979857
# rel_loss      0.145782
# total         1.125640
# dtype: float64
# -----------
#
# e 1b 6000/14430 0.318s/batch, 76.4m/epoch
# class_loss    0.953077
# rel_loss      0.142496
# total         1.095573
# dtype: float64
# -----------
#
# e 1b 7000/14430 0.317s/batch, 76.3m/epoch
# class_loss    0.918621
# rel_loss      0.144916
# total         1.063537
# dtype: float64
# -----------
#
# e 1b 8000/14430 0.319s/batch, 76.6m/epoch
# class_loss    0.916725
# rel_loss      0.141065
# total         1.057790
# dtype: float64
# -----------
#
# e 1b 9000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.899691
# rel_loss      0.143114
# total         1.042805
# dtype: float64
# -----------
# ---Total norm 11.654 clip coef 0.429-----------------
# roi_fmap_obj.0.weight                             : 7.995, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 4.918, (torch.Size([151, 1024]))
# roi_fmap_obj.3.weight                             : 4.688, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 3.367, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 2.869, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 1.741, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 1.055, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.726, (torch.Size([1024, 768]))
# roi_fmap.1.0.weight                               : 0.605, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.470, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.441, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.326, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.263, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.245, (torch.Size([256, 512]))
# roi_fmap.1.3.weight                               : 0.237, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.229, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.207, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.194, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.188, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.186, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.153, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.151, (torch.Size([151]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.150, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.145, (torch.Size([1024, 768]))
# ggnn_rel_reason.obj_proj.bias                     : 0.140, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.138, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.134, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.133, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.115, (torch.Size([4096]))
# union_boxes.conv.4.weight                         : 0.111, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.107, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.087, (torch.Size([256, 2, 7, 7]))
# roi_fmap_obj.0.bias                               : 0.076, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.067, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.040, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.030, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.023, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.018, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.017, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.016, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.016, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.014, (torch.Size([768]))
# union_boxes.conv.0.bias                           : 0.013, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.008, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.007, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# union_boxes.conv.2.weight                         : 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.005, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.003, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# -------------------------------
#
# e 1b10000/14430 0.320s/batch, 76.9m/epoch
# class_loss    0.898255
# rel_loss      0.138621
# total         1.036875
# dtype: float64
# -----------
#
# e 1b11000/14430 0.321s/batch, 77.1m/epoch
# class_loss    0.891443
# rel_loss      0.140787
# total         1.032230
# dtype: float64
# -----------
#
# e 1b12000/14430 0.319s/batch, 76.7m/epoch
# class_loss    0.882992
# rel_loss      0.138098
# total         1.021090
# dtype: float64
# -----------
#
# e 1b13000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.882487
# rel_loss      0.140477
# total         1.022964
# dtype: float64
# -----------
#
# e 1b14000/14430 0.319s/batch, 76.6m/epoch
# class_loss    0.868435
# rel_loss      0.141641
# total         1.010076
# dtype: float64
# -----------
# overall 1: (1.257)
# class_loss    1.114574
# rel_loss      0.142700
# total         1.257274
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.375702
# R@50: 0.402639
# R@100: 0.408868
# ======================sgcls  recall without constraint============================
# R@20: 0.425321
# R@50: 0.494105
# R@100: 0.525216
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.081487222770864
# mR@50:  0.09407327135646396
# mR@100:  0.09879376609413278
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.1331769874877828
# mR@50:  0.2193203114404117
# mR@100:  0.2777164145413505
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/alireza_z1992/.conda/envs/kern/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---Total norm 11.786 clip coef 0.424-----------------
# roi_fmap_obj.0.weight                             : 7.626, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 5.193, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 4.805, (torch.Size([151, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 3.351, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 3.124, (torch.Size([1024, 4096]))
# roi_fmap.1.0.weight                               : 1.545, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 1.463, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 1.004, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.915, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.687, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.599, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.564, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.532, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.513, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.441, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.437, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.427, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.422, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.392, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.381, (torch.Size([1024, 768]))
# ggnn_rel_reason.rel_proj.weight                   : 0.326, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.268, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.265, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.234, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.234, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.214, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.214, (torch.Size([512, 256, 3, 3]))
# union_boxes.conv.0.weight                         : 0.162, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.145, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.133, (torch.Size([151]))
# ggnn_rel_reason.obj_proj.bias                     : 0.120, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.109, (torch.Size([1024, 1024]))
# roi_fmap_obj.3.bias                               : 0.109, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.092, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.061, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.059, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.056, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.052, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.046, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.041, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.037, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.028, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.028, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.025, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.023, (torch.Size([256]))
# union_boxes.conv.0.bias                           : 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.018, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.017, (torch.Size([768]))
# roi_fmap.1.3.bias                                 : 0.016, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.013, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.012, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.012, (torch.Size([4096]))
# union_boxes.conv.2.weight                         : 0.010, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.010, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.005, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.005, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.003, (torch.Size([1024]))
# -------------------------------
#
# e 2b 1000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.853827
# rel_loss      0.140459
# total         0.994286
# dtype: float64
# -----------
#
# e 2b 2000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.841663
# rel_loss      0.138840
# total         0.980502
# dtype: float64
# -----------
#
# e 2b 3000/14430 0.318s/batch, 76.5m/epoch
# class_loss    0.861534
# rel_loss      0.140092
# total         1.001626
# dtype: float64
# -----------
#
# e 2b 4000/14430 0.318s/batch, 76.5m/epoch
# class_loss    0.850710
# rel_loss      0.136836
# total         0.987546
# dtype: float64
# -----------
#
# e 2b 5000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.832428
# rel_loss      0.139018
# total         0.971445
# dtype: float64
# -----------
#
# e 2b 6000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.834798
# rel_loss      0.140181
# total         0.974979
# dtype: float64
# -----------
#
# e 2b 7000/14430 0.318s/batch, 76.4m/epoch
# class_loss    0.847825
# rel_loss      0.136722
# total         0.984548
# dtype: float64
# -----------
#
# e 2b 8000/14430 0.319s/batch, 76.8m/epoch
# class_loss    0.832672
# rel_loss      0.136761
# total         0.969433
# dtype: float64
# -----------
#
# e 2b 9000/14430 0.319s/batch, 76.7m/epoch
# class_loss    0.848271
# rel_loss      0.138909
# total         0.987180
# dtype: float64
# -----------
# ---Total norm 9.519 clip coef 0.525-----------------
# roi_fmap_obj.0.weight                             : 7.098, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 4.782, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 2.553, (torch.Size([151, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 2.251, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.950, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.807, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.614, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.591, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.322, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.283, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.259, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.223, (torch.Size([51, 1024]))
# roi_fmap.1.3.weight                               : 0.219, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.200, (torch.Size([768, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.136, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.130, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.129, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.119, (torch.Size([256, 512]))
# union_boxes.conv.0.weight                         : 0.117, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.116, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.115, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.103, (torch.Size([768, 512]))
# roi_fmap_obj.3.bias                               : 0.100, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.097, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.095, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.094, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.091, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.084, (torch.Size([1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.084, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.076, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.076, (torch.Size([151]))
# roi_fmap_obj.0.bias                               : 0.062, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.059, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.047, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.017, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.017, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.014, (torch.Size([1024, 1024]))
# union_boxes.conv.0.bias                           : 0.013, (torch.Size([256]))
# union_boxes.conv.6.bias                           : 0.012, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.011, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.007, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.006, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.005, (torch.Size([512]))
# roi_fmap.1.3.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# roi_fmap.1.0.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.003, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.002, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.001, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# -------------------------------
#
# e 2b10000/14430 0.319s/batch, 76.8m/epoch
# class_loss    0.831583
# rel_loss      0.136867
# total         0.968450
# dtype: float64
# -----------
#
# e 2b11000/14430 0.319s/batch, 76.8m/epoch
# class_loss    0.836469
# rel_loss      0.135466
# total         0.971935
# dtype: float64
# -----------
#
# e 2b12000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.829713
# rel_loss      0.137960
# total         0.967674
# dtype: float64
# -----------
#
# e 2b13000/14430 0.319s/batch, 76.8m/epoch
# class_loss    0.835254
# rel_loss      0.136225
# total         0.971479
# dtype: float64
# -----------
#
# e 2b14000/14430 0.317s/batch, 76.3m/epoch
# class_loss    0.839879
# rel_loss      0.140078
# total         0.979957
# dtype: float64
# -----------
# overall 2: (0.980)
# class_loss    0.841318
# rel_loss      0.138227
# total         0.979545
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.379185
# R@50: 0.407249
# R@100: 0.413506
# ======================sgcls  recall without constraint============================
# R@20: 0.430957
# R@50: 0.497256
# R@100: 0.528908
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.08056010827690732
# mR@50:  0.09352765867869653
# mR@100:  0.09719625265419536
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.13243681989795453
# mR@50:  0.22758677398352312
# mR@100:  0.28316510027069286
# ---Total norm 7.923 clip coef 0.631-----------------
# roi_fmap_obj.0.weight                             : 5.295, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 4.289, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 2.685, (torch.Size([151, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 2.003, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.844, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.775, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.586, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.526, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.288, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.270, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.226, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.204, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.192, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.178, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.173, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.138, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.114, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.112, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.106, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.102, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.094, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.091, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.089, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.087, (torch.Size([151]))
# ggnn_rel_reason.obj_proj.bias                     : 0.086, (torch.Size([1024]))
# union_boxes.conv.4.weight                         : 0.086, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.083, (torch.Size([256, 512]))
# roi_fmap_obj.3.bias                               : 0.082, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.081, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.080, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.076, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.054, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.052, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.036, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.025, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.019, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.017, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.015, (torch.Size([512]))
# union_boxes.conv.6.weight                         : 0.012, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.010, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.009, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.008, (torch.Size([768]))
# union_boxes.conv.0.bias                           : 0.007, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.006, (torch.Size([1024]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.004, (torch.Size([512]))
# ggnn_rel_reason.rel_proj.bias                     : 0.004, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.004, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.004, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.004, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# -------------------------------
#
# e 3b 1000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.807899
# rel_loss      0.138319
# total         0.946218
# dtype: float64
# -----------
#
# e 3b 2000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.805996
# rel_loss      0.137742
# total         0.943738
# dtype: float64
# -----------
#
# e 3b 3000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.799295
# rel_loss      0.137471
# total         0.936766
# dtype: float64
# -----------
#
# e 3b 4000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.806554
# rel_loss      0.140419
# total         0.946973
# dtype: float64
# -----------
#
# e 3b 5000/14430 0.320s/batch, 76.9m/epoch
# class_loss    0.799806
# rel_loss      0.134370
# total         0.934176
# dtype: float64
# -----------
#
# e 3b 6000/14430 0.318s/batch, 76.4m/epoch
# class_loss    0.816251
# rel_loss      0.137212
# total         0.953463
# dtype: float64
# -----------
#
# e 3b 7000/14430 0.318s/batch, 76.6m/epoch
# class_loss    0.801835
# rel_loss      0.135708
# total         0.937544
# dtype: float64
# -----------
#
# e 3b 8000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.800367
# rel_loss      0.138053
# total         0.938420
# dtype: float64
# -----------
#
# e 3b 9000/14430 0.320s/batch, 76.9m/epoch
# class_loss    0.809843
# rel_loss      0.133571
# total         0.943414
# dtype: float64
# -----------
# ---Total norm 8.197 clip coef 0.610-----------------
# roi_fmap_obj.0.weight                             : 6.720, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 3.371, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 2.269, (torch.Size([151, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 1.441, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.389, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.709, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.561, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.464, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.306, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.233, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.224, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.210, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.174, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.156, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.143, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.130, (torch.Size([51, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.120, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.119, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.109, (torch.Size([768, 512]))
# roi_fmap_obj.3.bias                               : 0.106, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.098, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.095, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.092, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.092, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.090, (torch.Size([256, 512]))
# ggnn_rel_reason.obj_proj.bias                     : 0.089, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.088, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.087, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.085, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.084, (torch.Size([151]))
# roi_fmap_obj.0.bias                               : 0.060, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.058, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.057, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.039, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.022, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.021, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.012, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.012, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.012, (torch.Size([1024]))
# union_boxes.conv.6.weight                         : 0.011, (torch.Size([512]))
# union_boxes.conv.0.bias                           : 0.011, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.009, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.009, (torch.Size([256]))
# roi_fmap.1.3.bias                                 : 0.008, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.007, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.006, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.005, (torch.Size([768]))
# roi_fmap.1.0.bias                                 : 0.005, (torch.Size([4096]))
# union_boxes.conv.2.weight                         : 0.005, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.004, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# -------------------------------
#
# e 3b10000/14430 0.319s/batch, 76.6m/epoch
# class_loss    0.795861
# rel_loss      0.136999
# total         0.932860
# dtype: float64
# -----------
#
# e 3b11000/14430 0.319s/batch, 76.7m/epoch
# class_loss    0.800870
# rel_loss      0.137064
# total         0.937935
# dtype: float64
# -----------
#
# e 3b12000/14430 0.318s/batch, 76.4m/epoch
# class_loss    0.801748
# rel_loss      0.137020
# total         0.938768
# dtype: float64
# -----------
#
# e 3b13000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.812467
# rel_loss      0.136552
# total         0.949019
# dtype: float64
# -----------
#
# e 3b14000/14430 0.320s/batch, 76.9m/epoch
# class_loss    0.799141
# rel_loss      0.135428
# total         0.934570
# dtype: float64
# -----------
# overall 3: (0.941)
# class_loss    0.803693
# rel_loss      0.136926
# total         0.940619
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.385131
# R@50: 0.412642
# R@100: 0.419209
# ======================sgcls  recall without constraint============================
# R@20: 0.436499
# R@50: 0.507084
# R@100: 0.538592
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.08419646420617985
# mR@50:  0.09834258782093075
# mR@100:  0.10206365192115896
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.1356609847896211
# mR@50:  0.23647838755458556
# mR@100:  0.2961105320633871
# ---Total norm 6.265 clip coef 0.798-----------------
# roi_fmap_obj.0.weight                             : 4.999, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 2.795, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 1.710, (torch.Size([151, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.157, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 1.148, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.466, (torch.Size([1024, 1024]))
# roi_fmap.1.0.weight                               : 0.434, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.325, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.235, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.225, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.174, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.158, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.157, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.151, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.150, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.135, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.111, (torch.Size([1024, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.110, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.101, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.090, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.083, (torch.Size([768, 512]))
# roi_fmap_obj.3.bias                               : 0.078, (torch.Size([4096]))
# union_boxes.conv.4.weight                         : 0.076, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.073, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.071, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.068, (torch.Size([1024]))
# union_boxes.conv.0.weight                         : 0.068, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.obj_proj.bias                     : 0.064, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.063, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.060, (torch.Size([151]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.052, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.048, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.042, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.030, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.020, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.014, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.012, (torch.Size([51]))
# ...
# rel_loss      0.132788
# total         0.745124
# dtype: float64
# -----------
#
# e14b11000/14430 0.313s/batch, 75.3m/epoch
# class_loss    0.615192
# rel_loss      0.134949
# total         0.750141
# dtype: float64
# -----------
#
# e14b12000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.613813
# rel_loss      0.128815
# total         0.742628
# dtype: float64
# -----------
#
# e14b13000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.629483
# rel_loss      0.133371
# total         0.762853
# dtype: float64
# -----------
#
# e14b14000/14430 0.315s/batch, 75.7m/epoch
# class_loss    0.617970
# rel_loss      0.134364
# total         0.752334
# dtype: float64
# -----------
# overall14: (0.746)
# class_loss    0.613108
# rel_loss      0.132869
# total         0.745977
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.391507
# R@50: 0.419444
# R@100: 0.426565
# ======================sgcls  recall without constraint============================
# R@20: 0.447187
# R@50: 0.516853
# R@100: 0.548981
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.08406132005625562
# mR@50:  0.09730410955309717
# mR@100:  0.1034843056404622
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.14040792428354018
# mR@50:  0.2394956241883337
# mR@100:  0.29850870237767707
# ---Total norm 11.264 clip coef 0.444-----------------
# roi_fmap_obj.0.weight                             : 9.255, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 5.094, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 2.321, (torch.Size([151, 1024]))
# roi_fmap.1.0.weight                               : 1.618, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.416, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 1.404, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.873, (torch.Size([1024, 1024]))
# roi_fmap.1.3.weight                               : 0.617, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.517, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.476, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.454, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.429, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.407, (torch.Size([256, 512]))
# ggnn_rel_reason.rel_proj.weight                   : 0.392, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.329, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.323, (torch.Size([1024, 1024]))
# union_boxes.conv.4.weight                         : 0.299, (torch.Size([512, 256, 3, 3]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.298, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.271, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.263, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.236, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.226, (torch.Size([256, 512]))
# roi_fmap_obj.3.bias                               : 0.204, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.202, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.202, (torch.Size([1024, 1024]))
# union_boxes.conv.0.weight                         : 0.198, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.190, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.162, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.160, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.118, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.094, (torch.Size([1024]))
# roi_fmap_obj.0.bias                               : 0.091, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.080, (torch.Size([151]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.074, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.065, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.046, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.043, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.028, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.028, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.028, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.028, (torch.Size([512]))
# roi_fmap.1.3.bias                                 : 0.022, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.022, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.022, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.021, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.019, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.rel_proj.bias                     : 0.018, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.016, (torch.Size([51]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.016, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.015, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.015, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.015, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.014, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.014, (torch.Size([256]))
# union_boxes.conv.2.weight                         : 0.013, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.010, (torch.Size([1024]))
# union_boxes.conv.2.bias                           : 0.009, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.008, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.008, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.006, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.003, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.002, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.002, (torch.Size([1024]))
# -------------------------------
#
# e15b 1000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.595049
# rel_loss      0.131998
# total         0.727047
# dtype: float64
# -----------
#
# e15b 2000/14430 0.315s/batch, 75.9m/epoch
# class_loss    0.594614
# rel_loss      0.132431
# total         0.727045
# dtype: float64
# -----------
#
# e15b 3000/14430 0.313s/batch, 75.3m/epoch
# class_loss    0.585586
# rel_loss      0.133545
# total         0.719131
# dtype: float64
# -----------
#
# e15b 4000/14430 0.315s/batch, 75.7m/epoch
# class_loss    0.604840
# rel_loss      0.131197
# total         0.736037
# dtype: float64
# -----------
#
# e15b 5000/14430 0.314s/batch, 75.5m/epoch
# class_loss    0.599045
# rel_loss      0.131841
# total         0.730885
# dtype: float64
# -----------
#
# e15b 6000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.607842
# rel_loss      0.131800
# total         0.739642
# dtype: float64
# -----------
#
# e15b 7000/14430 0.313s/batch, 75.2m/epoch
# class_loss    0.604095
# rel_loss      0.133862
# total         0.737957
# dtype: float64
# -----------
#
# e15b 8000/14430 0.314s/batch, 75.5m/epoch
# class_loss    0.592303
# rel_loss      0.133582
# total         0.725885
# dtype: float64
# -----------
#
# e15b 9000/14430 0.315s/batch, 75.9m/epoch
# class_loss    0.60369
# rel_loss      0.13122
# total         0.73491
# dtype: float64
# -----------
# ---Total norm 9.180 clip coef 0.545-----------------
# roi_fmap_obj.0.weight                             : 7.957, (torch.Size([4096, 25088]))
# roi_fmap_obj.3.weight                             : 3.633, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.weight: 1.849, (torch.Size([151, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.weight: 1.032, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.weight                   : 0.985, (torch.Size([1024, 4096]))
# roi_fmap.1.0.weight                               : 0.950, (torch.Size([4096, 25088]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.weight      : 0.536, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.weight      : 0.375, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.weight: 0.350, (torch.Size([768, 512]))
# roi_fmap.1.3.weight                               : 0.346, (torch.Size([4096, 4096]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.weight: 0.322, (torch.Size([256, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.weight: 0.292, (torch.Size([1024, 768]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.weight: 0.292, (torch.Size([512, 1024]))
# ggnn_rel_reason.rel_proj.weight                   : 0.228, (torch.Size([1024, 4096]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.weight     : 0.227, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.weight     : 0.215, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.weight      : 0.205, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.weight: 0.185, (torch.Size([768, 512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.weight: 0.179, (torch.Size([1024, 768]))
# union_boxes.conv.4.weight                         : 0.154, (torch.Size([512, 256, 3, 3]))
# roi_fmap_obj.3.bias                               : 0.153, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.weight      : 0.151, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.weight: 0.137, (torch.Size([51, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.weight: 0.130, (torch.Size([512, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.weight: 0.127, (torch.Size([256, 512]))
# union_boxes.conv.0.weight                         : 0.127, (torch.Size([256, 2, 7, 7]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.weight     : 0.117, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.weight     : 0.103, (torch.Size([1024, 1024]))
# ggnn_rel_reason.obj_proj.bias                     : 0.089, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.weight: 0.088, (torch.Size([1024, 1024]))
# roi_fmap_obj.0.bias                               : 0.084, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.0.linear.bias: 0.075, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_ent.model.2.linear.bias: 0.071, (torch.Size([151]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.weight     : 0.057, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.weight      : 0.030, (torch.Size([1024, 1024]))
# union_boxes.conv.6.bias                           : 0.028, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.weight     : 0.026, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.0.linear.bias: 0.022, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_ent.bias        : 0.020, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_ent.bias        : 0.020, (torch.Size([1024]))
# union_boxes.conv.0.bias                           : 0.020, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.weight      : 0.017, (torch.Size([1024, 1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.2.linear.bias: 0.017, (torch.Size([256]))
# union_boxes.conv.6.weight                         : 0.015, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_ent.model.2.linear.bias: 0.015, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_pred.model.0.linear.bias: 0.013, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_ent.bias        : 0.012, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_ent.bias        : 0.012, (torch.Size([1024]))
# roi_fmap.1.3.bias                                 : 0.011, (torch.Size([4096]))
# ggnn_rel_reason.rel_proj.bias                     : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_w_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq5_u_img_pred.bias       : 0.010, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.0.linear.bias: 0.009, (torch.Size([512]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.2.linear.bias: 0.008, (torch.Size([51]))
# union_boxes.conv.2.weight                         : 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_send_img_ent.model.2.linear.bias: 0.008, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.0.linear.bias: 0.008, (torch.Size([768]))
# ggnn_rel_reason.ggnn.fc_mp_receive_img_pred.model.2.linear.bias: 0.008, (torch.Size([1024]))
# roi_fmap.1.0.bias                                 : 0.007, (torch.Size([4096]))
# ggnn_rel_reason.ggnn.fc_output_proj_img_pred.model.0.linear.bias: 0.006, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_w_img_pred.bias       : 0.005, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq3_u_img_pred.bias       : 0.005, (torch.Size([1024]))
# union_boxes.conv.4.bias                           : 0.002, (torch.Size([512]))
# union_boxes.conv.2.bias                           : 0.002, (torch.Size([256]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_ent.bias        : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_w_img_pred.bias       : 0.001, (torch.Size([1024]))
# ggnn_rel_reason.ggnn.fc_eq4_u_img_pred.bias       : 0.001, (torch.Size([1024]))
# -------------------------------
#
# e15b10000/14430 0.317s/batch, 76.2m/epoch
# class_loss    0.601953
# rel_loss      0.129296
# total         0.731249
# dtype: float64
# -----------
#
# e15b11000/14430 0.316s/batch, 76.0m/epoch
# class_loss    0.601844
# rel_loss      0.133035
# total         0.734879
# dtype: float64
# -----------
#
# e15b12000/14430 0.314s/batch, 75.6m/epoch
# class_loss    0.596340
# rel_loss      0.133186
# total         0.729525
# dtype: float64
# -----------
#
# e15b13000/14430 0.311s/batch, 74.8m/epoch
# class_loss    0.589117
# rel_loss      0.136929
# total         0.726046
# dtype: float64
# -----------
#
# e15b14000/14430 0.315s/batch, 75.8m/epoch
# class_loss    0.614179
# rel_loss      0.133982
# total         0.748161
# dtype: float64
# -----------
# overall15: (0.732)
# class_loss    0.599009
# rel_loss      0.132681
# total         0.731690
# dtype: float64
# ======================sgcls  recall with constraint============================
# R@20: 0.392750
# R@50: 0.420527
# R@100: 0.427986
# ======================sgcls  recall without constraint============================
# R@20: 0.447591
# R@50: 0.518339
# R@100: 0.549901
#
#
# ======================sgcls  mean recall with constraint============================
# mR@20:  0.08295983491609622
# mR@50:  0.09698990648071704
# mR@100:  0.10193352452220841
#
#
# ======================sgcls  mean recall without constraint============================
# mR@20:  0.1396471779101712
# mR@50:  0.23938451397015456
# mR@100:  0.29734115373193976
