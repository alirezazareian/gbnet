# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from utils_preprocessing import modify_edges, delete_edge
pd.set_option('display.max_colwidth', 999)
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
pd.set_option('display.min_rows', 100)
pd.set_option('display.expand_frame_repr', True)

# %%
# df_raw = pd.read_csv('edges_h0p1_sim_lim9999_thres00_681_20211218.csv')
# df_raw = pd.read_csv('edges_h0p1_sim_lim9999_thres00_551_20211219.csv')
# df_raw = pd.read_csv('edges_h0p1_sim_lim9999_thres00_537_20211223.csv')
df_raw = pd.read_csv('edges_h0p1_sim_lim9999_thres00_537_20211223_edit_2_main_compared_original.csv')

# %%
df_raw.head()
# Out:
#    Unnamed: 0   keep              e1            e2                r  \
# 0           0  False  /c/en/across/r    /c/en/from     /r/RelatedTo
# 1           1   True  /c/en/across/r  /c/en/over/r       /r/Synonym
# 2           2  False  /c/en/across/r      /c/en/to     /r/RelatedTo
# 3           3   True   /c/en/against   /c/en/along  /r/DistinctFrom
# 4           4   True   /c/en/against    /c/en/with       /r/Antonym
#
#   deleted_edit_2                                e1 + e2 + r  \
# 0           TRUE     /c/en/across/r /c/en/from /r/RelatedTo
# 1            NaN     /c/en/across/r /c/en/over/r /r/Synonym
# 2           TRUE       /c/en/across/r /c/en/to /r/RelatedTo
# 3            NaN  /c/en/against /c/en/along /r/DistinctFrom
# 4            NaN        /c/en/against /c/en/with /r/Antonym
#
#                        e1 + e2  \
# 0    /c/en/across/r /c/en/from
# 1  /c/en/across/r /c/en/over/r
# 2      /c/en/across/r /c/en/to
# 3    /c/en/against /c/en/along
# ...

# %%
duplicates = df_raw[df_raw.duplicated(['e1', 'e2', 'r'])].sort_values('e1')

# %%
duplicates # WOOOHOOO
# Out:
#      Unnamed: 0  keep              e1                e2          r  \
# 243         243  True  /c/en/handle/n      /c/en/door/n  /r/PartOf
# 509         509  True   /c/en/trunk/n  /c/en/elephant/n  /r/PartOf
#
#     deleted_edit_2                               e1 + e2 + r  \
# 243            NaN     /c/en/handle/n /c/en/door/n /r/PartOf
# 509            add  /c/en/trunk/n /c/en/elephant/n /r/PartOf
#
#                          e1 + e2                                      edge_id  \
# 243  /c/en/handle/n /c/en/door/n  /a/[/r/PartOf/,/c/en/handle/,/c/en/door/n/]
# 509                          NaN                                          NaN
#
#     modiifcation where modified         Unnamed: 11  original
# 243          NaN   NaN      NaN  addresses previous     False
# 509          NaN   NaN      NaN                 NaN     False

# %% [markdown]
# # 2. Modify Edges
#
# ## Note that the final df must be
# 1. Unique
# 1. Sorted
# 1. Only have three columns: e1, e2, r

# %%
df_final_unique = df_raw[~df_raw.duplicated(['e1', 'e2', 'r'])]

# %%
len(df_final_unique)
# Out:
# 564

# %%
from utils_preprocessing import switch

# %% [markdown]
# # 2.1 Make Zareian Modifications

# %%
len(df_raw[df_raw['original']]) # 104 - correct
# Out:
# 103

# %%
df_raw[df_raw['original']]['keep'].value_counts() # the missing one probably got edited
# Out:
# True    103
# Name: keep, dtype: int64

# %%
original = df_raw[df_raw['original']]
original[~original['keep']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, keep, e1, e2, r, deleted_edit_2, e1 + e2 + r, e1 + e2, edge_id, modiifcation, where, modified, Unnamed: 11, original]
# Index: []

# %%
print('modifying')
modify_edges(df_final_unique, ['/c/en/cat/n', '/c/en/woman/n', '/r/IsA'], 'e2', '/c/en/animal/n') # Reverse X
modify_edges(df_final_unique, ['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext'], 'r', '/r/PartOf') # Reverse X
modify_edges(df_final_unique, ['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext'], 'r', '/r/PartOf') # Reverse X
modify_edges(df_final_unique, ['/c/en/wheel/n', '/c/en/bicycle/n', '/r/Synonym'], 'r', '/r/PartOf') # Reverse X
modify_edges(df_final_unique, ['/c/en/watch/v', '/c/en/look/v', '/r/Entails'], 'r', '/r/MannerOf') # Reverse √
modify_edges(df_final_unique, ['/c/en/door/n', '/c/en/room/n', '/r/IsA'], 'r', '/r/PartOf') # Reverse X
modify_edges(df_final_unique, ['/c/en/face/n', '/c/en/person/n', '/r/IsA'], 'r', '/r/PartOf') # Reverse X
modify_edges(df_final_unique, ['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym'], 'r', '/r/RelatedTo') # Reverse √
modify_edges(df_final_unique, ['/c/en/arm/n', '/c/en/branch/n', '/r/Synonym'], 'r', '/r/RelatedTo') # Reverse X
modify_edges(df_final_unique, ['/c/en/sit/v', '/c/en/ride/v', '/r/Synonym'], 'r', '/r/RelatedTo') # Reverse √
modify_edges(df_final_unique, ['/c/en/branch/n', '/c/en/arm/n', '/r/Synonym'], 'r', '/r/RelatedTo') # Reverse X
modify_edges(df_final_unique, ['/c/en/table/n', '/c/en/board/n', '/r/Synonym'], 'r', '/r/RelatedTo')
modify_edges(df_final_unique, ['/c/en/leg/n', '/c/en/branch/n', '/r/Synonym'], 'r', '/r/RelatedTo')
modify_edges(df_final_unique, ['/c/en/on', '/c/en/along', '/r/Synonym'], 'r', '/r/RelatedTo')
modify_edges(df_final_unique, ['/c/en/hold/v', '/c/en/have/v', '/r/Synonym'], 'r', '/r/RelatedTo')
modify_edges(df_final_unique, ['/c/en/have/v', '/c/en/hold/v', '/r/Synonym'], 'r', '/r/RelatedTo')
modify_edges(df_final_unique, ['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor'], 'r', '/r/IsA')

modify_edges(df_final_unique, switch(['/c/en/cat/n', '/c/en/woman/n', '/r/IsA']), 'e2', '/c/en/animal/n')
modify_edges(df_final_unique, switch(['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext']), 'r', '/r/PartOf')
modify_edges(df_final_unique, switch(['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext']), 'r', '/r/PartOf')
modify_edges(df_final_unique, switch(['/c/en/wheel/n', '/c/en/bicycle/n', '/r/Synonym']), 'r', '/r/PartOf')
modify_edges(df_final_unique, switch(['/c/en/watch/v', '/c/en/look/v', '/r/Entails']), 'r', '/r/MannerOf')
modify_edges(df_final_unique, switch(['/c/en/door/n', '/c/en/room/n', '/r/IsA']), 'r', '/r/PartOf')
modify_edges(df_final_unique, switch(['/c/en/face/n', '/c/en/person/n', '/r/IsA']), 'r', '/r/PartOf')
modify_edges(df_final_unique, switch(['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/arm/n', '/c/en/branch/n', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/sit/v', '/c/en/ride/v', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/branch/n', '/c/en/arm/n', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/table/n', '/c/en/board/n', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/leg/n', '/c/en/branch/n', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/on', '/c/en/along', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/hold/v', '/c/en/have/v', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/have/v', '/c/en/hold/v', '/r/Synonym']), 'r', '/r/RelatedTo')
modify_edges(df_final_unique, switch(['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor']), 'r', '/r/IsA')
             


print('deleting')
delete_edge(df_final_unique, ['/c/en/bed/n', '/c/en/plant/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/with', '/c/en/from', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/bed/n', '/c/en/person/n', '/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/mount/v', '/c/en/ride/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/head/n', '/c/en/toilet/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/counter/n', '/c/en/boot/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/curtain/n', '/c/en/book/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/against', '/c/en/with', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/wave/n', '/c/en/woman/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/make/v', '/c/en/have/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/against', '/c/en/with', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/make/v', '/c/en/hold/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/cat/n', '/c/en/guy/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/and', '/c/en/to', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/to', '/c/en/at', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/child/n', '/c/en/animal/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/tile/n', '/c/en/man/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/from', '/c/en/and', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/against', '/c/en/along', '/r/DistinctFrom'])
# delete_edge(df_final_unique, ['/c/en/at', '/c/en/to', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/clock/n', '/c/en/people/n', '/r/UsedFor'])
delete_edge(df_final_unique, ['/c/en/ear/n', '/c/en/fruit/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/from', '/c/en/to', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/box/n', '/c/en/player/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/bench/n', '/c/en/people/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/counter/n', '/c/en/shoe/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/flag/n', '/c/en/tail/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/make/v', '/c/en/look/v', '/r/MannerOf'])
delete_edge(df_final_unique, ['/c/en/boot/n', '/c/en/car/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/pot/n', '/c/en/toilet/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/with', '/c/en/against', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/cover/v', '/c/en/play/v', '/r/MannerOf'])
delete_edge(df_final_unique, ['/c/en/flag/n', '/c/en/dog/n', '/r/PartOf'])
# delete_edge(df_final_unique, ['/c/en/to', '/c/en/on', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/chair/n', '/c/en/people/n', '/r/UsedFor'])
delete_edge(df_final_unique, ['/c/en/cat/n', '/c/en/book/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/bear/n', '/c/en/person/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/coat/n', '/c/en/hair/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/lie/v', '/c/en/with', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/counter/n', '/c/en/person/n', '/r/IsA'])
delete_edge(df_final_unique, ['/c/en/room/n', '/c/en/to', '/r/RelatedTo'])

delete_edge(df_final_unique, switch(['/c/en/bed/n', '/c/en/plant/n', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/with', '/c/en/from', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/bed/n', '/c/en/person/n', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/mount/v', '/c/en/ride/v', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/head/n', '/c/en/toilet/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/counter/n', '/c/en/boot/n', '/r/PartOf']))
delete_edge(df_final_unique, switch(['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/curtain/n', '/c/en/book/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/against', '/c/en/with', '/r/DistinctFrom']))
delete_edge(df_final_unique, switch(['/c/en/wave/n', '/c/en/woman/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/make/v', '/c/en/have/v', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/against', '/c/en/with', '/r/Antonym']))
delete_edge(df_final_unique, switch(['/c/en/make/v', '/c/en/hold/v', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf']))
delete_edge(df_final_unique, switch(['/c/en/cat/n', '/c/en/guy/n', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/and', '/c/en/to', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/to', '/c/en/at', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/child/n', '/c/en/animal/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/tile/n', '/c/en/man/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/from', '/c/en/and', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/against', '/c/en/along', '/r/DistinctFrom']))
delete_edge(df_final_unique, switch(['/c/en/at', '/c/en/to', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/clock/n', '/c/en/people/n', '/r/UsedFor']))
delete_edge(df_final_unique, switch(['/c/en/ear/n', '/c/en/fruit/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/from', '/c/en/to', '/r/DistinctFrom']))
delete_edge(df_final_unique, switch(['/c/en/box/n', '/c/en/player/n', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/bench/n', '/c/en/people/n', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/counter/n', '/c/en/shoe/n', '/r/PartOf']))
delete_edge(df_final_unique, switch(['/c/en/flag/n', '/c/en/tail/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/make/v', '/c/en/look/v', '/r/MannerOf']))
delete_edge(df_final_unique, switch(['/c/en/boot/n', '/c/en/car/n', '/r/PartOf']))
delete_edge(df_final_unique, switch(['/c/en/pot/n', '/c/en/toilet/n', '/r/Synonym']))
delete_edge(df_final_unique, switch(['/c/en/with', '/c/en/against', '/r/Antonym']))
delete_edge(df_final_unique, switch(['/c/en/cover/v', '/c/en/play/v', '/r/MannerOf']))
delete_edge(df_final_unique, switch(['/c/en/flag/n', '/c/en/dog/n', '/r/PartOf']))
delete_edge(df_final_unique, switch(['/c/en/to', '/c/en/on', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/chair/n', '/c/en/people/n', '/r/UsedFor']))
delete_edge(df_final_unique, switch(['/c/en/cat/n', '/c/en/book/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/bear/n', '/c/en/person/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/coat/n', '/c/en/hair/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/lie/v', '/c/en/with', '/r/RelatedTo']))
delete_edge(df_final_unique, switch(['/c/en/counter/n', '/c/en/person/n', '/r/IsA']))
delete_edge(df_final_unique, switch(['/c/en/room/n', '/c/en/to', '/r/RelatedTo']))
# Out:
# modifying
# deleting
# modify_edges: dropped     Unnamed: 0   keep           e1             e2             r  \
# 33          33  False  /c/en/bed/n  /c/en/plant/n  /r/RelatedTo
#
#    deleted_edit_2                             e1 + e2 + r  \
# 33           TRUE  /c/en/bed/n /c/en/plant/n /r/RelatedTo
#
#                       e1 + e2  \
# 33  /c/en/bed/n /c/en/plant/n
#
#                                                                  edge_id  \
# 33  /a/[/r/RelatedTo/,/c/en/bed/n/wn/artifact/,/c/en/plant/n/wn/botany/]
#
#    modiifcation where modified Unnamed: 11  original
# 33          NaN   NaN      NaN         NaN     False
# modify_edges: dropped      Unnamed: 0   keep          e1          e2             r deleted_edit_2  \
# 562         562  False  /c/en/with  /c/en/from  /r/RelatedTo            NaN
#
#                             e1 + e2 + r                e1 + e2  \
# 562  /c/en/with /c/en/from /r/RelatedTo  /c/en/with /c/en/from
#
# ...

# %%
len(df_final_unique) # was 494. Now
# Out:
# 523

# %%
df_raw[df_raw['original']]['keep'].value_counts() # the missing one probably got edited
# Out:
# True    103
# Name: keep, dtype: int64

# %% [markdown]
# # 2.2 Make My Own Modifications

# %%
df = df_final_unique
df.loc[(df['e1'] == '/c/en/leg/n') & (df['e2'] == '/c/en/branch/n') & (df['r'] == '/r/RelatedTo')]
# Out:
#      Unnamed: 0   keep           e1              e2             r  \
# 298         298   True  /c/en/leg/n  /c/en/branch/n  /r/RelatedTo
# 299         299  False  /c/en/leg/n  /c/en/branch/n  /r/RelatedTo
#
#     deleted_edit_2                              e1 + e2 + r  \
# 298     added back  /c/en/leg/n /c/en/branch/n /r/RelatedTo
# 299            NaN    /c/en/leg/n /c/en/branch/n /r/Synonym
#
#                         e1 + e2  \
# 298  /c/en/leg/n /c/en/branch/n
# 299  /c/en/leg/n /c/en/branch/n
#
#                                                              edge_id  \
# 298                    /a/[/r/RelatedTo/,/c/en/leg/n/,/c/en/branch/]
# 299  /a/[/r/Synonym/,/c/en/leg/n/wn/shape/,/c/en/branch/n/wn/shape/]
#
#     modiifcation where modified Unnamed: 11  original
# 298          NaN   NaN      NaN         NaN      True
# 299          NaN   NaN      NaN         NaN     False

# %%
len(df_final_unique[df_final_unique['keep']])
# Out:
# 234

# %%
# New 12/1
delete_edge(df_final_unique, ['/c/en/handle/n', '/c/en/door/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/handle/n', '/c/en/hand/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/have/v', '/c/en/bear/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/have/v', '/c/en/eat/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/have/v', '/c/en/food/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/have/v', '/c/en/hold/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/head/n', '/c/en/branch/n', '/r/Synonym/'])
delete_edge(df_final_unique, ['/c/en/head/n', '/c/en/flower/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/horse/n', '/c/en/animal/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/horse/n', '/c/en/ride/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/horse/n', '/c/en/zebra/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/house/n', '/c/en/building/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/house/n', '/c/en/tree/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/jacket/n', '/c/en/coat/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/lady/n', '/c/en/woman/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor'])
delete_edge(df_final_unique, ['/c/en/leaf/n', '/c/en/plant/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/lie/v', '/c/en/with', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/look/v', '/c/en/face/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/look/v', '/c/en/watch/v', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/make/v', '/c/en/constitute/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/man/n', '/c/en/person/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/man/n', '/c/en/person/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/man/n', '/c/en/woman/n', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/man/n', '/c/en/woman/n', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/mount/v', '/c/en/attach/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/mountain/n', '/c/en/hill/n', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/mountain/n', '/c/en/rock/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/neck/n', '/c/en/bottle/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/neck/n', '/c/en/shirt/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/over/r', '/c/en/under', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/over/r', '/c/en/under', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/over/r', '/c/en/under', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/paper/n', '/c/en/book/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/paper/n', '/c/en/hand/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/paper/n', '/c/en/post/n', '/r/PartOf'])
delete_edge(df_final_unique, ['/c/en/park/v', '/c/en/sit/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/people/n', '/c/en/person/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/plant/n', '/c/en/bed/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/plant/n', '/c/en/building/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/plant/n', '/c/en/tree/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/plate/n', '/c/en/eat/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/plate/n', '/c/en/mouth/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/play/v', '/c/en/person/n', '/r/HasContext'])
delete_edge(df_final_unique, ['/c/en/post/n', '/c/en/letter/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/post/n', '/c/en/paper/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/racket/n', '/c/en/shoe/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/racket/n', '/c/en/wire/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/ride/v', '/c/en/along', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/ride/v', '/c/en/bicycle/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/ride/v', '/c/en/horse/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/roof/n', '/c/en/building/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/seat/n', '/c/en/bench/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/seat/n', '/c/en/chair/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/shelf/n', '/c/en/cabinet/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/shirt/n', '/c/en/wear/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/shoe/n', '/c/en/boot/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/sit/v', '/c/en/seat/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/sit/v', '/c/en/seat/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/skateboard/n', '/c/en/wheel/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/street/n', '/c/en/sidewalk/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/table/n', '/c/en/board/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/tail/n', '/c/en/head/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/tile/n', '/c/en/cover/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/to', '/c/en/at', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/toilet/n', '/c/en/bowl/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/toilet/n', '/c/en/room/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/train/n', '/c/en/car/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/tree/n', '/c/en/branch/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/tree/n', '/c/en/plant/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/trunk/n', '/c/en/boot/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym'])
delete_edge(df_final_unique, ['/c/en/trunk/n', '/c/en/nose/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/trunk/n', '/c/en/tree/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/above/r', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/above/r', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/behind/r', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/over/r', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/over/r', '/r/DistinctFrom'])
delete_edge(df_final_unique, ['/c/en/under', '/c/en/over/r', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/vegetable/n', '/c/en/flower/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/vegetable/n', '/c/en/fruit/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/vegetable/n', '/c/en/plant/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/vehicle/n', '/c/en/transport/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/windshield/n', '/c/en/cover/v', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/windshield/n', '/c/en/screen/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/wire/n', '/c/en/fence/n', '/r/RelatedTo'])
delete_edge(df_final_unique, ['/c/en/with', '/c/en/against', '/r/Antonym'])
delete_edge(df_final_unique, ['/c/en/woman/n', '/c/en/lady/n', '/r/Synonym'])
# Out:
# /Users/zhanwenchen/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/zhanwenchen/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/zhanwenchen/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# delete_edge(df_final_unique, ['/c/en/bear/n','/c/en/person/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/bench/n','/c/en/dog/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bench/n','/c/en/counter/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bench/n','/c/en/food/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bicycle/n','/c/en/seat/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bird/n','/c/en/animal/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bird/n','/c/en/airplane/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bird/n','/c/en/wing/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bird/n','/c/en/guy/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/bird/n','/c/en/man/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/board/n','/c/en/pole/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/board/n','/c/en/light/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/board/n','/c/en/telephone/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/board/n','/c/en/with','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/book/n','/c/en/arm/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/car/n','/r/PartOf'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/plant/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/trunk/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/cover/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/player/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/leaf/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/boot/n','/c/en/flag/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/bottle/n','/c/en/hair/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/box/n','/c/en/player/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/box/n','/c/en/cup/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/bus/n','/c/en/people/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cap/n','/c/en/paper/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cap/n','/c/en/cup/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cap/n','/c/en/neck/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cap/n','/c/en/letter/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cap/n','/c/en/bird/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/car/n','/c/en/horse/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cat/n','/c/en/book/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/cat/n','/c/en/guy/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/cat/n','/c/en/woman/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/cat/n','/c/en/plate/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/clock/n','/c/en/sock/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/clock/n','/c/en/head/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/boot/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/person/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/hold/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/shoe/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/horse/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/counter/n','/c/en/head/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cow/n','/c/en/elephant/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cow/n','/c/en/woman/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cow/n','/c/en/car/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cup/n','/c/en/player/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cup/n','/c/en/box/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/cup/n','/c/en/cap/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/curtain/n','/c/en/book/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/curtain/n','/c/en/tower/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/curtain/n','/c/en/bed/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/dog/n','/c/en/woman/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/dog/n','/c/en/man/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/dog/n','/c/en/guy/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/ear/n','/c/en/head/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/ear/n','/c/en/fruit/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/elephant/n','/c/en/paper/n','/r/HasContext'])
# delete_edge(df_final_unique, ['/c/en/eye/n','/c/en/counter/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/eye/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/face/n','/c/en/racket/n','/r/PartOf'])
# delete_edge(df_final_unique, ['/c/en/face/n','/c/en/person/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/finger/n','/c/en/glass/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/finger/n','/c/en/person/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/finger/n','/c/en/cover/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/finger/n','/c/en/bird/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/finger/n','/c/en/animal/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/flag/n','/c/en/dog/n','/r/PartOf'])
# delete_edge(df_final_unique, ['/c/en/flag/n','/c/en/tail/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/flag/n','/c/en/face/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/flag/n','/c/en/leaf/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/flower/n','/c/en/head/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/from','/c/en/and','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/hand/n','/c/en/at','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/hand/n','/c/en/face/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/hand/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/handle/n','/c/en/hold/v','/r/UsedFor'])
# delete_edge(df_final_unique, ['/c/en/hang/v','/c/en/tree/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/head/n','/c/en/toilet/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/head/n','/c/en/toilet/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/head/n','/c/en/mouth/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/head/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/hill/n','/c/en/plant/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/hold/v','/c/en/bear/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/horse/n','/c/en/leg/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/house/n','/c/en/stand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/house/n','/c/en/child/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/house/n','/c/en/animal/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/house/n','/c/en/tree/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/in/r','/c/en/play/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/kite/n','/c/en/bird/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/kite/n','/c/en/letter/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/lady/n','/c/en/plate/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/leaf/n','/c/en/door/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/leg/n','/c/en/branch/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/leg/n','/c/en/branch/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/leg/n','/c/en/hold/v','/r/UsedFor'])
# delete_edge(df_final_unique, ['/c/en/leg/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/lie/v','/c/en/belong/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/look/v','/c/en/face/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/make/v','/c/en/have/v','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/make/v','/c/en/hold/v','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/make/v','/c/en/look/v','/r/MannerOf'])
# delete_edge(df_final_unique, ['/c/en/make/v','/c/en/cover/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/mount/v','/c/en/play/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/mountain/n','/c/en/woman/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/mouth/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/neck/n','/c/en/trunk/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/neck/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/neck/n','/c/en/under','/r/Antonym'])
# delete_edge(df_final_unique, ['/c/en/nose/n','/c/en/face/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/nose/n','/c/en/use/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/nose/n','/c/en/horse/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/nose/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/on','/c/en/leg/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/paper/n','/c/en/rock/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/path/n','/c/en/tree/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/person/n','/c/en/plant/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pillow/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pizza/n','/c/en/fruit/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pizza/n', '/c/en/vegetable/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/plant/n','/c/en/book/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/plate/n','/c/en/animal/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/plate/n','/c/en/hat/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/plate/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/plate/n','/c/en/with','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/post/n','/c/en/on','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/toilet/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/toilet/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/paper/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/use/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/hat/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/horse/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/hand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/helmet/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/glass/n,/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/pot/n','/c/en/stand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/ride/v','/c/en/lie/v','/r/MannerOf'])
# delete_edge(df_final_unique, ['/c/en/rock/n','/c/en/paper/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/rock/n','/c/en/hand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/room/n','/c/en/to','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/room/n','/c/en/post/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/screen/n','/c/en/wire/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/screen/n','/c/en/paint/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/shoe/n','/c/en/and','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/shoe/n','/c/en/tire/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/sign/n','/c/en/at','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/sock/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/stand/n','/c/en/book/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/stand/n','/c/en/tree/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/stand/v','/c/en/hold/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/stand/v','/c/en/hand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/table/n','/c/en/under','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/tail/n','/c/en/letter/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/tile/n','/c/en/man/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/tile/n','/c/en/hat/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/toilet/n','/c/en/head/n','/r/Synonym'])
# delete_edge(df_final_unique, ['/c/en/train/n','/c/en/bird/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/train/n','/c/en/tail/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/truck/n','/c/en/bed/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/truck/n','/c/en/skateboard/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/trunk/n','/c/en/on','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/use/v','/c/en/stand/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/walk/v','/c/en/play/v','/r/MannerOf'])
# delete_edge(df_final_unique, ['/c/en/wave/n','/c/en/woman/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/wear/v','/c/en/bear/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/wear/v','/c/en/watch/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/wing/n','/c/en/hold/v','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/wing/n','/c/en/flower/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/wing/n','/c/en/roof/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/wire/n','/c/en/woman/n','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/with','/c/en/from','/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/woman/n','/c/en/man/n','/r/IsA'])
# delete_edge(df_final_unique, ['/c/en/cup/n', '/c/en/handle/n', '/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/door/n', '/c/en/handle/n', '/r/RelatedTo'])
# delete_edge(df_final_unique, ['/c/en/post/n', '/c/en/paper/n', '/r/HasContext'])



# # For modify edges, because of the different replacement parts, copy Google Sheet into Atom
# # and replace tabs with ', ', => select all => 'all'
# modify_edges(df_final_unique, ['/c/en/face/n', '/c/en/person/n', '/r/IsA'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/door/n', '/c/en/room/n', '/r/IsA'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/eye/n', '/c/en/look/v', '/r/RelatedTo'], 'r', '/r/UsedFor')
# modify_edges(df_final_unique, ['/c/en/eye/n', '/c/en/animal/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/finger/n', '/c/en/hold/v', '/r/RelatedTo'], 'r', '/r/UsedFor')
# modify_edges(df_final_unique, ['/c/en/flower/n', '/c/en/plant/n', '/r/RelatedTo'], 'r', '/r/IsA')
# modify_edges(df_final_unique, ['/c/en/guy/n', '/c/en/person/n', '/r/RelatedTo'], 'r', '/r/IsA')
# modify_edges(df_final_unique, ['/c/en/guy/n', '/c/en/person/n', '/r/RelatedTo'], 'r', '/r/IsA')
# # around 235 change r
# modify_edges(df_final_unique, ['/c/en/handle/n', '/c/en/hold/v', '/r/Synonym'], 'r', '/r/UsedFor')
# # around 244 change r
# modify_edges(df_final_unique, ['/c/en/head/n', '/c/en/branch/n', '/r/Synonym/'], 'r', '/r/Antonym')
# modify_edges(df_final_unique, ['/c/en/jacket/n', '/c/en/cover/v', '/r/RelatedTo'], 'r', '/r/UsedFor')
# modify_edges(df_final_unique, ['/c/en/leaf/n', '/c/en/plant/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/leaf/n', '/c/en/tree/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/mountain/n', '/c/en/hill/n', '/r/DistinctFrom'], 'r', '/r/Synonym')
# modify_edges(df_final_unique, ['/c/en/neck/n', '/c/en/bottle/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/orange/n', '/c/en/fruit/n', '/r/RelatedTo'], 'r', '/r/IsA')
# modify_edges(df_final_unique, ['/c/en/paw/n', '/c/en/animal/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/pot/n', '/c/en/hold/v', '/r/RelatedTo'], 'r', '/r/UsedFor')
# modify_edges(df_final_unique, ['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/seat/n', '/c/en/bicycle/n', '/r/IsA'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/tail/n', '/c/en/animal/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/tail/n', '/c/en/head/n', '/r/RelatedTo'], 'r', '/r/Antonym')
# modify_edges(df_final_unique, ['/c/en/tire/n', '/c/en/bicycle/n', '/r/IsA'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/train/n', '/c/en/transport/v', '/r/RelatedTo'], 'r', '/r/UsedFor')
# modify_edges(df_final_unique, ['/c/en/trunk/n', '/c/en/elephant/n', '/r/RelatedTo'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/wheel/n', '/c/en/bicycle/n', '/r/IsA'], 'r', '/r/PartOf')
# modify_edges(df_final_unique, ['/c/en/wing/n', '/c/en/animal/n', '/r/RelatedTo'], 'r', '/r/PartOf')

# %%
len(df_final_unique)
# Out:
# 564

# %%
df_final_unique=df_final_unique.reset_index(drop=True)

# %%
# from utils_preprocessing import add_edge
# add_edge(df_final_unique, ['/c/en/handle/n', '/c/en/cup/n', '/r/PartOf'])
# add_edge(df_final_unique, ['/c/en/vegetable/n', '/c/en/pizza/n', '/r/PartOf'])
# add_edge(df_final_unique, ['/c/en/paper/n', '/c/en/post/n', '/r/PartOf'])

# %%
len(df_final_unique)
# Out:
# 564

# %%
df_final_unique
# Out:
#      Unnamed: 0   keep                  e1                  e2  \
# 0             0  False      /c/en/across/r          /c/en/from
# 1             1   True      /c/en/across/r        /c/en/over/r
# 2             2  False      /c/en/across/r            /c/en/to
# 3             3   True       /c/en/against         /c/en/along
# 4             4   True       /c/en/against          /c/en/with
# 5             5  False       /c/en/against          /c/en/with
# 6             6   True       /c/en/ahead/r      /c/en/behind/r
# 7             7  False    /c/en/airplane/n        /c/en/wing/n
# 8             8  False         /c/en/along      /c/en/across/r
# 9             9   True         /c/en/along          /c/en/with
# 10           10  False           /c/en/and            /c/en/to
# 11           11  False      /c/en/animal/n       /c/en/plant/n
# 12           12   True         /c/en/arm/n      /c/en/branch/n
# 13           13  False         /c/en/arm/n      /c/en/branch/n
# ...

# %%
len(df_final_unique[df_final_unique['keep']])
# Out:
# 238

# %%
corrected_benchmark = df_final_unique[df_final_unique['keep']]

# %%
len(corrected_benchmark)
# Out:
# 238

# %%
import pandas as pd
fname_diff = 'edges_diff_h0p2_rand_lim50_thres00_249_20220105.csv' # - This is the raw benchmark. It's been reduced to 238 already so we can piggy back on the edit_2.
# fname_diff = 'edges_diff_h0p2_rand_lim50_thres00_249_20220104 - edges_diff_h0p2_rand_lim50_thres00_249_20220104_edited_40.csv' # - This is the raw benchmark. It's been reduced to 238 already so we can piggy back on the edit_2.
# fname_diff = 'edges_diff_h0p2_rand_lim50_thres00_249_20220104 - edges_diff_h0p2_rand_lim50_thres00_249_20220104.csv' # - This is the raw benchmark. It's been reduced to 238 already so we can piggy back on the edit_2.

columns = ['e1', 'e2', 'r', 'edge_id']
# columns = ['e1', 'e2', 'r']
# columns_old = ['edge_start_matched', 'edge_end_matched', 'predicate', 'edge_id']
# df_new = pd.read_csv(fname_new)[columns]
# df_old = pd.read_csv(fname_old)[columns]
df_diff = pd.read_csv(fname_diff)
df_diff = df_diff[df_diff['keep']][columns]
df_combined = pd.concat([corrected_benchmark, df_diff], ignore_index=True, sort=False)

# %%
len(df_diff)
# Out:
# 40

# %%
len(df_combined)
# Out:
# 278

# %%
# df_final_unique.to_csv('edges_h0p1_sim_lim9999_thres00_537_20211223_step_2_edit_381_20211223.csv', index=False)
# df_final_unique[df_final_unique['keep']].to_csv('edges_h0p1_sim_lim9999_thres00_537_20211223_step_2_edit_238_20220103.csv', index=False)
# df_combined.to_csv('edges_h0p2_rand_lim50_thres00_738_edited_278_20220104.csv', index=False)
df_combined.to_csv('edges_h0p2_rand_lim50_thres00_738_edited_278_20220105.csv', index=False)
