# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. Build my own unique matched-cn_id-only df

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 400)
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 300)
pd.set_option('display.min_rows', 100)
pd.set_option('display.expand_frame_repr', True)

# %%
columns = ['edge_start_matched', 'edge_pd_matched', 'predicate']

# %%
df = pd.read_csv('edges_154_h1p0_20211121.csv')

# %%
edges_matched = df[['edge_start_matched', 'edge_pd_matched', 'predicate']]

# %%
edges_matched_unique = df[~df.duplicated(subset=['edge_start_matched', 'edge_pd_matched', 'predicate'])][['edge_start_matched', 'edge_pd_matched', 'predicate']]

# %%
len(df)
# Out:
# 154

# %%
len(edges_matched_unique)
# Out:
# 143

# %%
df_edges_matched_unique_sorted = edges_matched_unique.sort_values(by=['edge_start_matched', 'edge_pd_matched', 'predicate']).reset_index(drop=True)

# %%
df_edges_matched_unique_sorted
# Out:
#      edge_start_matched     edge_pd_matched        predicate
# 0         /c/en/against         /c/en/along  /r/DistinctFrom
# 1         /c/en/against          /c/en/with       /r/Antonym
# 2         /c/en/against          /c/en/with  /r/DistinctFrom
# 3           /c/en/along          /c/en/with     /r/RelatedTo
# 4             /c/en/and            /c/en/to     /r/RelatedTo
# 5           /c/en/arm/n      /c/en/branch/n       /r/Synonym
# 6           /c/en/bag/n        /c/en/hold/v       /r/UsedFor
# 7           /c/en/bag/n   /c/en/transport/v       /r/UsedFor
# 8        /c/en/basket/n        /c/en/hold/v       /r/UsedFor
# 9          /c/en/bear/n      /c/en/animal/n           /r/IsA
# 10         /c/en/bear/n      /c/en/person/n           /r/IsA
# 11          /c/en/bed/n        /c/en/hold/v       /r/UsedFor
# 12          /c/en/bed/n      /c/en/person/n     /r/RelatedTo
# 13          /c/en/bed/n       /c/en/plant/n     /r/RelatedTo
# ...

# %% [markdown]
# # 2. Build Zareian's df

# %%
# Load from Zareian's 147 edges
edges_zareian_enumerate = \
[(0, ['/c/en/windshield/n', '/c/en/screen/n', '/r/IsA']),
 (1, ['/c/en/cat/n', '/c/en/woman/n', '/r/IsA']),
 (2, ['/c/en/wing/n', '/c/en/airplane/n', '/r/PartOf']),
 (3, ['/c/en/room/n', '/c/en/to', '/r/RelatedTo']),
 (4, ['/c/en/bowl/n', '/c/en/hold/v', '/r/UsedFor']),
 (5, ['/c/en/play/v', '/c/en/use/v', '/r/MannerOf']),
 (6, ['/c/en/arm/n', '/c/en/branch/n', '/r/Synonym']),
 (7, ['/c/en/counter/n', '/c/en/person/n', '/r/IsA']),
 (8, ['/c/en/lie/v', '/c/en/with', '/r/RelatedTo']),
 (9, ['/c/en/window/n', '/c/en/car/n', '/r/PartOf']),
 (10, ['/c/en/guy/n', '/c/en/man/n', '/r/IsA']),
 (11, ['/c/en/coat/n', '/c/en/hair/n', '/r/IsA']),
 (12, ['/c/en/face/n', '/c/en/animal/n', '/r/PartOf']),
 (13, ['/c/en/bench/n', '/c/en/seat/n', '/r/IsA']),
 (14, ['/c/en/nose/n', '/c/en/face/n', '/r/PartOf']),
 (15, ['/c/en/window/n', '/c/en/bus/n', '/r/PartOf']),
 (16, ['/c/en/wear/v', '/c/en/have/v', '/r/MannerOf']),
 (17, ['/c/en/mount/v', '/c/en/attach/v', '/r/MannerOf']),
 (18, ['/c/en/bag/n', '/c/en/transport/v', '/r/UsedFor']),
 (19, ['/c/en/bear/n', '/c/en/person/n', '/r/IsA']),
 (20, ['/c/en/cat/n', '/c/en/book/n', '/r/IsA']),
 (21, ['/c/en/roof/n', '/c/en/truck/n', '/r/PartOf']),
 (22, ['/c/en/door/n', '/c/en/room/n', '/r/IsA']),
 (23, ['/c/en/ear/n', '/c/en/head/n', '/r/PartOf']),
 (24, ['/c/en/skateboard/n', '/c/en/board/n', '/r/IsA']),
 (25, ['/c/en/kite/n', '/c/en/bird/n', '/r/IsA']),
 (26, ['/c/en/face/n', '/c/en/head/n', '/r/PartOf']),
 (27, ['/c/en/trunk/n', '/c/en/tree/n', '/r/PartOf']),
 (28, ['/c/en/bowl/n', '/c/en/food/n', '/r/RelatedTo']),
 (29, ['/c/en/chair/n', '/c/en/people/n', '/r/UsedFor']),
 (30, ['/c/en/room/n', '/c/en/building/n', '/r/PartOf']),
 (31, ['/c/en/basket/n', '/c/en/hold/v', '/r/UsedFor']),
 (32, ['/c/en/to', '/c/en/on', '/r/RelatedTo']),
 (33, ['/c/en/flag/n', '/c/en/dog/n', '/r/PartOf']),
 (34, ['/c/en/sit/v', '/c/en/ride/v', '/r/Synonym']),
 (35, ['/c/en/face/n', '/c/en/person/n', '/r/IsA']),
 (36, ['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym']),
 (37, ['/c/en/cover/v', '/c/en/play/v', '/r/MannerOf']),
 (38, ['/c/en/bicycle/n', '/c/en/ride/v', '/r/UsedFor']),
 (39, ['/c/en/with', '/c/en/against', '/r/Antonym']),
 (40, ['/c/en/head/n', '/c/en/animal/n', '/r/PartOf']),
 (41, ['/c/en/bag/n', '/c/en/hold/v', '/r/UsedFor']),
 (42, ['/c/en/pot/n', '/c/en/toilet/n', '/r/Synonym']),
 (43, ['/c/en/boot/n', '/c/en/shoe/n', '/r/IsA']),
 (44, ['/c/en/on', '/c/en/along', '/r/Synonym']),
 (45, ['/c/en/boot/n', '/c/en/car/n', '/r/PartOf']),
 (46, ['/c/en/with', '/c/en/against', '/r/RelatedTo']),
 (47, ['/c/en/hold/v', '/c/en/cover/v', '/r/MannerOf']),
 (48, ['/c/en/counter/n', '/c/en/table/n', '/r/IsA']),
 (49, ['/c/en/motorcycle/n', '/c/en/ride/v', '/r/UsedFor']),
 (50, ['/c/en/leg/n', '/c/en/hold/v', '/r/UsedFor']),
 (51, ['/c/en/horse/n', '/c/en/animal/n', '/r/IsA']),
 (52, ['/c/en/desk/n', '/c/en/table/n', '/r/IsA']),
 (53, ['/c/en/bear/n', '/c/en/animal/n', '/r/IsA']),
 (54, ['/c/en/branch/n', '/c/en/arm/n', '/r/Synonym']),
 (55, ['/c/en/make/v', '/c/en/look/v', '/r/MannerOf']),
 (56, ['/c/en/roof/n', '/c/en/building/n', '/r/PartOf']),
 (57, ['/c/en/flag/n', '/c/en/tail/n', '/r/IsA']),
 (58, ['/c/en/lamp/n', '/c/en/light/n', '/r/RelatedTo']),
 (59, ['/c/en/paint/v', '/c/en/cover/v', '/r/MannerOf']),
 (60, ['/c/en/counter/n', '/c/en/shoe/n', '/r/PartOf']),
 (61, ['/c/en/bench/n', '/c/en/people/n', '/r/RelatedTo']),
 (62, ['/c/en/fly/v', '/c/en/transport/v', '/r/MannerOf']),
 (63, ['/c/en/watch/v', '/c/en/look/v', '/r/Entails']),
 (64, ['/c/en/car/n', '/c/en/transport/v', '/r/UsedFor']),
 (65, ['/c/en/with', '/c/en/on', '/r/RelatedTo']),
 (66, ['/c/en/box/n', '/c/en/player/n', '/r/RelatedTo']),
 (67, ['/c/en/from', '/c/en/to', '/r/DistinctFrom']),
 (68, ['/c/en/leg/n', '/c/en/table/n', '/r/PartOf']),
 (69, ['/c/en/ride/v', '/c/en/lie/v', '/r/MannerOf']),
 (70, ['/c/en/ear/n', '/c/en/fruit/n', '/r/IsA']),
 (71, ['/c/en/player/n', '/c/en/person/n', '/r/IsA']),
 (72, ['/c/en/hand/n', '/c/en/arm/n', '/r/PartOf']),
 (73, ['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext']),
 (74, ['/c/en/counter/n', '/c/en/hold/v', '/r/UsedFor']),
 (75, ['/c/en/bed/n', '/c/en/hold/v', '/r/UsedFor']),
 (76, ['/c/en/at', '/c/en/on', '/r/RelatedTo']),
 (77, ['/c/en/clock/n', '/c/en/people/n', '/r/UsedFor']),
 (78, ['/c/en/at', '/c/en/to', '/r/RelatedTo']),
 (79, ['/c/en/against', '/c/en/along', '/r/DistinctFrom']),
 (80, ['/c/en/box/n', '/c/en/seat/n', '/r/IsA']),
 (81, ['/c/en/mouth/n', '/c/en/face/n', '/r/PartOf']),
 (82, ['/c/en/hold/v', '/c/en/have/v', '/r/Synonym']),
 (83, ['/c/en/glass/n', '/c/en/hold/v', '/r/UsedFor']),
 (84, ['/c/en/cabinet/n', '/c/en/box/n', '/r/IsA']),
 (85, ['/c/en/boat/n', '/c/en/transport/v', '/r/UsedFor']),
 (86, ['/c/en/from', '/c/en/and', '/r/RelatedTo']),
 (87, ['/c/en/child/n', '/c/en/person/n', '/r/IsA']),
 (88, ['/c/en/walk/v', '/c/en/play/v', '/r/MannerOf']),
 (89, ['/c/en/table/n', '/c/en/board/n', '/r/Synonym']),
 (90, ['/c/en/bus/n', '/c/en/transport/v', '/r/UsedFor']),
 (91, ['/c/en/drawer/n', '/c/en/desk/n', '/r/PartOf']),
 (92, ['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor']),
 (93, ['/c/en/tile/n', '/c/en/man/n', '/r/IsA']),
 (94, ['/c/en/child/n', '/c/en/animal/n', '/r/IsA']),
 (95, ['/c/en/along', '/c/en/with', '/r/RelatedTo']),
 (96, ['/c/en/leg/n', '/c/en/chair/n', '/r/PartOf']),
 (97, ['/c/en/man/n', '/c/en/person/n', '/r/IsA']),
 (98, ['/c/en/to', '/c/en/at', '/r/RelatedTo']),
 (99, ['/c/en/and', '/c/en/to', '/r/RelatedTo']),
 (100, ['/c/en/with', '/c/en/along', '/r/RelatedTo']),
 (101, ['/c/en/leg/n', '/c/en/branch/n', '/r/Synonym']),
 (102, ['/c/en/cat/n', '/c/en/guy/n', '/r/Synonym']),
 (103, ['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf']),
 (104, ['/c/en/make/v', '/c/en/hold/v', '/r/Synonym']),
 (105, ['/c/en/have/v', '/c/en/hold/v', '/r/Synonym']),
 (106, ['/c/en/box/n', '/c/en/hold/v', '/r/UsedFor']),
 (107, ['/c/en/eye/n', '/c/en/face/n', '/r/PartOf']),
 (108, ['/c/en/bus/n', '/c/en/car/n', '/r/IsA']),
 (109, ['/c/en/cup/n', '/c/en/hold/v', '/r/UsedFor']),
 (110, ['/c/en/house/n', '/c/en/building/n', '/r/IsA']),
 (111, ['/c/en/against', '/c/en/with', '/r/Antonym']),
 (112, ['/c/en/make/v', '/c/en/have/v', '/r/Synonym']),
 (113, ['/c/en/gym_shoe/n', '/c/en/shoe/n', '/r/IsA']),
 (114, ['/c/en/toilet/n', '/c/en/room/n', '/r/IsA']),
 (115, ['/c/en/handle/n', '/c/en/racket/n', '/r/PartOf']),
 (116, ['/c/en/shelf/n', '/c/en/cabinet/n', '/r/PartOf']),
 (117, ['/c/en/wave/n', '/c/en/woman/n', '/r/IsA']),
 (118, ['/c/en/against', '/c/en/with', '/r/DistinctFrom']),
 (119, ['/c/en/curtain/n', '/c/en/book/n', '/r/IsA']),
 (120, ['/c/en/make/v', '/c/en/constitute/v', '/r/MannerOf']),
 (121, ['/c/en/jacket/n', '/c/en/coat/n', '/r/IsA']),
 (122, ['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym']),
 (123, ['/c/en/roof/n', '/c/en/car/n', '/r/PartOf']),
 (124, ['/c/en/counter/n', '/c/en/boot/n', '/r/PartOf']),
 (125, ['/c/en/face/n', '/c/en/racket/n', '/r/PartOf']),
 (126, ['/c/en/stand/n', '/c/en/table/n', '/r/IsA']),
 (127, ['/c/en/chair/n', '/c/en/seat/n', '/r/IsA']),
 (128, ['/c/en/windshield/n', '/c/en/airplane/n', '/r/PartOf']),
 (129, ['/c/en/lady/n', '/c/en/woman/n', '/r/IsA']),
 (130, ['/c/en/finger/n', '/c/en/hand/n', '/r/PartOf']),
 (131, ['/c/en/head/n', '/c/en/toilet/n', '/r/IsA']),
 (132, ['/c/en/wing/n', '/c/en/bird/n', '/r/PartOf']),
 (133, ['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext']),
 (134, ['/c/en/mount/v', '/c/en/ride/v', '/r/Synonym']),
 (135, ['/c/en/curtain/n', '/c/en/window/n', '/r/RelatedTo']),
 (136, ['/c/en/wheel/n', '/c/en/bicycle/n', '/r/Synonym']),
 (137, ['/c/en/surfboard/n', '/c/en/board/n', '/r/IsA']),
 (138, ['/c/en/bed/n', '/c/en/person/n', '/r/RelatedTo']),
 (139, ['/c/en/finger/n', '/c/en/glove/n', '/r/PartOf']),
 (140, ['/c/en/with', '/c/en/from', '/r/RelatedTo']),
 (141, ['/c/en/bed/n', '/c/en/plant/n', '/r/RelatedTo']),
 (142, ['/c/en/handle/n', '/c/en/umbrella/n', '/r/PartOf']),
 (143, ['/c/en/trunk/n', '/c/en/nose/n', '/r/IsA']),
 (144, ['/c/en/window/n', '/c/en/building/n', '/r/PartOf']),
 (145, ['/c/en/roof/n', '/c/en/bus/n', '/r/PartOf']),
 (146, ['/c/en/bottle/n', '/c/en/hold/v', '/r/UsedFor'])]

# %%
edges_zareian = [row [1] for row in edges_zareian_enumerate]

# %%
df_edges_zareian = pd.DataFrame(edges_zareian, columns=columns).sort_values(by=columns).reset_index(drop=True)

# %%
df_edges_zareian
# Out:
#      edge_start_matched     edge_pd_matched        predicate
# 0         /c/en/against         /c/en/along  /r/DistinctFrom
# 1         /c/en/against          /c/en/with       /r/Antonym
# 2         /c/en/against          /c/en/with  /r/DistinctFrom
# 3           /c/en/along          /c/en/with     /r/RelatedTo
# 4             /c/en/and            /c/en/to     /r/RelatedTo
# 5           /c/en/arm/n      /c/en/branch/n       /r/Synonym
# 6              /c/en/at            /c/en/on     /r/RelatedTo
# 7              /c/en/at            /c/en/to     /r/RelatedTo
# 8           /c/en/bag/n        /c/en/hold/v       /r/UsedFor
# 9           /c/en/bag/n   /c/en/transport/v       /r/UsedFor
# 10       /c/en/basket/n        /c/en/hold/v       /r/UsedFor
# 11         /c/en/bear/n      /c/en/animal/n           /r/IsA
# 12         /c/en/bear/n      /c/en/person/n           /r/IsA
# 13          /c/en/bed/n        /c/en/hold/v       /r/UsedFor
# ...

# %%
import numpy as np
def compare(df_1, df_2):
    df = pd.merge(df_1, df_2, on=columns, how='outer', indicator='Exist')
#     df.drop('Rating', inplace=True, axis=1)
#     df['Exist'] = np.where(df.Exist == 'both', True, False)
#     for index, row in df_1.iterrows():
#         if row in 
    return df

# %%
compare(df_edges_matched_unique_sorted, df_edges_zareian)
# Out:
#      edge_start_matched     edge_pd_matched        predicate       Exist
# 0         /c/en/against         /c/en/along  /r/DistinctFrom        both
# 1         /c/en/against          /c/en/with       /r/Antonym        both
# 2         /c/en/against          /c/en/with  /r/DistinctFrom        both
# 3           /c/en/along          /c/en/with     /r/RelatedTo        both
# 4             /c/en/and            /c/en/to     /r/RelatedTo        both
# 5           /c/en/arm/n      /c/en/branch/n       /r/Synonym        both
# 6           /c/en/bag/n        /c/en/hold/v       /r/UsedFor        both
# 7           /c/en/bag/n   /c/en/transport/v       /r/UsedFor        both
# 8        /c/en/basket/n        /c/en/hold/v       /r/UsedFor        both
# 9          /c/en/bear/n      /c/en/animal/n           /r/IsA        both
# 10         /c/en/bear/n      /c/en/person/n           /r/IsA        both
# 11          /c/en/bed/n        /c/en/hold/v       /r/UsedFor        both
# ...

# %%
# list(enumerate(edges_zareian))

# %%
edges_zareian[3]
# Out:
# ['/c/en/room/n', '/c/en/to', '/r/RelatedTo']

# %%
def modify_edges(df, conditions, column_index, to):
#     if column_index == 1: column = 'edge_pd_matched'
#     if column_index == 2: column = 'predicate'
    columns = df.columns
    e1, e2, r = conditions
    print(df.loc[(df[columns[0]] == e1) & (df[columns[1]] == e2) & (df[columns[2]] == r), columns[column_index]])
    df.loc[(df[columns[0]] == e1) & (df[columns[1]] == e2) & (df[columns[2]] == r), columns[column_index]] = to
                 
def delete_edge(df, conditions):
    columns = df.columns
    e1, e2, r = conditions
    print(df.loc[(df[columns[0]] == e1) & (df[columns[1]] == e2) & (df[columns[2]] == r)])
    df.drop(df.index[(df[columns[0]] == e1) & (df[columns[1]] == e2) & (df[columns[2]] == r)], axis=0, inplace=True)
#     Report_Card.drop(Report_Card.index[(Report_Card["Lectures"] == "German")],axis=0,inplace=True)

# %%
df_after = df_edges_matched_unique_sorted.copy()

# %%
modify_edges(df_after, ['/c/en/cat/n', '/c/en/woman/n', '/r/IsA'], 1, '/c/en/animal/n')
modify_edges(df_after, ['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext'], 2, '/r/PartOf')
modify_edges(df_after, ['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext'], 2, '/r/PartOf')
modify_edges(df_after, ['/c/en/wheel/n', '/c/en/bicycle/n', '/r/Synonym'], 2, '/r/PartOf')
modify_edges(df_after, ['/c/en/watch/v', '/c/en/look/v', '/r/Entails'], 2, '/r/MannerOf')
modify_edges(df_after, ['/c/en/door/n', '/c/en/room/n', '/r/IsA'], 2, '/r/PartOf')
modify_edges(df_after, ['/c/en/face/n', '/c/en/person/n', '/r/IsA'], 2, '/r/PartOf')
modify_edges(df_after, ['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/arm/n', '/c/en/branch/n', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/sit/v', '/c/en/ride/v', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/branch/n', '/c/en/arm/n', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/table/n', '/c/en/board/n', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/leg/n', '/c/en/branch/n', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/on', '/c/en/along', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/hold/v', '/c/en/have/v', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/have/v', '/c/en/hold/v', '/r/Synonym'], 2, '/r/RelatedTo')
modify_edges(df_after, ['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor'], 2, '/r/IsA')

delete_edge(df_after, ['/c/en/bed/n', '/c/en/plant/n', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/with', '/c/en/from', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/bed/n', '/c/en/person/n', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/mount/v', '/c/en/ride/v', '/r/Synonym'])
delete_edge(df_after, ['/c/en/head/n', '/c/en/toilet/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/counter/n', '/c/en/boot/n', '/r/PartOf'])
delete_edge(df_after, ['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym'])
delete_edge(df_after, ['/c/en/curtain/n', '/c/en/book/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/against', '/c/en/with', '/r/DistinctFrom'])
delete_edge(df_after, ['/c/en/wave/n', '/c/en/woman/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/make/v', '/c/en/have/v', '/r/Synonym'])
delete_edge(df_after, ['/c/en/against', '/c/en/with', '/r/Antonym'])
delete_edge(df_after, ['/c/en/make/v', '/c/en/hold/v', '/r/Synonym'])
delete_edge(df_after, ['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf'])
delete_edge(df_after, ['/c/en/cat/n', '/c/en/guy/n', '/r/Synonym'])
delete_edge(df_after, ['/c/en/and', '/c/en/to', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/to', '/c/en/at', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/child/n', '/c/en/animal/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/tile/n', '/c/en/man/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/from', '/c/en/and', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/against', '/c/en/along', '/r/DistinctFrom'])
delete_edge(df_after, ['/c/en/at', '/c/en/to', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/clock/n', '/c/en/people/n', '/r/UsedFor'])
delete_edge(df_after, ['/c/en/ear/n', '/c/en/fruit/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/from', '/c/en/to', '/r/DistinctFrom'])
delete_edge(df_after, ['/c/en/box/n', '/c/en/player/n', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/bench/n', '/c/en/people/n', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/counter/n', '/c/en/shoe/n', '/r/PartOf'])
delete_edge(df_after, ['/c/en/flag/n', '/c/en/tail/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/make/v', '/c/en/look/v', '/r/MannerOf'])
delete_edge(df_after, ['/c/en/boot/n', '/c/en/car/n', '/r/PartOf'])
delete_edge(df_after, ['/c/en/pot/n', '/c/en/toilet/n', '/r/Synonym'])
delete_edge(df_after, ['/c/en/with', '/c/en/against', '/r/Antonym'])
delete_edge(df_after, ['/c/en/cover/v', '/c/en/play/v', '/r/MannerOf'])
delete_edge(df_after, ['/c/en/flag/n', '/c/en/dog/n', '/r/PartOf'])
delete_edge(df_after, ['/c/en/to', '/c/en/on', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/chair/n', '/c/en/people/n', '/r/UsedFor'])
delete_edge(df_after, ['/c/en/cat/n', '/c/en/book/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/bear/n', '/c/en/person/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/coat/n', '/c/en/hair/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/lie/v', '/c/en/with', '/r/RelatedTo'])
delete_edge(df_after, ['/c/en/counter/n', '/c/en/person/n', '/r/IsA'])
delete_edge(df_after, ['/c/en/room/n', '/c/en/to', '/r/RelatedTo'])
# Out:
# 33    /c/en/woman/n
# Name: edge_pd_matched, dtype: object
# 114    /r/HasContext
# Name: predicate, dtype: object
# 99    /r/HasContext
# Name: predicate, dtype: object
# 131    /r/Synonym
# Name: predicate, dtype: object
# 128    /r/Entails
# Name: predicate, dtype: object
# 50    /r/IsA
# Name: predicate, dtype: object
# 57    /r/IsA
# Name: predicate, dtype: object
# 103    /r/Synonym
# Name: predicate, dtype: object
# 5    /r/Synonym
# Name: predicate, dtype: object
# 116    /r/Synonym
# Name: predicate, dtype: object
# 26    /r/Synonym
# Name: predicate, dtype: object
# 120    /r/Synonym
# Name: predicate, dtype: object
# 84    /r/Synonym
# Name: predicate, dtype: object
# 101    /r/Synonym
# Name: predicate, dtype: object
# 76    /r/Synonym
# Name: predicate, dtype: object
# 72    /r/Synonym
# Name: predicate, dtype: object
# 83    /r/UsedFor
# Name: predicate, dtype: object
#    edge_start_matched edge_pd_matched     predicate
# ...

# %%
edges_zareian[1][1] = '/c/en/animal/n' # ['/c/en/cat/n', '/c/en/woman/n', '/r/IsA'], '/c/en/woman/n' => '/c/en/animal/n'
edges_zareian[73][2] = '/r/PartOf' # ['/c/en/seat/n', '/c/en/airplane/n', '/r/HasContext']
edges_zareian[133][2] = '/r/PartOf' # ['/c/en/nose/n', '/c/en/animal/n', '/r/HasContext']
edges_zareian[136][2] = '/r/PartOf' # ['/c/en/wheel/n', '/c/en/bicycle/n', '/r/Synonym']
edges_zareian[63][2] = '/r/MannerOf' # ['/c/en/watch/v', '/c/en/look/v', '/r/Entails']
edges_zareian[22][2] = '/r/PartOf' # ['/c/en/door/n', '/c/en/room/n', '/r/IsA']
edges_zareian[35][2] = '/r/PartOf' # ['/c/en/face/n', '/c/en/person/n', '/r/IsA']
edges_zareian[36][2] = '/r/RelatedTo' # ['/c/en/paw/n', '/c/en/hand/n', '/r/Synonym']
edges_zareian[6][2] = '/r/RelatedTo' # ['/c/en/arm/n', '/c/en/branch/n', '/r/Synonym']
edges_zareian[34][2] = '/r/RelatedTo' # ['/c/en/sit/v', '/c/en/ride/v', '/r/Synonym']
edges_zareian[54][2] = '/r/RelatedTo' # ['/c/en/branch/n', '/c/en/arm/n', '/r/Synonym']
edges_zareian[89][2] = '/r/RelatedTo' # ['/c/en/table/n', '/c/en/board/n', '/r/Synonym']
edges_zareian[101][2] = '/r/RelatedTo' # ['/c/en/leg/n', '/c/en/branch/n', '/r/Synonym']
edges_zareian[44][2] = '/r/RelatedTo' # ['/c/en/on', '/c/en/along', '/r/Synonym']
edges_zareian[82][2] = '/r/RelatedTo' # ['/c/en/hold/v', '/c/en/have/v', '/r/Synonym']
edges_zareian[105][2] = '/r/RelatedTo' # ['/c/en/have/v', '/c/en/hold/v', '/r/Synonym']
edges_zareian[92][2] = '/r/IsA' # ['/c/en/lamp/n', '/c/en/light/n', '/r/UsedFor']
del edges_zareian[141] # ['/c/en/bed/n', '/c/en/plant/n', '/r/RelatedTo']
del edges_zareian[140] # ['/c/en/with', '/c/en/from', '/r/RelatedTo']
del edges_zareian[138] # ['/c/en/bed/n', '/c/en/person/n', '/r/RelatedTo']
del edges_zareian[134] # ['/c/en/mount/v', '/c/en/ride/v', '/r/Synonym']
del edges_zareian[131] # ['/c/en/head/n', '/c/en/toilet/n', '/r/IsA']
del edges_zareian[124] # ['/c/en/counter/n', '/c/en/boot/n', '/r/PartOf']
del edges_zareian[122] # ['/c/en/trunk/n', '/c/en/boot/n', '/r/Synonym']
del edges_zareian[119] # ['/c/en/curtain/n', '/c/en/book/n', '/r/IsA']
del edges_zareian[118] # ['/c/en/against', '/c/en/with', '/r/DistinctFrom']
del edges_zareian[117] # ['/c/en/wave/n', '/c/en/woman/n', '/r/IsA']
del edges_zareian[112] # ['/c/en/make/v', '/c/en/have/v', '/r/Synonym']
del edges_zareian[111] # ['/c/en/against', '/c/en/with', '/r/Antonym']
del edges_zareian[104] # ['/c/en/make/v', '/c/en/hold/v', '/r/Synonym']
del edges_zareian[103] # ['/c/en/mouth/n', '/c/en/bottle/n', '/r/PartOf']
del edges_zareian[102] # ['/c/en/cat/n', '/c/en/guy/n', '/r/Synonym']
del edges_zareian[99] # ['/c/en/and', '/c/en/to', '/r/RelatedTo']
del edges_zareian[98] # ['/c/en/to', '/c/en/at', '/r/RelatedTo']
del edges_zareian[94] # ['/c/en/child/n', '/c/en/animal/n', '/r/IsA']
del edges_zareian[93] # ['/c/en/tile/n', '/c/en/man/n', '/r/IsA']
del edges_zareian[86] # ['/c/en/from', '/c/en/and', '/r/RelatedTo']
del edges_zareian[79] # ['/c/en/against', '/c/en/along', '/r/DistinctFrom']
del edges_zareian[78] # ['/c/en/at', '/c/en/to', '/r/RelatedTo']
del edges_zareian[77] # ['/c/en/clock/n', '/c/en/people/n', '/r/UsedFor']
del edges_zareian[70] # ['/c/en/ear/n', '/c/en/fruit/n', '/r/IsA']
del edges_zareian[67] # ['/c/en/from', '/c/en/to', '/r/DistinctFrom']
del edges_zareian[66] # ['/c/en/box/n', '/c/en/player/n', '/r/RelatedTo']
del edges_zareian[61] # ['/c/en/bench/n', '/c/en/people/n', '/r/RelatedTo']
del edges_zareian[60] # ['/c/en/counter/n', '/c/en/shoe/n', '/r/PartOf']
del edges_zareian[57] # ['/c/en/flag/n', '/c/en/tail/n', '/r/IsA']
del edges_zareian[55] # ['/c/en/make/v', '/c/en/look/v', '/r/MannerOf']
del edges_zareian[45] # ['/c/en/boot/n', '/c/en/car/n', '/r/PartOf']
del edges_zareian[42] # ['/c/en/pot/n', '/c/en/toilet/n', '/r/Synonym']
del edges_zareian[39] # ['/c/en/with', '/c/en/against', '/r/Antonym']
del edges_zareian[37] # ['/c/en/cover/v', '/c/en/play/v', '/r/MannerOf']
del edges_zareian[33] # ['/c/en/flag/n', '/c/en/dog/n', '/r/PartOf']
del edges_zareian[32] # ['/c/en/to', '/c/en/on', '/r/RelatedTo']
del edges_zareian[29] # ['/c/en/chair/n', '/c/en/people/n', '/r/UsedFor']
del edges_zareian[20] # ['/c/en/cat/n', '/c/en/book/n', '/r/IsA']
del edges_zareian[19] # ['/c/en/bear/n', '/c/en/person/n', '/r/IsA']
del edges_zareian[11] # ['/c/en/coat/n', '/c/en/hair/n', '/r/IsA']
del edges_zareian[8] # ['/c/en/lie/v', '/c/en/with', '/r/RelatedTo']
del edges_zareian[7] # ['/c/en/counter/n', '/c/en/person/n', '/r/IsA']
del edges_zareian[3] # ['/c/en/room/n', '/c/en/to', '/r/RelatedTo']

# %%
df_edges_zareian_after = pd.DataFrame(edges_zareian, columns=columns).sort_values(by=columns).reset_index(drop=True)

# %%
compare(df_after, df_edges_zareian_after)
# Out:
#      edge_start_matched     edge_pd_matched     predicate       Exist
# 0           /c/en/along          /c/en/with  /r/RelatedTo        both
# 1           /c/en/arm/n      /c/en/branch/n  /r/RelatedTo        both
# 2           /c/en/bag/n        /c/en/hold/v    /r/UsedFor        both
# 3           /c/en/bag/n   /c/en/transport/v    /r/UsedFor        both
# 4        /c/en/basket/n        /c/en/hold/v    /r/UsedFor        both
# 5          /c/en/bear/n      /c/en/animal/n        /r/IsA        both
# 6           /c/en/bed/n        /c/en/hold/v    /r/UsedFor        both
# 7         /c/en/bench/n        /c/en/seat/n        /r/IsA        both
# 8       /c/en/bicycle/n        /c/en/ride/v    /r/UsedFor        both
# 9          /c/en/boat/n   /c/en/transport/v    /r/UsedFor        both
# 10         /c/en/boot/n        /c/en/shoe/n        /r/IsA        both
# 11       /c/en/bottle/n        /c/en/hold/v    /r/UsedFor        both
# ...

# %%
len(edges_zareian)

# %%
df_after.to_csv('edges_h1p0_less_2_20211121.csv', index=False)
