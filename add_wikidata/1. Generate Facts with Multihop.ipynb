# %% [markdown]
# # Remember to do it for preds

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import save_obj, load_obj
from edge_builder import EdgeBuilder

# %%
label2id_zareian = load_obj('label2id_150_zareian_code_20211017')
pred2id = load_obj('pred2id_old')
cn_ids = sorted(list(set(label2id_zareian.values()).union(set(pred2id.values()))))
# cn_ids_labels = sorted(list(set(label2id_zareian.values())))
# cn_ids_preds = sorted(list(set(pred2id.values())))
# print(len(cn_ids))
# cn_ids = ['/c/en/against', '/c/en/with']
# cn_ids_to_explore = ['/c/en/animal/n']
cn_ids_to_explore = cn_ids

# %%
len(cn_ids)
# Out:
# 192

# %%
[cn_id for cn_id in cn_ids if 'dorsal' in cn_id]
# Out:
# []

# %% [markdown]
# # Main Issue #1: why is the result the same with different h's?
#
# Example - with cn_ids = \['animal'\], plus=0, we'd expect hops=1 to be

# %%
import gensim
model = gensim.models.KeyedVectors.load_word2vec_format('numberbatch-en-19.08.txt', binary=False)
# model = gensim.models.KeyedVectors.load_word2vec_format('numberbatch-19.08.txt', binary=False) # Never finishes

# %%
from random import seed
seed(0)
test = EdgeBuilder(cn_ids)
# test.run_dfs_relevant_plus(hops=0, plus=1)
# 1. For cn_ids_to_explore = ['/c/en/animal/n'
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=1) #445
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=1, plus=0) #5
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=2, plus=0) #16
# test.run_dfs_relevant_plus(['/c/en/animal/n'], hops=0, plus=1, strategy='random', rand_num=10) #22 # 8 for random
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=1, strategy='random', rand_num=10) #1332
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', rand_num=10) #1664
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=3, strategy='random', rand_num=10) #1332
# test.explore_cn_id('/c/en/against', 1, 0)

# test.run_dfs_relevant_plus(['/c/en/animal'], hops=0, plus=2, strategy='random', rand_num=3) #411 => 570 => 396
# test.run_dfs_relevant_plus(['/c/en/animal'], hops=0, plus=2, strategy='random', rand_num=3) #411 => 570 => 396
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', limit=3) #425 => 983

# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=3) # 817
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0.4, limit=3) # 708
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0.5, limit=3) # 674
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0.7, limit=3, model=model) # v0.0: 608. v0.1: 523 (98 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0.8, limit=3, model=model) # v0.0: 455. v0.1: 425 (pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0.9, limit=3, model=model) # v0.0: 355 => v0.1: 301 (45 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=3, model=model) # v0.1: 709 (192 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=3, strategy='similarity', threshold=0, limit=3, model=model) # v0.1: 1045 (255 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=4, strategy='similarity', threshold=0, limit=3, model=model) # v0.1: 1157 (367 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=10, model=model) # v0.1: 3058 (1200 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=1, strategy='similarity', threshold=0, limit=9999, model=model, last_relevant=True) # v0.1: 15702 (601 pruned)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=1, strategy='similarity', threshold=0, limit=9999, model=model) # v0.1: 680 (autoprune) => 551 after edge_id uniqueness
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=10, model=model) # 1874
test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=50, model=model) # 7462 (738)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='similarity', threshold=0, limit=5, model=model) # 935
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=3) # 1039 (474)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=5) # 1404 (482)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=10) # 2271 (498)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=20) # 3893 (543)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=50) # 7577 (721)
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=0, plus=2, strategy='random', threshold=0, limit=5) # 1044

# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=1, plus=0) # 130
# test.run_dfs_relevant_plus(cn_ids_to_explore, hops=2, plus=0) # 130
print(test.graph.number_of_edges())
# Out:
# edge #1: level=0 /c/en/above/r -> /r/RelatedTo -> /c/en/dorsal; edge_id=/a/[/r/RelatedTo/,/c/en/above/r/,/c/en/dorsal/]
# edge #2: level=0 /c/en/above/r -> /r/RelatedTo -> /c/en/overhead; edge_id=/a/[/r/RelatedTo/,/c/en/above/r/,/c/en/overhead/]
# edge #3: level=0 /c/en/above/r -> /r/RelatedTo -> /c/en/addition; edge_id=/a/[/r/RelatedTo/,/c/en/above/r/,/c/en/addition/]
# edge #4: level=0 /c/en/across/r -> /r/RelatedTo -> /c/en/particular; edge_id=/a/[/r/RelatedTo/,/c/en/across/r/,/c/en/particular/]
# edge #5: level=0 /c/en/across/r -> /r/RelatedTo -> /c/en/horizontally; edge_id=/a/[/r/RelatedTo/,/c/en/across/r/,/c/en/horizontally/]
# edge #6: level=0 /c/en/across/r -> /r/RelatedTo -> /c/en/other; edge_id=/a/[/r/RelatedTo/,/c/en/across/r/,/c/en/other/]
# edge #7: level=0 /c/en/across/r -> /r/RelatedTo -> /c/en/side; edge_id=/a/[/r/RelatedTo/,/c/en/across/r/,/c/en/side/]
# KeyError for againstness from cn_id=/c/en/against. Message is "Key 'againstness' not present"
# ...

# %%
print(test.graph.number_of_edges())
# Out:
# 7462

# %%
test.prune()
print(test.graph.number_of_edges())
# Out:
# 738

# %%
edges = list(test.graph.edges.data('edge_id', keys=True))
len(edges)
# Out:
# 738

# %%
# save_obj(test, 'EdgeBuilder_h0p1_sim_lim9999_thres00_551_20211219')
# save_obj(test, 'h0p2_rand_lim3_985_20211211')

# %%
# test = load_obj('EdgeBuilder_h0p2_sim_lim3_thres00_709_20211212')
# test.prune_main()

# %%
# def to_edges_tuples(list_of_dicts):
#     return [(e['edge_start_matched'], e['edge_end_matched'], e['predicate']) for e in list_of_dicts]

# %%
# edges_tuples = to_edges_tuples(test.edge_list)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 999)
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
pd.set_option('display.min_rows', 100)
pd.set_option('display.expand_frame_repr', True)
# df_edgebuilder = pd.DataFrame(test.edge_list)[['edge_start_raw', 'edge_start_matched', 'predicate', 'edge_end_raw', 'edge_end_matched', 'edge_id']]
df_edgebuilder = pd.DataFrame(edges, columns=['e1', 'e2', 'r', 'edge_id'])

# df_edgebuilder_v0_0_0 = pd.read_csv('edges_154_h1p0_20211121.csv')

# %%
len(df_edgebuilder)
# Out:
# 738

# %%
df_edgebuilder
# Out:
#                             e1                         e2             r  \
# 0               /c/en/across/r                 /c/en/side  /r/RelatedTo
# 1               /c/en/across/r                   /c/en/to  /r/RelatedTo
# 2               /c/en/across/r                 /c/en/from  /r/RelatedTo
# 3                   /c/en/side                /c/en/along  /r/RelatedTo
# 4                   /c/en/side                   /c/en/on  /r/RelatedTo
# 5                /c/en/against               /c/en/versus  /r/RelatedTo
# 6                   /c/en/with              /c/en/against  /r/RelatedTo
# 7                   /c/en/with                 /c/en/from  /r/RelatedTo
# 8                   /c/en/with                /c/en/along  /r/RelatedTo
# 9                   /c/en/with                 /c/en/back  /r/RelatedTo
# 10                  /c/en/from                  /c/en/and  /r/RelatedTo
# 11                  /c/en/from                 /c/en/form  /r/RelatedTo
# ...

# %%
# df_edgebuilder.to_csv('edges_h0p1_sim_lim9999_thres00_551_20211219.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p1_sim_lim9999_thres00_537_20211223.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p1_sim_lim10_thres00_1874_20211223.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim5_thres00_1044_20211223.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim3_thres00_634_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim3_thres00_727_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim3_thres00_474_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim10_thres00_498_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim20_thres00_543_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_rand_lim50_thres00_721_20220104.csv', index=False)
# df_edgebuilder.to_csv('edges_h0p2_sim_lim10_thres00_504_20220104.csv', index=False)
df_edgebuilder.to_csv('edges_h0p2_sim_lim50_thres00_738_20220104.csv', index=False)
